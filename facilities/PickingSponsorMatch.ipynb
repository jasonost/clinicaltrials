# %%
import codecs, requests, nltk, json, string, cPickle as pickle, Levenshtein as L, random, collections
import pandas as pd
from string import punctuation
from connect import gkey

# %% [markdown]
# ### Loading data

# %% [markdown]
# Facilities

# %%
column_names = ["facility_id",
                "nct_id",
                "status",
                "facility_name",
                "city",
                "state",
                "zipcode",
                "country"]

facilities = pd.read_csv('../data/facilities.txt', names=column_names, sep="|", encoding='utf-8', quoting=3)
facilities_nct = facilities.set_index('nct_id')

# %% [markdown]
# Sponsors

# %%
column_names = ["sponsor_id",
                "nct_id",
                "sponsor_type",
                "agency",
                "agency_class"]

sponsors = pd.read_csv('../data/sponsors.txt', names=column_names, sep="|", encoding='utf-8', quoting=3)
sponsors_nct = sponsors.set_index('nct_id')
sponsor_count = sponsors.groupby('agency').count()['nct_id']

# %% [markdown]
# Clustered facilities

# %%
dupes = pickle.load(open('../data/facility_clusters.pkl','rb'))
dupes_nct = dupes.set_index('nct_id')

# %% [markdown]
# Freebase lookups

# %%
sponsor_poss = pickle.load(open('../data/sponsor_guess.pickle','rb'))

# %% [markdown]
# List of acceptable Freebase categories

# %%
cat_ok = {"College/University",
            "Business Operation",
            "Hospital",
            "Organization",
            "Nonprofit organization",
            "Pharmaceutical Preparations Business",
            "Government Agency",
            "Pharmaceutical industry Business",
            "Biotechnology Business",
            "Health care Business",
            "Biological Product (except Diagnostic) Manufacturing Business",
            "Employer",
            "Biomedical research Organization",
            "Venture Funded Company",
            "Biomedical research",
            "Clinical and Research Cancer Center",
            "Surgical and Medical Instruments and Apparatus Business",
            "Drug manufacturer",
            "Educational Institution",
            "Private university",
            "Physician",
            "Disease or medical condition",
            "Internal medicine Hospital",
            "Academic",
            "Electromedical and Electrotherapeutic Apparatus Business",
            "Government Office or Title",
            "In Vitro and In Vivo Diagnostic Substances Business",
            "Medical Equipment and Supplies Manufacturing Business",
            "Drug",
            "Medical specialty",
            "Commercial Physical and Biological Research Business",
            "Orthopedic, Prosthetic, and Surgical Appliances and Supplies Business",
            "Anatomical structure",
            "Medical school",
            "Chemical industry Business",
            "Public school",
            "Hospital and Medical Service Plans Business",
            "Analytical Laboratory Instrument Manufacturing Business",
            "Medical Laboratories Business",
            "Consumer product",
            "Surgeon",
            "Non-profit organization",
            "Educational Institution Campus",
            "Scientist",
            "School district",
            "Food Manufacturing Business",
            "Manufacturing Business",
            "Veterans' benefits Organization",
            "Autism Organization",
            "Diabetes mellitus Organization",
            "School",
            "Think tank",
            "Venture Investor",
            "Crude Petroleum and Natural Gas Extraction Business",
            "Cancer Center Constituent",
            "US State",
            "Dentistry",
            "Military post",
            "General Medical and Surgical Hospitals Business",
            "Drug brand",
            "Financial Services Business",
            "Consumer electronics Business",
            "Household Audio and Video Equipment Business",
            "Bottled and Canned Soft Drinks and Carbonated Waters Business",
            "Alternative medicine Organization",
            "Philanthropy Organization",
            "Petroleum industry Business",
            "Alzheimer's disease Organization",
            "Conglomerate Business",
            "Surgery Organization",
            "Public health Organization",
            "Drug policy Organization",
            "Pharmacies and Drug Stores Business",
            "Agricultural science Organization",
            "Photographic Equipment and Supplies Business",
            "National university",
            "Conservation Organization",
            "Medical trial sponsor",
            "University system",
            "Research Business",
            "Information technology Business",
            "Inventor",
            "Stem Cell Research Business",
            "Perfumes, Cosmetics, and Other Toilet Preparations Business",
            "Defunct Organization",
            "Computer hardware Business",
            "Chemist",
            "Physicist",
            "International development Organization",
            "Department",
            "Foundation",
            "Medicinal and Botanical Manufacturing Business",
            "Psychologist",
            "Cancer Center",
            "Telecom Equipment Vendor Business",
            "Land-grant university",
            "Cooperative",
            "Sports equipment Business",
            "Neurologist",
            "Drugs and Druggists' Sundries Merchant Wholesalers Business",
            "Engineering and Construction Services Business",
            "Aerospace Business",
            "Mining Business",
            "Pediatrics Hospital",
            "Internet Publishing and Broadcasting and Web Search Portals Business",
            "Medical Treatment",
            "Blood donation Organization",
            "Instruments for Measuring and Testing of Electricity and Electrical Signals Business",
            "Cause Of Death",
            "Women's rights Organization",
            "Consumer company",
            "Private equity Business",
            "Plastics Material and Resin Manufacturing Business",
            "Agricultural marketing Organization",
            "Natural history Museum",
            "Institute of technology",
            "Toy Business",
            "Anti-epileptic Agent Drug",
            "Macrolide Antibiotic Drug",
            "Vaccination Organization",
            "Life Insurance Business",
            "Physical medicine and rehabilitation Hospital",
            "Palliative care Organization",
            "Mental health Organization",
            "Biotechnology Organization"
            }

# %% [markdown]
# ### Picking best match based on Freebase category

# %%
best_match = {}
not_found = []

# %%
for a in sponsors['agency'].value_counts().index:
    if a not in best_match and a not in not_found:
        aa = a.encode('utf-8')
        if len(sponsor_poss[aa]) > 0:
            if 'notable' in sponsor_poss[aa][0] and sponsor_poss[aa][0]['notable']['name'] in cat_ok:
                best_match[a] = sponsor_poss[aa][0]
            else:
                print u'Sponsor: %s' % a
                for i, s in enumerate(sponsor_poss[aa][:5]):
                    print '%d.  %s' % (i, str(s))
                same = raw_input('Go with one of these? (enter number) ')
                if same in ['0','1','2','3','4']:
                    best_match[a] = sponsor_poss[aa][int(same)]
                else:
                    not_found.append(a)
                print
                print
        else:
            not_found.append(a)

# %%
pickle.dump(best_match,open('../data/facility_match_good.pkl','wb'))
pickle.dump(not_found,open('../data/facility_match_bad.pkl','wb'))

# %% [markdown]
# ### Getting data for good matches

# %%
# procedure get data
def query_url(url, param_data=None, retries=5):
    '''
    url: full URL from which to request data
    retries: maximum number of retries before moving on
    '''
    while retries > 0:
        try:
            if param_data:
                r = requests.get(url, params=param_data)
            else:
                r = requests.get(url)
        except:
            print '  Got error querying %s. Retrying.' % url
            pass
        if r.status_code == 200:
            return json.loads(r.text)
        else:
            retries -= 1
    
    # if we've tried enough times, print problem and return nothing
    print '  Unable to query %s. Status code %d.' % (url, r.status_code)
    return None

# %%
# procedure to get type and location data
def query_freebase(mid, name):
    '''
    mid: string representing unique Freebase ID
    name: string of entity name, e.g. 'University of California, Berkeley'
    '''
    # initialize variables
    type_data = None
    loc_data = None
    
    # type information
    url = 'https://www.googleapis.com/freebase/v1/topic/m/%s?filter=/type/object/type&key=%s' % (mid, gkey)
    type_info = query_url(url)
    if type_info and 'property' in type_info and '/type/object/type' in type_info['property']:
        type_data = [d['text'] for d in type_info['property']['/type/object/type']['values']
                     if d['id'][:5] not in ('/base','/user','/comm')]
    
    # location information
    url = 'https://www.googleapis.com/freebase/v1/topic/m/%s?filter=/location/location/geolocation&key=%s' % (mid, gkey)
    loc_info = query_url(url)
    if loc_info and 'property' in loc_info and '/location/location/geolocation' in loc_info['property']:
        for v in loc_info['property']['/location/location/geolocation']['values']:
            if '/type/object/type' in v['property'] and v['property']['/type/object/type']['values'][0]['text'] == 'Geocode':
                loc_data = {'lat': v['property']['/location/geocode/latitude']['values'][0]['value'],
                            'lng': v['property']['/location/geocode/longitude']['values'][0]['value'],
                            'source': 'Freebase'
                            }
    
    # backfilling with gmaps
    if not loc_data:
        param_data = {'address': name, 'key': gkey}
        url = 'https://maps.googleapis.com/maps/api/geocode/json'
        loc_info = query_url(url, param_data=param_data)
        if loc_info and len(loc_info['results']) > 0:
            loc_data = loc_info['results'][0]['geometry']['location']
            loc_data['address'] = loc_info['results'][0]['formatted_address']
            loc_data['source'] = 'Google Maps'
    
    return (type_data, loc_data)

# %%
to_remove = []

# %%
for b in sponsors['agency'].value_counts().index:
    if b in best_match and b not in to_remove and 'types' not in best_match[b]:
        # print the basics
        print 'Sponsor name: %s' % b
        print 'Freebase name: %s' % best_match[b]['name']
        print 'Freebase id: %s' % best_match[b]['mid'][3:]
        if 'notable' in best_match[b]:
            print 'Notable for: %s' % best_match[b]['notable']['name']
        else:
            print 'No notable listing'
        print
        
        # print top facilities
        cur_trials = sponsors[sponsors.agency == b]['nct_id']
        facs = facilities_nct.loc[cur_trials]['facility_name'].value_counts()[:3].index
        print 'Top facilities: %s' % str(list(facs))
        print
        
        # get type and location information
        type_data, loc_data = query_freebase(best_match[b]['mid'][3:], best_match[b]['name'])
        print 'Freebase types: ' + ', '.join(type_data)
        print
        print 'Location info: %s' % str(loc_data)
        
        # check if this is acceptable
        ok = raw_input('Enter to accept, "m" to see other possibilities, "d" to drop geocode, any other key to reject both\n')
        if not ok or ok.strip() == '':
            best_match[b]['types'] = type_data
            if loc_data:
                best_match[b]['geo'] = loc_data
        elif ok.lower()[0] == 'd':
            best_match[b]['types'] = type_data
        elif ok.lower()[0] == 'm':
            for i, p in enumerate(sponsor_poss[b.encode('utf-8')]):
                if len(p['name']) > 0:
                    print '%d. %s (%s) %s' % (i, p['name'], p['notable']['name'] if 'notable' in p else 'no notable', p['mid'])
            ok2 = raw_input('Any of these? ')
            try:
                new_s = int(ok2)
                type_data, loc_data = query_freebase(sponsor_poss[b][new_s]['mid'][3:], sponsor_poss[b][new_s]['name'])
                print 'Freebase types: ' + ', '.join(type_data)
                print
                print 'Location info: %s' % str(loc_data)
                ok3 = raw_input('Enter to accept, any other key to reject ')
                if not ok3 or ok3.strip() == '':
                    best_match[b] = sponsor_poss[b][new_s]
                    best_match[b]['types'] = type_data
                    if loc_data:
                        best_match[b]['geo'] = loc_data
                else:
                    to_remove.append(b)
            except:
                to_remove.append(b)
        else:
            to_remove.append(b)
        print
        print

# %%
len([b for b in best_match if 'types' in best_match[b]])
# Out:
# 998

# %%
to_remove
# Out:
# [u'Lundbeck Foundation',
#  u'Hospital for Special Surgery, New York',
#  u'The Royal Norwegian Ministry of Health',
#  u'Aesculap AG',
#  u'Hvidovre University Hospital',
#  u'Universit\xe0 degli Studi di Ferrara',
#  u'Christiana Care Health Services',
#  u'ORA, Inc.',
#  u'Fresenius Medical Care North America',
#  u'Dong-A Pharmaceutical Co., Ltd.',
#  u'Seattle Institute for Biomedical and Clinical Research',
#  u'Ministry of Health, France',
#  u'Huashan Hospital',
#  u'Baylor Research Institute',
#  u'Alberta Heritage Foundation for Medical Research',
#  u'Southeast University, China',
#  u'Biotronik, Inc.',
#  u'Healthpoint',
#  u'Cardiovascular Institute & Fuwai Hospital',
#  u'Mount Sinai Hospital, Canada',
#  u'Sahlgrenska University Hospital, Sweden',
#  u'ConvaTec Inc.',
#  u'Academisch Medisch Centrum - Universiteit van Amsterdam (AMC-UvA)',
#  u'Institute of Tropical Medicine, Belgium']

# %%
not_found = list(set(not_found + to_remove))
for r in to_remove:
    if r in best_match: del best_match[r]

for b in best_match.keys():
    best_match[b]['trials'] = sponsor_count[b]
pickle.dump(best_match,open('../data/facility_match_good.pkl','wb'))
pickle.dump(not_found,open('../data/facility_match_bad.pkl','wb'))

# %%
cur_trials = sponsors[sponsors.agency == 'Georgetown University']['nct_id']

# %%
best_match['Northwestern University']
# Out:
# {'geo': {'lat': 42.054853, 'lng': -87.673945, 'source': 'Freebase'},
#  u'id': u'/en/northwestern_university',
#  u'lang': u'en',
#  u'mid': u'/m/017j69',
#  u'name': u'Northwestern University',
#  u'notable': {u'id': u'/education/university', u'name': u'College/University'},
#  u'score': 1163.585938,
#  'trials': 621,
#  'types': [u'Employer',
#   u'Award Presenting Organization',
#   u'Organization member',
#   u'Organization',
#   u'School in fiction',
#   u'Cancer Center Constituent',
#   u'Endowed Organization',
#   u'Ranked item',
#   u'Nonprofit organization',
#   u'Business Operation',
#   u'Academic institution',
#   u'Educational Institution',
#   u'College/University',
#   u'Film screening venue']}

# %%
slist = dupes[dupes.cluster == 10480].nct_id.values
sponsors_nct.loc[slist]['agency'].value_counts()
# Out:
# Department of Veterans Affairs                                  92
# Duke University                                                 19
# Durham VA Medical Center                                        16
# Bristol-Myers Squibb                                             5
# National Heart, Lung, and Blood Institute (NHLBI)                3
# Pfizer                                                           3
# Merck Sharp & Dohme Corp.                                        3
# Department of Defense                                            2
# ALS Association                                                  2
# National Institute of Allergy and Infectious Diseases (NIAID)     2
# Colorado Prevention Center                                       2
# Precision Fabrics Group, Inc.                                    2
# Sanofi                                                           2
# National Institutes of Health (NIH)                              2
# New River Pharmaceuticals                                        2
# ...
# Ariad Pharmaceuticals                                          1
# Durham Veterans Affairs Medical Center                         1
# National Center for Genome Resources                           1
# ActivBiotics                                                   1
# Sigma-Tau Research, Inc.                                       1
# Otsuka Pharmaceutical Development & Commercialization, Inc.    1
# Bavarian Nordic, Inc.                                          1
# Astellas Pharma Inc                                            1
# University of Rochester                                        1
# Thrasos Innovation, Inc.                                       1
# American Heart Association                                     1
# Centers for Disease Control and Prevention                     1
# New England Research Institutes                                1
# Marinus Pharmaceuticals                                        1
# Otsuka Pharmaceutical Co., Ltd.                                1
# Length: 76, dtype: int64

# %%
[k for k in sponsor_poss.keys() if 'ucsf' in k.lower()]
# Out:
# ['UCSF Mt. Zion hospital',
#  'UCSF Clinical & Translational Science Institute',
#  'the UCSF/MtZion Health Fund',
#  "UZ-UCSF Collaborative Programme on Women's Health"]

# %%
nlist = sponsors[sponsors.agency == 'Bayside Health'].nct_id.values
dupes_nct.loc[nlist]['facility_name'].value_counts()
# Out:
# John Muir Clinical Research Center    1
# dtype: int64

# %%
nlist
# Out:
# array([u'NCT00157144', u'NCT00157170', u'NCT00157183', u'NCT00164086',
#        u'NCT00164138', u'NCT00163735', u'NCT00163748', u'NCT00163761',
#        u'NCT00163774', u'NCT00163787', u'NCT00163800', u'NCT00163813',
#        u'NCT00163826', u'NCT00163839', u'NCT00163852', u'NCT00163865',
#        u'NCT00163878', u'NCT00163891', u'NCT00163904', u'NCT00163917',
#        u'NCT00163930', u'NCT00163943', u'NCT00163956', u'NCT00163969',
#        u'NCT00163982', u'NCT00163995', u'NCT00164008', u'NCT00164021',
#        u'NCT00164034', u'NCT00164047', u'NCT00164060', u'NCT00164073',
#        u'NCT00163631', u'NCT00163644', u'NCT00206531', u'NCT00163670',
#        u'NCT00163683', u'NCT00163696', u'NCT00163709', u'NCT00163722',
#        u'NCT00206570', u'NCT00206609', u'NCT00250263', u'NCT00228657',
#        u'NCT00264511', u'NCT00224367', u'NCT00280878', u'NCT00307697',
#        u'NCT00310570', u'NCT00402220', u'NCT00436020', u'NCT00395148',
#        u'NCT00412919', u'NCT00447109', u'NCT00422253', u'NCT00430989',
#        u'NCT00451711', u'NCT00480727', u'NCT00558935', u'NCT00485368',
#        u'NCT00532688', u'NCT00531258', u'NCT00481026', u'NCT00662194',
#        u'NCT00660361', u'NCT00697177', u'NCT00637429', u'NCT00666861',
#        u'NCT00636922', u'NCT00681226', u'NCT00808938', u'NCT00808782',
#        u'NCT00825123', u'NCT00885521', u'NCT00906646', u'NCT00986167',
#        u'NCT01015794', u'NCT01029223', u'NCT01121042', u'NCT01186614',
#        u'NCT01272713', u'NCT01365065', u'NCT01391377', u'NCT01424150',
#        u'NCT01499316', u'NCT01886638', u'NCT01813357', u'NCT02014623',
#        u'NCT02003300', u'NCT01958736', u'NCT01998711', u'NCT01997931',
#        u'NCT02020538', u'NCT01974778'], dtype=object)

# %%
[dupes[dupes.cluster == clus]['facility_name'].value_counts().index[0] for clus in dupes['cluster'].value_counts().index]
# Out:
# [u'National Institutes of Health Clinical Center, 9000 Rockville Pike',
#  u'Mayo Clinic',
#  u'Memorial Sloan-Kettering Cancer Center',
#  u'UT MD Anderson Cancer Center',
#  u'Johns Hopkins University',
#  u'Massachusetts General Hospital',
#  u'Washington University School of Medicine',
#  u'Cleveland Clinic Foundation',
#  u'Duke University Medical Center',
#  u'University of Pittsburgh',
#  u'University of Chicago',
#  u'University of Michigan',
#  u'Stanford University School of Medicine',
#  u'University of Alabama at Birmingham',
#  u'Northwestern University',
#  u'Indiana University Cancer Center',
#  u'Emory University',
#  u'University of Pennsylvania',
#  u'University of Wisconsin Hospital and Clinics',
#  u'University of Rochester',
#  u'Ohio State University',
#  u'University of Minnesota',
#  u'University of California, San Francisco',
#  u'Columbia University Medical Center',
#  u'University of North Carolina',
#  u'Oregon Health and Science University',
#  u'Vanderbilt University Medical Center',
#  u'University of Washington',
#  u'University of Miami',
#  u'Dana-Farber Cancer Institute',
#  u'Medical University of South Carolina',
#  u'University of Iowa Hospitals and Clinics',
#  u'Baylor College of Medicine',
#  u'Beth Israel Deaconess Medical Center',
#  u'University of Florida',
#  u'Roswell Park Cancer Institute',
#  u'Wake Forest University Health Sciences',
#  u"Brigham and Women's Hospital",
#  u"Children's Hospital of Philadelphia",
#  u'H. Lee Moffitt Cancer Center and Research Institute',
#  u'University of Maryland',
#  u'University of Colorado Denver',
#  u'City of Hope Comprehensive Cancer Center',
#  u'University of New Mexico Cancer Center',
#  u'University of Virginia',
#  u'University of Texas - MD Anderson Cancer Center',
#  u'Fred Hutchinson Cancer Research Center',
#  u'University of Utah',
#  u'Mount Sinai School of Medicine',
#  u'Vanderbilt-Ingram Cancer Center',
#  u"Cincinnati Children's Hospital Medical Center",
#  u'University of Cincinnati',
#  u'Penn State Cancer Institute at Milton S. Hershey Medical Center',
#  u'Virginia Commonwealth University',
#  u'Rush University Medical Center',
#  u'University of California Davis Cancer Center',
#  u'Cancer Center of Kansas, PA - Wichita',
#  u'Yale University',
#  u'University of Mississippi Medical Center',
#  u'Fox Chase Cancer Center',
#  u'University of Texas Health Science Center at San Antonio',
#  u'University of Kansas Medical Center',
#  u'University of Illinois at Chicago',
#  u'Cedars-Sinai Medical Center',
#  u'Medical College of Wisconsin',
#  u'University of Texas Southwestern Medical Center',
#  u'Montefiore Medical Center',
#  u'Mayo Clinic - Jacksonville',
#  u'University of Oklahoma Health Sciences Center',
#  u'St. Louis University Health Sciences Center',
#  u'University of Nebraska Medical Center',
#  u'Henry Ford Hospital',
#  u"Children's Hospital of Pittsburgh",
#  u'Thomas Jefferson University',
#  u"Children's National Medical Center",
#  u'Case Western Reserve University',
#  u'Mayo Clinic Scottsdale',
#  u'University of Arkansas for Medical Sciences',
#  u'St. Vincent Hospital Regional Cancer Center',
#  u'Jonsson Comprehensive Cancer Center, UCLA',
#  u'Sidney Kimmel Comprehensive Cancer Center at Johns Hopkins',
#  u'University Hospitals of Cleveland',
#  u'University of Kentucky',
#  u'Wayne State University',
#  u'CCOP - Carle Cancer Center',
#  u'USC/Norris Comprehensive Cancer Center and Hospital',
#  u'Rhode Island Hospital',
#  u'University of Texas Medical Branch',
#  u'University of Southern California',
#  u"Children's Hospital Los Angeles",
#  u"St. Jude Children's Research Hospital",
#  u'Medical Oncology and Hematology Associates at Mercy Cancer Center',
#  u'Arthur G. James Cancer Hospital - Ohio State University',
#  u'Barbara Ann Karmanos Cancer Institute',
#  u'Marshfield Clinic',
#  u'University of Massachusetts Medical School',
#  u'Hackensack University Medical Center',
#  u'North Shore University Hospital',
#  u'William Beaumont Hospital',
#  u'Loyola University Medical Center',
#  u'Mount Sinai Medical Center',
#  u'Dartmouth-Hitchcock Medical Center',
#  u'CCOP - Scott and White Hospital',
#  u'Lineberger Comprehensive Cancer Center at University of North Carolina - Chapel Hill',
#  u"Children's Hospital Boston",
#  u'MetroHealth Medical Center',
#  u'Florida Hospital',
#  u'Georgetown University',
#  u'Hurley Medical Center',
#  u'CCOP - Southern Nevada Cancer Research Foundation',
#  u'CCOP - Montana Cancer Consortium',
#  u'Cancer Institute of New Jersey',
#  u"Green Bay Oncology, Limited at St. Mary's Hospital",
#  u'Huntsman Cancer Institute',
#  u'University of Texas Health Science Center at Houston',
#  u'UCLA',
#  u'CCOP - Wichita',
#  u"Children's Mercy Hospital",
#  u'University of California, Los Angeles',
#  u'New York University Langone Medical Center',
#  u'University of California, San Diego',
#  u'Beth Israel Medical Center',
#  u'Siouxland Hematology-Oncology Associates, LLP',
#  u'Virginia Mason Medical Center',
#  u'Carolinas Medical Center',
#  u'Loma Linda University Medical Center',
#  u'Hennepin County Medical Center',
#  u"Children's Memorial Hospital",
#  u'SUNY Upstate Medical University Hospital',
#  u'CCOP - Iowa Oncology Research Association',
#  u'Arizona Cancer Center',
#  u'Weill Cornell Medical College',
#  u'Duke Comprehensive Cancer Center',
#  u'Boston Medical Center',
#  u'University of California San Diego Cancer Center',
#  u"Texas Children's Hospital",
#  u'University of Arizona',
#  u'CCOP - Michigan Cancer Research Consortium',
#  u'Stanford University',
#  u'CCOP - Metro-Minnesota',
#  u"Nationwide Children's Hospital",
#  u'Via Christi Cancer Center at Via Christi Regional Medical Center',
#  u'Billings Clinic - Downtown',
#  u'Riverside Methodist Hospital',
#  u'Abramson Cancer Center of the University of Pennsylvania',
#  u"Children's Healthcare of Atlanta",
#  u'Robert H. Lurie Comprehensive Cancer Center at Northwestern University',
#  u'Bozeman Deaconess Cancer Center',
#  u'The Methodist Hospital',
#  u'CCOP - Grand Rapids',
#  u'Park Nicollet Cancer Center',
#  u'CCOP - Upstate Carolina',
#  u'Walter Reed Army Medical Center',
#  u'West Michigan Cancer Center',
#  u'Ireland Cancer Center',
#  u'University of Louisville',
#  u'Creighton University Medical Center',
#  u'John Stoddard Cancer Center at Iowa Methodist Medical Center',
#  u'Norris Cotton Cancer Center',
#  u'Comprehensive Cancer Center at Wake Forest University',
#  u'University of Colorado Cancer Center',
#  u'Bronson Methodist Hospital',
#  u'CCOP - Columbia River Oncology Program',
#  u'CCOP - Columbus',
#  u'CCOP - Cancer Research for the Ozarks',
#  u'Washington Hospital Center',
#  u'Herbert Irving Comprehensive Cancer Center',
#  u'Cancer Center of Kansas, PA - Winfield',
#  u'United Hospital',
#  u'Geisinger Medical Center',
#  u'Cancer Center of Kansas, PA - Wellington',
#  u'Cancer Center of Kansas, PA - Dodge City',
#  u'Fairview Southdale Hospital',
#  u'Associates in Womens Health, PA - North Review',
#  u'Mercy and Unity Cancer Center at Mercy Hospital',
#  u'Holden Comprehensive Cancer Center at University of Iowa',
#  u'Cancer Center of Kansas, PA - Newton',
#  u'Cancer Center of Kansas, PA - Chanute',
#  u'Cancer Center of Kansas, PA - Pratt',
#  u'Cancer Center of Kansas, PA - Kingman',
#  u'CCOP - Mount Sinai Medical Center',
#  u'Cancer Center of Kansas, PA - Parsons',
#  u'Hospital of the University of Pennsylvania',
#  u'Galesburg Cottage Hospital',
#  u'Cancer Center of Kansas, PA - El Dorado',
#  u'Cancer Centers of the Carolinas',
#  u'Boston University School of Medicine',
#  u'New York Presbyterian Hospital - Cornell Campus',
#  u'St. John Macomb Hospital',
#  u"St. Luke's Regional Medical Center",
#  u'Hematology-Oncology Centers of the Northern Rockies - Billings',
#  u"Saint Luke's - Roosevelt Hosp Ctr",
#  u'Mercy Medical Center - Sioux City',
#  u'Regions Hospital Cancer Care Center',
#  u'Ellis Fischel Cancer Center at University of Missouri - Columbia',
#  u"Seattle Children's Hospital",
#  u'University of South Florida',
#  u'Charles M. Barrett Cancer Center at University Hospital',
#  u'McFarland Clinic, PC',
#  u'Great Falls Clinic - Main Facility',
#  u"Children's Hospital and Research Center at Oakland",
#  u'St. Joseph Mercy Oakland',
#  u'Stony Brook University Medical Center',
#  u'UT Southwestern Medical Center',
#  u'Methodist Medical Center of Illinois',
#  u'Warren Grant Magnuson Clinical Center - NCI Clinical Studies Support',
#  u'CCOP - Toledo Community Hospital',
#  u'CCOP - Kansas City',
#  u'St. Vincent Healthcare Cancer Care Services',
#  u'University of Missouri',
#  u'Decatur Memorial Hospital Cancer Care Institute',
#  u'Fletcher Allen Health Care - University Health Center Campus',
#  u'Siteman Cancer Center at Barnes-Jewish Hospital - Saint Louis',
#  u'Tulane University Health Sciences Center',
#  u"Children's Hospital of Orange County",
#  u'Dana-Farber Cancer Institute',
#  u'Montana Cancer Specialists at Montana Cancer Center',
#  u'Memorial Hospital of South Bend',
#  u'Temple University Hospital',
#  u'Rapid City Regional Hospital',
#  u"St. Peter's Hospital",
#  u'Minnesota Oncology Hematology PA-Maplewood',
#  u"Nemours Children's Clinic",
#  u'James P. Wilmot Cancer Center at University of Rochester Medical Center',
#  u'CCOP - MeritCare Hospital',
#  u"Children's Hospital Colorado",
#  u'Borgess Medical Center',
#  u"Rush Presbyterian - Saint Luke's Med Ctr",
#  u'Cancer Care Northwest - Spokane South',
#  u'CCOP - Duluth',
#  u'State University of New York Upstate Medical University',
#  u'Wayne Memorial Hospital, Incorporated',
#  u'George Washington University',
#  u'Swedish Cancer Institute at Swedish Medical Center - First Hill Campus',
#  u'Winthrop University Hospital',
#  u'MD Anderson Cancer Center Orlando',
#  u'Henry Ford Health System',
#  u'Minnesota Oncology Hematology, PA - Woodbury',
#  u'CCOP - Illinois Oncology Research Association',
#  u'CCOP - Bay Area Tumor Institute',
#  u'California Pacific Medical Center',
#  u'Newark Beth Israel Medical Center',
#  u'St. Mary Mercy Hospital',
#  u'Harborview Medical Center',
#  u'CCOP - Greenville',
#  u'Virginia Piper Cancer Institute at Abbott - Northwestern Hospital',
#  u'Howard University Hospital',
#  u'OSF St. Francis Medical Center',
#  u'Weill Medical College of Cornell University',
#  u'Chao Family Comprehensive Cancer Center',
#  u'Spectrum Health at Butterworth Campus',
#  u'Good Samaritan Hospital',
#  u'Dana-Farber/Harvard Cancer Center at Dana Farber Cancer Institute',
#  u"Presbyterian - St. Luke's Medical Center",
#  u'Brooke Army Medical Center',
#  u'University of California Medical Center At Irvine-Orange Campus',
#  u"Cook Children's Medical Center",
#  u'Albany Medical Center',
#  u'Glacier Oncology, PLLC',
#  u'Swedish Medical Center',
#  u'Samaritan North Cancer Care Center',
#  u'Ochsner Clinic Foundation',
#  u'Community Cancer Center',
#  u'Tufts Medical Center',
#  u'The Miriam Hospital',
#  u'San Francisco General Hospital',
#  u'Welch Cancer Center at Sheridan Memorial Hospital',
#  u'CCOP - Northern Indiana CR Consortium',
#  u'University of Tennessee, Memphis Cancer Center',
#  u'Harbor-UCLA Medical Center',
#  u'Elkhart General Hospital',
#  u'Mount Carmel Health - West Hospital',
#  u'Cancer Research Center of Hawaii',
#  u'Genesys Hurley Cancer Institute',
#  u'Blanchard Valley Medical Associates',
#  u'Madigan Army Medical Center',
#  u'Sarah Cannon Research Institute',
#  u'CCOP - Missouri Valley Cancer Consortium',
#  u'University of Connecticut Health Center',
#  u'Joliet Oncology-Hematology Associates, Limited - West',
#  u'Cancer Treatment Center at Pekin Hospital',
#  u'St. Francis Hospital and Health Centers - Beech Grove Campus',
#  u'St. Vincent Mercy Medical Center',
#  u'Hartford Hospital',
#  u"Children's Hospital and Regional Medical Center - Seattle",
#  u'CCOP - Dayton',
#  u'CCOP - Christiana Care Health Services',
#  u'Gundersen Lutheran',
#  u'University of Vermont',
#  u'Kalispell Medical Oncology at KRMC',
#  u'Saint John Hospital and Medical Center',
#  u'Kimmel Cancer Center at Thomas Jefferson University - Philadelphia',
#  u'Bay Area Cancer Care Center at Bay Area Medical Center',
#  u'Avera Cancer Institute',
#  u"St. Mary's Hospital Medical Center - Green Bay",
#  u'Van Elslander Cancer Center at St. John Hospital and Medical Center',
#  u'Lawrence Memorial Hospital',
#  u'Medical College of Georgia',
#  u'BroMenn Regional Medical Center',
#  u'UCSF Helen Diller Family Comprehensive Cancer Center',
#  u"Phoenix Children's Hospital",
#  u'New York Medical College',
#  u'Winship Cancer Institute of Emory University',
#  u'St. Joseph Medical Center',
#  u'Wake Forest University Comprehensive Cancer Center',
#  u'Illinois Valley Community Hospital',
#  u'Albert Einstein Cancer Center',
#  u'Mid Dakota Clinic, PC',
#  u'UCSF',
#  u'West Virginia University',
#  u'Fort Wayne Medical Oncology and Hematology Inc - State Boulevard',
#  u'Eureka Community Hospital',
#  u'Sanofi-Aventis Administrative Office',
#  u'Western Pennsylvania Hospital',
#  u'UAB Comprehensive Cancer Center',
#  u'Baylor University Medical Center',
#  u'Reid Hospital & Health Care Services',
#  u'Sinai Hospital of Baltimore',
#  u'LDS Hospital',
#  u"All Children's Hospital",
#  u'Christiana Care Health System-Christiana Hospital',
#  u'Tennessee Oncology, PLLC',
#  u'Hubert H. Humphrey Cancer Center at North Memorial Outpatient Center',
#  u'Swedish Medical Center',
#  u'Mission Hospitals - Memorial Campus',
#  u'Adena Regional Medical Center',
#  u'Methodist Estabrook Cancer Center',
#  u'Licking Memorial Cancer Care Program at Licking Memorial Hospital',
#  u"Children's Hospitals and Clinics of Minnesota - Minneapolis",
#  u'Hollings Cancer Center at Medical University of South Carolina',
#  u"Saint Luke's Mountain States Tumor Institute",
#  u"Rady Children's Hospital - San Diego",
#  u'Kaiser Permanente',
#  u'Natalie Warren Bryant Cancer Center at St. Francis Hospital',
#  u'Doctors Hospital at Ohio Health',
#  u'Allegheny General Hospital',
#  u'Porter Adventist Hospital',
#  u'Graham Hospital',
#  u'McDonough District Hospital',
#  u'Lehigh Valley Hospital',
#  u'CCOP - Colorado Cancer Research Program',
#  u'Masonic Cancer Center at University of Minnesota',
#  u'Munson Medical Center',
#  u'Abington Memorial Hospital',
#  u'Saint Joseph Mercy Cancer Center',
#  u'Tulane University School of Medicine',
#  u'Southern Illinois University School of Medicine',
#  u'CCOP - Atlanta Regional',
#  u'Seattle Cancer Care Alliance',
#  u'Long Island Jewish Medical Center',
#  u'University of Florida',
#  u'Medical City Dallas Hospital',
#  u'Lombardi Comprehensive Cancer Center at Georgetown University',
#  u'Mercy and Unity Cancer Center at Unity Hospital',
#  u'Toledo Clinic, Incorporated - Main Clinic',
#  u'University of South Alabama',
#  u'Scripps Clinic',
#  u'UC Davis Medical Center',
#  u'Cancer Center of Kansas - Salina',
#  u'West Virginia University Charleston',
#  u"Seton Cancer Institute at Saint Mary's - Saginaw",
#  u"Rainbow Babies and Children's Hospital",
#  u'New York State Psychiatric Institute',
#  u"Children's Hospital of Michigan",
#  u"C S Mott Children's Hospital",
#  u'Montana Cancer Center at St. Patrick Hospital and Health Sciences Center',
#  u'Sparrow Regional Cancer Center',
#  u'Wenatchee Valley Medical Center',
#  u'Oklahoma University Cancer Institute',
#  u'Northern Rockies Radiation Oncology Center',
#  u'St. Alexius Medical Center Cancer Center',
#  u"Midwest Children's Cancer Center",
#  u'Veterans Affairs Medical Center - Dayton',
#  u'Abbott-Northwestern Hospital',
#  u'Missouri Baptist Cancer Center',
#  u'Barnes-Jewish Hospital',
#  u'Greater Baltimore Medical Center',
#  u'Women and Infants Hospital',
#  u'Flower Hospital Cancer Center',
#  u'Maine Medical Center',
#  u'Blumenthal Cancer Center at Carolinas Medical Center',
#  u'Lima Memorial Hospital',
#  u"Arkansas Children's Hospital",
#  u'Saint Anthony Memorial Health Centers',
#  u'Louisiana State University Health Sciences Center - Shreveport',
#  u'Geisinger Medical Group - Scenery Park',
#  u'Grant Medical Center Cancer Care',
#  u'Veterans Affairs Medical Center - Chicago (Westside Hospital)',
#  u'Baystate Medical Center',
#  u'East Carolina University',
#  u'National Jewish Health',
#  u'Hickman Cancer Center at Bixby Medical Center',
#  u"NYU School of Medicine's Kaplan Comprehensive Cancer Center",
#  u'Providence St. Vincent Medical Center',
#  u'Boulder Community Hospital',
#  u'Arkansas Cancer Research Center at University of Arkansas for Medical Sciences',
#  u'Northeast Georgia Medical Center',
#  u'St. Mary - Corwin Regional Medical Center',
#  u"St. Christopher's Hospital for Children",
#  u'Sky Ridge Medical Center',
#  u"Kosair Children's Hospital",
#  u'CCOP - Northwest',
#  u'CCOP - Ochsner',
#  u'Lankenau Cancer Center at Lankenau Hospital',
#  u'Riley Hospital for Children',
#  u'MBCCOP - LSU Health Sciences Center',
#  u"Saint John's Mercy Medical Center",
#  u'Genesis Regional Cancer Center at Genesis Medical Center',
#  u'James Graham Brown Cancer Center',
#  u'Inova Fairfax Hospital',
#  u"Saint Luke's Hospital of Kansas City",
#  u'Greenville Hospital Cancer Center',
#  u'Simmons Comprehensive Cancer Center at University of Texas Southwestern Medical Center - Dallas',
#  u'Mercy Memorial Hospital - Monroe',
#  u'UCSF Comprehensive Cancer Center',
#  u'Bellevue Hosp / New York Univ Med Ctr',
#  u'CCOP - Kalamazoo',
#  u'University of Hawaii',
#  u'Kaiser Permanente Center for Health Research',
#  u'Rose Medical Center',
#  u'Green Bay Oncology, Limited - Sturgeon Bay',
#  u'Legacy Emanuel Hospital and Health Center',
#  u'Green Bay Oncology, Limited - Oconto Falls',
#  u'Green Bay Oncology, Limited - Escanaba',
#  u'Karmanos Cancer Institute',
#  u'CCOP - Central Illinois',
#  u'Beth Israel Deaconess Medical Center',
#  u'UVMC Cancer Care Center at Upper Valley Medical Center',
#  u'Cedar Rapids Oncology Associates',
#  u'Providence Saint Joseph Medical Center - Burbank',
#  u'Medcenter One Hospital Cancer Care Center',
#  u'Saint Alphonsus Regional Medical Center',
#  u'Oakwood Cancer Center at Oakwood Hospital and Medical Center',
#  u'Evanston CCOP-NorthShore University HealthSystem',
#  u'Foote Memorial Hospital',
#  u'CCOP - St. Louis-Cape Girardeau',
#  u'Vermont Cancer Center',
#  u"St. John's Regional Health Center",
#  u"Lucile Packard Children's Hospital Stanford University",
#  u'Josephine Ford Cancer Center at Henry Ford Hospital',
#  u'Sanford Cancer Center at Sanford USD Medical Center',
#  u'McKee Medical Center',
#  u"Connecticut Children's Medical Center",
#  u'Morristown Memorial Hospital',
#  u'UCSF Cancer Center and Cancer Research Institute',
#  u'Alfred I. duPont Hospital for Children',
#  u'Broward General Medical Center',
#  u"Childrens Hospital-King's Daughters",
#  u'New England Medical Center Hospital',
#  u'Oncology Hematology Associates of Central Illinois, PC - Peoria',
#  u'Research Medical Center',
#  u'Gibbs Regional Cancer Center at Spartanburg Regional Medical Center',
#  u'Rutherford Hospital',
#  u'North Colorado Medical Center',
#  u'Cooper Hospital University Medical Center',
#  u'Hulston Cancer Center at Cox Medical Center South',
#  u'Kaiser Permanente',
#  u'VA Puget Sound Health Care System',
#  u'Columbia Presbyterian Med Ctr',
#  u'Piedmont Hospital',
#  u'Medical X-Ray Center, PC',
#  u'CCOP - Hematology-Oncology Associates of Central New York',
#  u'Case Medical Center, University Hospitals Seidman Cancer Center, Case Comprehensive Cancer Center',
#  u'John H. Stroger, Jr. Hospital of Cook County',
#  u'CentraCare Clinic - River Campus',
#  u'Cardinal Bernardin Cancer Center at Loyola University Medical Center',
#  u'CCOP - Southeast Cancer Control Consortium',
#  u'Kaiser Permanente Medical Center - San Francisco Geary Campus',
#  u'Cancer Institute of New Jersey at Cooper - Voorhees',
#  u'Saint Joseph Mercy Hospital',
#  u'Kaiser Permanente-Oakland',
#  u'PRACS Institute, Ltd.',
#  u'Sletten Cancer Institute at Benefis Healthcare',
#  u'Albert B. Chandler Medical Center, University of Kentucky',
#  u'Cancer Therapy and Research Center',
#  u'Reading Hospital and Medical Center',
#  u'Albert Einstein College of Medicine',
#  u'Utah Cancer Specialists at UCS Cancer Center',
#  u'Toledo Clinic - Oregon',
#  u'Alegant Health Cancer Center at Bergan Mercy Medical Center',
#  u'North Coast Cancer Care, Incorporated',
#  u'Greenebaum Cancer Center at University of Maryland Medical Center',
#  u'Providence Cancer Center at Providence Portland Medical Center',
#  u'Mercy Cancer Center at Mercy Medical Center - Des Moines',
#  u'North Suburban Medical Center',
#  u'Cancer Center of Kansas, PA - Liberal',
#  u'Mary Bird Perkins Cancer Center',
#  u"Primary Children's Medical Center",
#  u"St. Joseph's Hospital and Medical Center",
#  u'Waukesha Memorial Hospital Regional Cancer Center',
#  u'Dixie Regional Medical Center - East Campus',
#  u'Drexel University College of Medicine',
#  u'Toledo Hospital',
#  u'Utah Valley Regional Medical Center - Provo',
#  u"Miami Children's Hospital",
#  u'VA Palo Alto Health Care System',
#  u'Long Beach Memorial Medical Center',
#  u'Rocky Mountain Cancer Center',
#  u'Saint Vincent Hospital and Health Services',
#  u'Los Angeles County - USC Med Ctr',
#  u'Naval Medical Center, Portsmouth',
#  u'St. Francis Cancer Center at St. Francis Medical Center',
#  u'Duke University Health System',
#  u'Durham VA Medical Center',
#  u'CCOP - MainLine Health',
#  u'Michael E. DeBakey VA Medical Center (152)',
#  u'Bismarck Cancer Center',
#  u'Memorial Health University Medical Center',
#  u'Froedtert and the Medical College of Wisconsin',
#  u'CCOP - Santa Rosa Memorial Hospital',
#  u'University Cancer Center at University of Washington Medical Center',
#  u'Medical Oncology and Hematology Associates-West Des Moines',
#  u'Florida Cancer Specialists',
#  u'Community Medical Center',
#  u'Case Comprehensive Cancer Center',
#  u'The Christ Hospital',
#  u'Nemours Childrens Clinic - Orlando',
#  u'University of Texas Southwestern Medical Center at Dallas',
#  u'Rush-Copley Cancer Care Center',
#  u'Memoral Sloan Kettering Cancer Center',
#  u'SUNY Downstate Medical Center',
#  u'Valley Medical Oncology Consultants-Fremont',
#  u'Lahey Clinic',
#  u'Fredericksburg Oncology, Incorporated',
#  u'Milton S. Hershey Medical Center',
#  u'Eastern Maine Medical Center',
#  u'Presbyterian Hospital',
#  u'Mercy Regional Cancer Center at Mercy Medical Center',
#  u'Wesley Medical Center',
#  u'Holy Family Memorial Hospital',
#  u'Kapiolani Medical Center for Women and Children',
#  u'Medical University of Ohio Cancer Center',
#  u'St. James Healthcare Cancer Care',
#  u'VA Connecticut Healthcare System',
#  u'Miami Research Associates',
#  u'Columbia Basin Hematology',
#  u'Kaiser Permanente Medical Center - Santa Clara',
#  u'Marlene & Stewart Greenebaum Cancer Center, University of Maryland',
#  u'Knight Cancer Institute at Oregon Health and Science University',
#  u'Big Sky Oncology',
#  u'Kinston Medical Specialists',
#  u'Pennington Biomedical Research Center',
#  u'Kaiser Permanente Medical Center - Sacramento',
#  u'Walter Reed National Military Medical Center',
#  u'UMDNJ - New Jersey Medical School',
#  u'Texas Oncology, P.A.',
#  u'Elkhart Clinic',
#  u'Bryn Mawr Hospital',
#  u'Skagit Valley Hospital Cancer Care Center',
#  u'Altoona Center for Clinical Research',
#  u'Marshfield Clinic - Indianhead Center',
#  u'Tripler Army Medical Center',
#  u'Louisiana State University Health Science Center',
#  u'Illinois CancerCare Galesburg',
#  u'Northern Indiana Cancer Research Consortium',
#  u'Hospital for Special Surgery',
#  u'Northside Hospital',
#  u'Overlook Hospital',
#  u'Oakwood Hospital',
#  u"Cardinal Glennon Children's Hospital",
#  u'Mecosta County Medical Center',
#  u'VA San Diego Healthcare System',
#  u'Icahn School of Medicine at Mount Sinai',
#  u"St. Luke's Hospital Cancer Center",
#  u'Rebecca and John Moores UCSD Cancer Center',
#  u'Akron General Medical Center',
#  u'Wake Research Associates',
#  u'Saint Francis Hospital and Medical Center',
#  u'Geisinger Medical Center-Cancer Center Hazelton',
#  u'Memorial Sloan-Kettering Cancer Center @ Suffolk',
#  u"HealthEast Cancer Care at St. John's Hospital",
#  u'Shands Hospital and Clinics, University of Florida',
#  u'Illinois CancerCare-Peoria',
#  u'David Grant Medical Center',
#  u"Children's Hospital Central California",
#  u'Providence Hospital - Southfield',
#  u'Truman Medical Center',
#  u'Cook County Hosp',
#  u'Oncology Hematology Associates of Central Illinois, PC - Ottawa',
#  u'University Medical Center of Southern Nevada',
#  u'OnCare Hawaii, Incorporated - Kuakini',
#  u'Memorial Hermann Hospital',
#  u"East Tennessee Children's Hospital",
#  u"St. Rita's Medical Center",
#  u'Strecker Cancer Center at Marietta Memorial Hospital',
#  u"Children's Hospital of Denver",
#  u"The Children's Medical Center of Dayton",
#  u'Brown University',
#  u'Mercy Capitol Hospital',
#  u'Marshfield Clinic-Minocqua Center',
#  u'Albert Einstein Cancer Center at Albert Einstein College of Medicine',
#  u'Robert Wood Johnson Medical School',
#  u'Swedish-American Regional Cancer Center',
#  u'UC Davis Comprehensive Cancer Center',
#  u'Howard Community Hospital',
#  u'Virginia Oncology Associates',
#  u'Penrose Cancer Center at Penrose Hospital',
#  u'Massey Cancer Center',
#  u'CCOP - Cedar Rapids Oncology Project',
#  u"Children's Hospital of Wisconsin",
#  u'New York Oncology Hematology, P.C.',
#  u'State University of New York Health Science Center at Brooklyn',
#  u'Community Hospital of Springfield and Clark County',
#  u'Providence Portland Medical Center',
#  u'Oncology Hematology Care',
#  u"Children's Hospital Medical Center of Akron",
#  u'Saint Joseph Regional Medical Center-Mishawaka',
#  u'Presbyterian Cancer Center at Presbyterian Hospital',
#  u'Magee-Womens Hospital of UPMC',
#  u'CCOP - Sioux Community Cancer Consortium',
#  u'Metro-Minnesota CCOP',
#  u'UNMC Eppley Cancer Center at the University of Nebraska Medical Center',
#  u"Saint Luke's Cancer Institute at Saint Luke's Hospital",
#  u'Poudre Valley Hospital',
#  u'VA Greater Los Angeles Healthcare System, West LA',
#  u'Miller - Dwan Medical Center',
#  u'Cancer Center at the University of Virginia',
#  u"St. Margaret's Hospital",
#  u'Marshfield Clinic - Weston Center',
#  u'Central Baptist Hospital',
#  u'CCOP - Scottsdale Oncology Program',
#  u'Minor and James Medical, PLLC',
#  u'Pardee Memorial Hospital',
#  u'Ingalls Memorial Hospital',
#  u'Sparrow Hospital',
#  u'Heartland Regional Medical Center',
#  u"Saint Joseph's Hospital of Atlanta",
#  u'Mayo Clinic Hospital',
#  u'Southeast Cancer Center',
#  u'Saint Barnabas Medical Center',
#  u'Front Range Cancer Specialists',
#  u"Children's Hospital of New Orleans",
#  u'North Kansas City Hospital',
#  u'Saint Francis Medical Center',
#  u'Massachusetts General Hospital',
#  u"Saint Mary's of Michigan",
#  u'Hematology and Oncology Associates',
#  u'Marshfield Clinic Cancer Care at Regional Cancer Center',
#  u'Genesis - Good Samaritan Hospital',
#  u'Straub Clinic and Hospital',
#  u'UCSD Medical Center',
#  u'Northwest Ohio Oncology Center',
#  u'St. Anthony Central Hospital',
#  u'Hematology Oncology Center',
#  u'Center for Cancer and Blood Disorders',
#  u'South Bend Clinic',
#  u'Kansas Masonic Cancer Research Institute at the University of Kansas Medical Center',
#  u'Menorah Medical Center',
#  u"Lacks Cancer Center at Saint Mary's Health Care",
#  u'Group Health Central Hospital',
#  u'Comprehensive Cancer Centers of Nevada',
#  u'Legacy Good Samaritan Hospital & Comprehensive Cancer Center',
#  u'Northwest Cancer Specialists',
#  u'Altru Cancer Center at Altru Hospital',
#  u'Evanston Northwestern Healthcare',
#  u'Curtis and Elizabeth Anderson Cancer Institute at Memorial Health University Medical Center',
#  u'MeritCare Bemidji',
#  u'Lakeland Hospital',
#  u'Southern California Permanente Medical Group',
#  u'Good Samaritan Regional Health Center',
#  u'AIDS Research Consortium of Atlanta',
#  u'AnMed Health Cancer Center',
#  u'Lakeland Regional Cancer Care Center - St. Joseph',
#  u"Schneider Children's Hospital",
#  u'Saint James Community Hospital and Cancer Treatment Center',
#  u'University of Tennessee - Knoxville',
#  u'Simmons Cancer Center - Dallas',
#  u'Battle Creek Health System Cancer Care Center',
#  u'NYU Cancer Institute at New York University Medical Center',
#  u"Methodist Children's Hospital of South Texas",
#  u'Sanford USD Medical Center - Sioux Falls',
#  u'Iowa Methodist Medical Center',
#  u'Allegiance Health',
#  u'Philadelphia FIGHT',
#  u'Geisinger Cancer Institute at Geisinger Health',
#  u'Kansas City Cancer Centers - North',
#  u'Greenville Health System Cancer Institute-Faris',
#  u'Veterans Affairs Medical Center - Denver',
#  u'Memorial Medical Center',
#  u'Lake University Ireland Cancer Center',
#  u'CCOP - Illinois Oncology Research Association',
#  u'Lombardi Cancer Center',
#  u'Saint Joseph Mercy Port Huron',
#  u'North Memorial Medical Health Center',
#  u'Hopedale Medical Complex',
#  u'Naval Medical Center - San Diego',
#  u'Intermountain Medical Center',
#  u"Driscoll Children's Hospital",
#  u'Tampa General Hospital',
#  u'Regional Cancer Center at Memorial Medical Center',
#  u'Illinois CancerCare - Bloomington',
#  u'Illinois CancerCare-Peru',
#  u'University of Toledo',
#  u'Kaiser Permanente Medical Center - Vallejo',
#  u'Good Samaritan Cancer Center at Good Samaritan Hospital',
#  u'Butterworth Hospital at Spectrum Health',
#  u"St. Luke's Hospital",
#  u"Miller Children's Hospital",
#  u'Forsyth Medical Center',
#  u'Mercy Medical Center - Des Moines',
#  u'John B. Amos Cancer Center',
#  u'Memorial Sloan-Kettering Cancer Center at Phelps Memorial Hospital Center',
#  u'Keesler Medical Center - Keesler AFB',
#  u'Nebraska Methodist Hospital',
#  u'AnMed Cancer Center',
#  u'Illinois CancerCare - Macomb',
#  u'Miami Valley Hospital',
#  u'Illinois CancerCare - Canton',
#  u'State University of New York Health Sciences Center - Stony Brook',
#  u'Illinois CancerCare - Eureka',
#  u'Cancer Center of Kansas, PA - Salina',
#  u'Yale New Haven Hospital',
#  u'Veterans Affairs Medical Center - East Orange',
#  u'Sutter Cancer Center',
#  u"St. Louis Children's Hospital",
#  u'Aultman Cancer Center at Aultman Hospital',
#  u'Iowa Lutheran Hospital',
#  u"Saint John's Hospital - Healtheast",
#  u'Duluth Clinic Cancer Center - Duluth',
#  u"Helen DeVos Children's Hospital at Spectrum Health",
#  u'Marshfield Clinic - Wisconsin Rapids Center',
#  u'Hillman Cancer Center at University of Pittsburgh Cancer Institute',
#  u'Veterans Affairs Medical Center - Long Beach',
#  u'Baptist Hospital of Miami',
#  u'Group Health Cooperative',
#  u'National Heart, Lung and Blood Institute (NHLBI)',
#  u'Veterans Affairs Medical Center - Hines (Hines Junior VA Hospital)',
#  u'Michiana Hematology Oncology PC-Mishawaka',
#  u'Advanced Clinical Research Institute',
#  u'Veterans Affairs Medical Center - San Antonio (Murphy)',
#  u'Knox Community Hospital',
#  u"The Toledo Hospital/Toledo Children's Hospital",
#  u'Veterans Affairs Medical Center - Milwaukee (Zablocki)',
#  u'McLean Hospital',
#  u"St. Joseph's Hospital and Medical Center",
#  u'John Theurer Cancer Center at Hackensack University Medical Center',
#  u'Illinois CancerCare-Princeton',
#  u'Gundersen Lutheran Center for Cancer and Blood',
#  u'The Hospital of Central Connecticut',
#  u'Illinois CancerCare-Pekin',
#  u'Mercy Hospital Cancer Center - Scranton',
#  u'University of Colorado Cancer Center',
#  u'Memorial Hospital Cancer Center',
#  u'Cancer Care Associates-Yale',
#  u'Texas Tech University Health Science Center',
#  u'Delaware County Memorial Hospital',
#  u'St. Francis Hospital',
#  u'Illinois CancerCare - Monmouth',
#  u'Illinois CancerCare - Carthage',
#  u'Olympic Hematology and Oncology',
#  u'Wichita CCOP',
#  u'Baptist Cancer Institute - Jacksonville',
#  u'St. Joseph Hospital',
#  u'Veterans Affairs Medical Center - Minneapolis',
#  u'Illinois CancerCare-Kewanee Clinic',
#  u'New York Methodist Hospital',
#  u'Cleveland Clinic Cancer Center/Fairview Hospital',
#  u'Lucille P. Markey Cancer Center at University of Kentucky',
#  u'Maimonides Medical Center',
#  u'Oncare Hawaii Inc-POB II',
#  u'Rockefeller University Hospital',
#  u'Saint Jude Midwest Affiliate',
#  u"Children's Medical Center of Dallas",
#  u"Children's Hospital and Medical Center of Omaha",
#  u'Cleveland Clinic Florida',
#  u'Kapiolani Medical Center at Pali Momi',
#  u'Lakeland Regional Cancer Center',
#  u'Unity Hospital',
#  u'St. Joseph Cancer Center',
#  u"St. Luke's Medical Center",
#  u"Saint Peter's University Hospital",
#  u'MBCCOP - Gulf Coast',
#  u'Valley Hospital',
#  u'Alta Bates Summit Medical Center - Summit Campus',
#  u'Cooper University Hospital',
#  u'David Geffen School of Medicine at UCLA',
#  u'Univ. of Hawaii at Manoa, Leahi Hosp.',
#  u'Cancer Resource Center - Lincoln',
#  u'Bronx Lebanon Hosp Ctr',
#  u'SUNY Stony Brook NICHD CRS',
#  u'Illinois CancerCare - Community Cancer Center',
#  u'Texas Tech University Health Sciences Center School of Medicine',
#  u'Saint Francis/Mount Sinai Regional Cancer Center at Saint Francis Hospital and Medical Center',
#  u'Evergreen Hematology and Oncology, PS',
#  u'Houston Methodist Hospital',
#  u'Hematology Oncology Associates - Skokie',
#  u'CCOP - Geisinger Clinic and Medical Center',
#  u'Michiana Hematology Oncology PC-South Bend',
#  u'Cancer Centers of the Carolinas-Greer Medical Oncology',
#  u'Cancer Center of Albany Medical Center',
#  u'University of California, Irvine',
#  u'Michiana Hematology Oncology-PC Westville',
#  u'McDowell Cancer Center at Akron General Medical Center',
#  u'Monmouth Medical Center',
#  u'Kettering Medical Center',
#  u"Saint Luke's East - Lee's Summit",
#  u'Hope Cancer Care Center at Longmont United Hospital',
#  u'Columbia Hospital',
#  u'Veterans Affairs Medical Center - Lexington',
#  u'Alta Bates Summit Comprehensive Cancer Center',
#  u'Barrow Neurological Institute',
#  u'Joe Arrington Cancer Research and Treatment Center',
#  u'Akron City Hospital',
#  u'Southwest Washington Medical Center Cancer Center',
#  u'Michiana Hematology Oncology PC-Plymouth',
#  u'Michiana Hematology Oncology PC-Elkhart',
#  u'Advocate Lutheran General Cancer Care Center',
#  u"Mount Carmel St. Ann's Cancer Center",
#  u'Wilford Hall Medical Center',
#  u'El Camino Hospital',
#  u'CCOP - Syracuse Hematology-Oncology Associates of Central New York, P.C.',
#  u'Lutheran General Cancer Care Center',
#  u'Gabrail Cancer Center',
#  u'Minneapolis VA Medical Center',
#  u"Ann & Robert H. Lurie Children's Hospital of Chicago",
#  u'Georgia Regents University',
#  u'Methodist Hosp of Indiana / Life Care Clinic',
#  u'Saint Patrick Hospital - Community Hospital',
#  u'Metro Health Hospital',
#  u'Coborn Cancer Center',
#  u'Providence St. Peter Hospital Regional Cancer Center',
#  u'Advocate Christ Medical Center',
#  u'New York Presbyterian Hospital',
#  u'Harrison Poulsbo Hematology and Onocology',
#  u'Spartanburg Regional Medical Center',
#  u'Novartis Pharmaceuticals',
#  u'Harrington Cancer Center',
#  u'CCOP - Missouri Valley Cancer Consortium',
#  u'Tyler Cancer Center',
#  u"Saint Anthony's Hospital at Saint Anthony's Health Center",
#  u'Fox Chase Cancer Center at Virtua Memorial Hospital of Burlington County',
#  u"Chicago Children's CRS",
#  u'Sharp Memorial Hospital',
#  u'Illinois CancerCare - Havana',
#  u'Yale Comprehensive Cancer Center',
#  u'Compass Research, LLC',
#  u'Mount Nittany Medical Center',
#  u"Children's Hospital of Alabama",
#  u'National Institute of Allergy and Infectious Diseases (NIAID)',
#  u'Hematology Oncology Associates of the Quad Cities',
#  u"St. Mary's Regional Cancer Center at St. Mary's Hospital and Medical Center",
#  u'Illinois CancerCare - Spring Valley',
#  u'Doctors Medical Center - San Pablo Campus',
#  u'Veterans Affairs Medical Center - Kansas City',
#  u'Pennsylvania Hospital',
#  u'Louis A. Weiss Memorial Hospital',
#  u'New York Weill Cornell Cancer Center at Cornell University',
#  u'Highland General Hospital',
#  u'Kaiser Permanente Medical Center - Hayward',
#  u'Unc Aids Crs',
#  u'Allenmore Hospital',
#  u'Roger Maris Cancer Center',
#  u"Penn State Hershey Children's Hospital",
#  u'Geisinger Wyoming Valley',
#  u'Rice Memorial Hospital',
#  u'Saint Joseph Regional Medical Center',
#  u'Roger Williams Medical Center/BUSM',
#  u'North Shore Oncology and Hematology Associates, Limited - Libertyville',
#  u'Mercy Health Partners-Mercy Campus',
#  u'New Hampshire Oncology - Hematology, PA - Hooksett',
#  u'MBCCOP - Medical College of Georgia Cancer Center',
#  u"Saint Ann's Hospital",
#  u"Aurora St. Luke's Medical Center",
#  u'Genesys Regional Medical Center',
#  u'Univ of Colorado Health Sciences Ctr',
#  u'Iredell Memorial Hospital',
#  u'Holy Family Medical Center',
#  u"Children's Hospital Medical Center - Cincinnati",
#  u'St. Clare Hospital',
#  u"David C. Pratt Cancer Center at St. John's Mercy",
#  u'Sentara Norfolk General Hospital',
#  u"Covenant Children's Hospital",
#  u'Cancer Care Centers of South Texas',
#  u'UNC Chapel Hill',
#  u'Heartland Hematology and Oncology Associates Incorporated',
#  u'Gwinnett Medical Center',
#  u'Jacksonville Center for Clinical Research',
#  u'CCOP - Dayton',
#  u'Community Cancer Center',
#  u'St. Joseph Hospital Regional Cancer Center - Orange',
#  u"Akron Children's Hospital",
#  u'Legacy Mount Hood Medical Center',
#  u'Franklin Square Hospital Center',
#  u"Marshfield Clinic Cancer Care at Saint Michael's Hospital",
#  u'South Carolina Oncology Associates',
#  u'Hinsdale Hematology Oncology Associates',
#  u'The West Clinic',
#  u"Blank Children's Hospital",
#  u'NY Univ. HIV/AIDS CRS',
#  u'Santa Clara Valley Medical Center',
#  u'Harrison Bremerton Hematology and Oncology',
#  u'Highland Hospital of Rochester',
#  u'Veterans Affairs Medical Center - Indianapolis (Roudebush)',
#  u'McKay-Dee Hospital Center',
#  u'Yakima Valley Memorial Hospital',
#  u'Maine Center for Cancer Medicine and Blood Disorders - Scarborough',
#  u'Veterans Affairs Medical Center - Shreveport',
#  u'UMDNJ - Robert Wood Johnson University Hospital',
#  u'Thompson Cancer Survival Center',
#  u'Atlanta VA Medical Center',
#  u'Hahnemann University Hospital',
#  u'Dayton CCOP',
#  u'Sylvester Cancer Center, University of Miami',
#  u'Veterans Affairs Medical Center - Atlanta (Decatur)',
#  u'Univ of California / San Diego Treatment Ctr',
#  u'UMDNJ University Hospital',
#  u'Veterans Affairs Medical Center - Seattle',
#  u'Providence Centralia Hospital',
#  u"St. Luke's Episcopal Hospital",
#  u'Medical Center of Central Georgia',
#  u"St. Mary's - Duluth Clinic Cancer Center",
#  u'McLeod Regional Medical Center',
#  u'Mercy General Hospital',
#  u'Fox Chase Virtua Health Cancer Program at Virtua Memorial Hospital Marlton',
#  u'University of Tennessee Cancer Institute',
#  u'Northwest Cancer Specialists at Rose Quarter Cancer Center',
#  u'Sanford Medical Center-Fargo',
#  u'MeritCare Broadway',
#  u'Veterans Affairs Medical Center - Jackson',
#  u'Veterans Affairs Medical Center - San Francisco',
#  u'Good Samaritan Hospital',
#  u'Albert Einstein Comprehensive Cancer Center',
#  u'Denver Health Medical Center',
#  u'Paoli Memorial Hospital',
#  u'Hawaii Medical Center - East',
#  u'Rockwood Clinic',
#  u'Orlando Immunology Center',
#  u'Ozark Health Ventures LLC dba Cancer Research for The Ozarks Springfield',
#  u'Veterans Affairs Medical Center - Cincinnati',
#  u'Veterans Affairs Medical Center - Portland',
#  u'Benefis Healthcare- Sletten Cancer Institute',
#  u"Saint Joseph's Hospital",
#  u'Meeker County Memorial Hospital',
#  u'Veterans Affairs Medical Center - Detroit',
#  u'UCLA CARE Center CRS',
#  u"Saint Mary's Hospital and Regional Medical Center",
#  u'Summa Akron City Hospital/Cooper Cancer Center',
#  u'DermResearch, Inc.',
#  u'Markey Cancer Center at University of Kentucky Chandler Medical Center',
#  u"Advocate Hope Children's Hospital",
#  u'Michigan State University',
#  u'Deaconess Billings Clinic - Downtown',
#  u"Queen's Medical Center",
#  u'Floating Hospital for Children',
#  u'Green Bay Oncology - Iron Mountain',
#  u'Elliot Regional Cancer Center',
#  u'Contra Costa Regional Medical Center',
#  u'Kaiser Permanente Medical Center - Roseville',
#  u'Nevada Cancer Institute',
#  u'Minneapolis Heart Institute',
#  u'Harlem Hosp Ctr',
#  u'Genesys Regional Medical Center-West Flint Campus',
#  u'Veterans Affairs Medical Center - Buffalo',
#  u'Meharry Medical College',
#  u"Brigham and Women's Hospital",
#  u'Southern Regional Medical Center',
#  u'Mountainview Medical',
#  u'Oklahoma Medical Research Foundation',
#  u'Monter Cancer Center',
#  u"Boston Children's Hospital",
#  u'Veterans Affairs Medical Center - Albuquerque',
#  u"Saint Joseph Children's Hospital of Tampa",
#  u'Deaconess Medical Center',
#  u'Veterans Affairs Medical Center - Ann Arbor',
#  u'Southern Ohio Medical Center',
#  u'University of Alabama Comprehensive Cancer Center',
#  u'Penrose-Saint Francis Healthcare',
#  u'Illinois CancerCare-Ottawa Clinic',
#  u'Highlands Oncology Group Dept of Highlands Oncology Grp',
#  u'Saint Nicholas Hospital',
#  u'Trinity Cancer Care Center',
#  u'Bay Area Breast Surgeons Inc',
#  u'Saint Joseph Oncology Inc',
#  u'Texas Oncology Cancer Center',
#  u'Atlanta Gastroenterology Associates',
#  u'Glendale Memorial Hospital and Health Center',
#  u'The Medical Center of Aurora',
#  u'Ucsf Aids Crs',
#  u"Nemours Children's Clinic - Pensacola",
#  u'Cleveland Clinic - Wooster',
#  u'Baylor University Medical Center - Houston',
#  u'Cornell University',
#  u'Memorial Hospital of Rhode Island',
#  u'Kaiser Permanente Medical Center - Walnut Creek',
#  u'Kaiser Permanente Medical Center - Santa Teresa',
#  u'Integrated Community Oncology Network',
#  u'Tom K Lee Inc',
#  u'Oklahoma University Medical Center',
#  u'Peninsula Regional Medical Center',
#  u'Veterans Affairs Medical Center - Oklahoma City',
#  u'Washington Cancer Institute at Washington Hospital Center',
#  u'Chattanooga Oncology Hematology Associates',
#  u'Cancer Centers of the Carolinas - Seneca',
#  u'Hunterdon Regional Cancer Center at Hunterdon Medical Center',
#  u'Sioux Valley Hospital and University of South Dakota Medical Center',
#  u'USC CRS',
#  u'Cape Cod Hospital',
#  u'Joslin Diabetes Center',
#  u'Veterans Affairs Medical Center - Salt Lake City',
#  u'Sandra L. Maxwell Cancer Center',
#  ...]

# %%
dupes['cluster'].value_counts()
# Out:
# 6802     2868
# 7732     2379
# 9843     2024
# 13902    2019
# 6732     1965
# 7190     1952
# 8166     1942
# 11078    1923
# 10481    1810
# 11820    1738
# 5420     1717
# 7631     1690
# 946      1558
# 181      1556
# 5423     1480
# ...
# 4227     2
# 11131    2
# 11129    2
# 11128    2
# 11127    2
# 11117    2
# 4237     2
# 4238     2
# 11115    2
# 4240     2
# 11110    2
# 4243     2
# 11106    2
# 11098    2
# 11500    2
# Length: 15110, dtype: int64

# %%
dupes.cluster.nunique()
# Out:
# 15110

# %%
for n in dupes[dupes.cluster == 6732].facility_name.value_counts().index: print n
# Out:
# Johns Hopkins University
# Johns Hopkins Hospital
# Johns Hopkins University School of Medicine
# Johns Hopkins Oncology Center
# Johns Hopkins Hosp
# Johns Hopkins Bayview Medical Center
# Johns Hopkins
# Johns Hopkins University-Sidney Kimmel Cancer Center
# The Johns Hopkins Hospital
# Johns Hopkins School of Medicine
# Johns Hopkins Medical Institutions
# Johns Hopkins Hosp - Pediatric
# John Hopkins University
# Johns Hopkins Hosp. & Health System - Dept. of Peds., Div. of Infectious Diseases
# Johns Hopkins Medical Center
# Johns Hopkins Bloomberg School of Public Health
# The Johns Hopkins University
# Johns Hopkins University (BPRU) Bayview Campus
# Johns Hopkins Medical Institute
# Johns Hopkins Univ. Baltimore NICHD CRS
# Johns Hopkins School of Public Health
# Johns Hopkins University Medical Center
# Johns Hopkins Univ
# Johns Hopkins University Hospital
# Johns Hopkins Univ School of Medicine
# Johns Hopkins Bayview Medical Center - Infectious Diseases
# John Hopkins Hospital
# John Hopkins Medical Center
# Johns Hopkins University NICHD CRS (5092)
# John Hopkins
# Johns Hopkins Medical Institution
# Johns Hopkins Bloomberg School of Public Health,Ctr for Immunization Research,Project SAVE-Baltimore
# Johns Hopkins Medicine
# The Johns Hopkins Bayview Headache Center
# Johns Hopkins University, Bloomberg School of Public Health
# Johns Hopkins University Bayview Medical Center
# Johns Hopkins Hosp / SOCA
# The Johns Hopkins University School of Medicine
# Johns Hopkins University School of Nursing
# Johns Hopkins University CRS
# Johns Hopkins Bayview
# Johns Hopkins Bayview Campus
# Johns Hopkins University Bloomberg School of Public Health
# John Hopkins Bayview Medical Center
# Johns Hopkins Bayview Medical Campus
# The John Hopkins Hospital
# Johns Hopkins University - IMPAACT Site
# BPRU, Johns Hopkins Bayview Medical Center
# Johns Hopkins Hospital School of Medicine
# Johns Hopkins University School Of Medicine
# Johns Hopkins Bayview Medicial Center, Inpatient Unit
# Johns Hopkins Hospital Pediatric Emergency Department
# John Hopkins Bloomberg School of Public Health
# Johns Hopkins Medical Institutes
# Johns Hopkins School Of Medicine
# Johns Hopkins Center for Viral Hepatits
# Johns Hopkins University - Division of Rheumatology
# John Hopkins Children's Hospital
# Johns Hopkins Eastern Campus
# Bloomberg School of Public Health
# Johns Hopkins Bayview Medical Center, CIR Unit at the Mason F Lord Building
# John Hopkins University Medical Center
# Johns Hopkins Hospital, Adult Epilepsy Center
# Johns Hopkins ALIVE Clinic
# Johns Hopkins University, School of Medicine
# Johns Hopkins University, The Clinical Trials Unit
# John Hopkins University Hospital
# The Johns Hopkins University School of Medicne
# The Johns Hopkins Bayview Medical Center
# The Johns Hopkins Medical Institutions
# Johns Hopkins University - Sidney Kimmel Comprehensive Cancer Center
# Johns Hopkins Wound Center
# Johns Hopkins Bayview Medical Center, Clinical Studies Program
# John's Hopkins University School of Medicine
# John's Hopkins Medical Institute
# John's Hopkins University
# John Hopkins Hospital, Dept. of Neurology
# Johns Hopkins Hospital - Medicine - Infectious Diseases
# Johns Hopkins University Geriatrics Center
# Johns Hopkins School of Medicine/General Clinical Research Center
# Johns Hopkins University Wilmer Eye Institute
# Johns Hopkins University, Bayview Medical Center
# Johns Hopkins MS Center
# Johns Hopkins Univ / School of Hygiene & Public Health
# Johns Hopkins University Hospital Dept.ofJohnsHopkinsHospital
# Johns Hopkins University - Sidney Kimmel Cancer Center
# Johns Hopkins Hospital Multiple Sclerosis Center
# Johns Hopkins School of Medicine Bayview Campus
# Johns Hopkins University Brady Urological Institute
# Johns Hopkins Hospital, Division of Pain Management
# Johns Hopkins Bayview Clinical Research Unit
# Johns Hopkins University/Bayview Medical Center
# Johns Hopkins University, SKCCC
# Johns Hopkins Harriet Lane Clinic
# Johns Hopkins University Drug Development Unit
# Johns Hopkins University, Department of Medicine
# Johns Hopkins Bloomberg School of Public Health, Ctr. for Immunization Research, Project SAVE-DC
# The Johns Hopkins Lupus Center
# Johns Hopkins Medical
# The Johns Hopkins University School of Medicine, The Sidney Kimmel Comprehensive Cancer Center
# Johns Hopkins University Clinical Trials Unit
# Johns Hopkins University Pediatric Emergency Medicine
# Johns Hopkins University Division Of Rheumatology
# Johns Hopkins-Bayview Medical Center
# The Johns Hopkins University, School of Medicine
# Johns Hopkins Medical Institute/Johns Hopkins Hospital
# John Hopkins Hospital/Wilmer Eye Institute
# Johns Hopkins Bayview Hospital
# Johns Hopkins University School of Medicine/Bayview Medical Center
# Johns Hopkins Bayview Medical Center/General Clinical Research Center
# Johns Hopkins Health Sytstem
# Johns Hopkins Bayview Medical Center; Johns Hopkins Hospital
# Johns Hopkins - Bayview Medical Center
# Johns Hopkins, Harriet Lane Clinic
# The John's Hopkins University
# Johns Hopkins University, Division of Clinical Pharmacology, Drug Development Unit
# Johns Hopkins University School of Medicine, Outpatient General Clinical Research Center
# Johns Hopkins Hospital GCRC
# Johns Hopkins University/Sidney Kimmel Comprehensive Cancer Center (SKCCC)
# Johns Hopkins University, Dept of Neurology
# Johns Hopkins School of Medicine / Wilmer Eye Institute
# Johns Hopkins Parkinson's Disease and Movement Disorder Center
# Johns Hopkins Hospital - Wilmer Eye Institute
# Johns Hopkins Bayview Medical Center, Center for Addiction and Pregnancy
# Johns Hopkins Hospital, Dept. of Rheumatology
# Johns Hopkins Hospital, Blalcok 5 MRI
# Johns Hopkins University Division of Rheumatology
# Johns Hopkins School of Public Health 615 N. Wolfe St Room: E2537
# Johns Hopkins Univ Clinical Pharmacology
# Johns Hopkins University, Division of Pediatric Dermatolgy
# The Johns Hopkins University School of Medicine Division of Clinical Pharmacology
# Johns Hopkins ALS Clinic
# Johns Hopkins Bayview Medical Center 5510 Nathan Shock Dr, Ste 100
# Johns Hopkins University School of Hygiene and Public Health
# Johns Hopkins University Bayview Medical Campus
# The John Hopkins Universitiy
# Johns Hopkins Oncology Center (M1011)
# Johns Hopkins University School of Medicine, 600 North Wolfe St, CMSC 1102
# Johns Hopkins Bayview Medical Center Center for Chemical Dependence
# Johns Hopkins University- School of Medicine
# Johns Hopkins University, Center for Viral Hepatitis
# Johns Hopkins University School of Medicine Dept.ofJohnsHopkinsUniv.
# Johns Hopkins University (Bayview Campus)
# Johns Hopkins Medical Institution- Dept of Radiology , Division of Nuclear Medicine
# Johns Hopkins Universtiy - Wilmer Ophthamological Institute
# Johns Hopkins OPC - Meyer Bldg
# Johns Hopkins Hospital Medical Intensive Care Unit
# Johns Hopkins Baview Medical
# Johns Hopkins School of Public Health - Wood Clinic
# Johns Hopkins - School of Medicine
# Johns Hopkins University School of Medicine, Dept. of Psychiatry
# Johns Hopkins Health System
# Hopkins Bayview Medical Center
# The Johns Hopkins University School of Medicine Johns Hopkins University
# The John's Hopkins Medical Institute
# Johns Hopkins Hospital Outpatient Center
# The Johns Hopkins School of Hygiene and Public Health
# Johns Hopkins University SKCCC
# Johns Hopkins Bayview Medical Center Campus
# Johns Hopkins Unv., School of Medicine
# Johns Hopkins Pain Center
# The Johns Hopkins SKCCC
# Johns Hopkins School of Medicine - Sidney Kimmel Comprehensive Cancer Center
# Johns Hopkins University, 600 North Wolfe Street, Meyer 2-181
# John Hopkins University School of Medicine
# The Johns Hopkins Institute for Clinical and Translational Research
# Johns Hopkins Sidney Kimmel Cancer Center
# Johns Hopkins University School of Medicine, Johns Hopkins Hospital
# Johns Hopkins Institution, Dept of Radiology and Radiological Science
# Johns Hopkins Bloomberg School of Public Health,Ctr for Immunization Research, Project SAVE-Baltimore
# John Hopkins University (JHU)
# Johns Hopkins University SOM. 1830 East Monument St, Ste 7500
# John Hopkins University School of Medicine, Viral Hepatitis Center
# Johns Hopkins University CF Clinic
# Johns Hopkins Oncology
# Johns Hopkins School of Medicine/General Internal Medicine
# GCRC Johns Hopkins University
# Johns Hopkins Unversity
# John Hopkins University - Tier 2 Site
# Johns Hopkins Universty
# Johns Hopkins University Clinical Trial Unit
# Johns Hopkins University Department of Radiation Oncology and Molecular Radiation Sciences
# Johns Hopkins University, Bloomberg School of Medicine
# Johns Hopkins Bayview Medical Center and Johns Hopkins Hospital
# Johns Hopkins university
# Johns Hopkins University CCOP
# Johns Hopkins Hosp / Dept of Neurology / Meyer 6109
# Johns Hopkins School of Medicine, Dermatology Department
# John Hopkins School of Medicine
# Johns Hopkins University, 1500 Orleans St. 3M South
# Johns Hopkins University School of Medicine The Johns Hopkins Hospital
# The Johns Hopkins Bloomberg School of Public Health
# Johns Hopkins at Bayview
# Johns Hopkins Hospital & School of Medicine, Div. of Gastroenterology & Hepatology
# John's Hopkins
# Johns Hopkins Hopsital
# Johns Hopkins University Harriet Lane Kidney Center, Rubenstein Child Health Bldg
# Johns Hopkins Medical Institutes - Neuroradiology Division
# Johns Hopkins Hospital (Testing Pediatric Patients Age 3 to 19)
# Johns Hopkins University/ Kongwa Trachoma Project
# Johns Hopkins Uninversity
# Johns Hopkins Lupus Center, 1830 East Monument Street, Suite 7500
# Johns Hopkins Unversity School of Medicine
# Johns Hopkins Lupus Center 1830 E Monument Street, Ste 7500
# Johns Hopkins, Lions Vision Center
# The Johns Hopkins hospital
# The Johns Hopkins Institute for Clinical and Translational Research, Adult Outpatient Clinical Research Unit
# Johns Hopkins University, Bayview Campus
# Johns Hopkins University, Meyer 2-147, 600 North Wolfe Street
# The Johs Hopkins Hospital
# John's Hopkins Hospital
# Johns Hopkins University / Johns Hopkins Hospital
# Johns Hopkins Univesity School of Medicine
# Johns Hopkins University School of Nursing, Center for Innovative Care in Aging
# Johns Hopkins Medical Research Institute
# Johns Hopkins University, Department of Neurology, 600 N. Wolfe St, Meyer 6-181
# Johns Hopkins Univ / Brazil
# Johns Hopkins Bayview Meidical Center: Behavioral Medicine Research Laboratory
# Johns Hopkins University Division of Hematology
# Johns Hopkins University, School of Nursing
# Johns Hopkins McKusick- Institute of Genetic Medicine
# Johns Hopkins Bayview Institute for Clinical Translational Research
# John Hopkins Bloomberg School of Public Health - Center for Immunization Research (CIR)
# Johns Hopkins HIV Clinic
# Johns Hopkins University, Department of Neurology
# Johns Hopkins University--Sidney Kimmel Comprehensive Cancer Center
# Johns Hopskins Hospital
# Johns Hopkins Univeristy School of Medicine
# Johns Hopkins Hospital/Health System
# Johns Hopkins University - School of Medicine
# Johns Hopkins Hospital - The Bunting Blaustein Cancer Research Building
# The Johns Hopkins School of Medicine
# John's Hopkins University Medical Center
