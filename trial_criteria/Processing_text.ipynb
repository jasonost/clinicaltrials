# %%
import nltk
import codecs
import string
import random
from collections import Counter
import cPickle as pickle
import re
from copy import deepcopy

from __future__ import division

# %% [markdown]
# ### Load Data

# %%
trial_criteria = {}
predefined_criteria = {}
for row in codecs.open('data/clinical_study.txt','r','utf-8').readlines():
    data = row.split('|')
    trial_criteria[data[0]] = data[26]
    # 27 = gender, 28 = min age, 29 = max age, 30 = Health volunteers
    predefined_criteria[data[0]] = (data[27], data[28], data[29], data[30])

# %% [markdown]
# ### Split Inclusive and Exclusive

# %%
def split_doc_on_exclusion(doc):
    '''This function splits the criteria documents into the Inclusion 
    and Exclusion sections'''
    split_doc = doc.split()
    for idx, word in enumerate(split_doc):
        if word.lower() == u'exclusion' and u'criteria' in split_doc[idx + 1].lower():
            inclusive = ' '.join(split_doc[:idx])
            exclusive =  ' '.join(split_doc[idx:])
            return inclusive, exclusive
    if split_doc[0].lower() == u'inclusion' and u'criteria' in split_doc[1].lower():
        return doc, None

no_inc_exc_dict = {}
trial_criteria_split = {}

for key, doc in trial_criteria.items():
    try:
        inclusive, exclusive = split_doc_on_exclusion(doc)
        if exclusive is None:
            trial_criteria_split[key] = [inclusive]
        else:
            trial_criteria_split[key] = [inclusive, exclusive]
            
    #if there are not inclusion/exclusion
    except:
         no_inc_exc_dict[key] = doc

# %%
len(trial_criteria_split)
# Out:
# 152877

# %%
#save ram
del trial_criteria

# %% [markdown]
# ### ~10,000 trials did not have an inclusive exclusive split

# %%
len(no_inc_exc_dict)
# Out:
# 10887

# %%
len(trial_criteria)
# Out:
# 163764

# %% [markdown]
# ### Save Files

# %%
#save to pickle
pickle.dump(predefined_criteria, open('data/predefined_criteria.pkl', 'wb'))
pickle.dump(trial_criteria, open('data/trial_criteria.pkl', 'wb'))
pickle.dump(trial_criteria_split, open('data/trial_criteria_split.pkl', 'wb'))
pickle.dump(no_inc_exc_dict, open('data/no_inc_exc_dict.pkl', 'wb'))

# %% [markdown]
# ### Load Data From Pickle

# %%
trial_criteria = pickle.load(open('data/trial_criteria.pkl', 'rb'))

# %%
trial_criteria_split = pickle.load(open('data/trial_criteria_split.pkl', 'rb'))

# %% [markdown]
# Create interactive information extraction system
#
# list of sysnonyms, predictors, and throw out as options
#
# pull unigram, bigrams, trigams (exclude those that only have stop words and punctuation)
#
# need to get sentences, tokens, pos tag
#
# keep inclusion vs exclusion distinction

# %% [markdown]
# ### Initial Concept Term Lists

# %%
smoker_list = ['Non-smoker', 'smoker', 'Current smoker', 'smoking', 'tobacco', 'nicotine',
               'cigarettes']
pregnancy_list = ['Pregnancy']
birth_control_list = ['Birth control', 'contraception']
drug_list = ['Illicit drugs', 'Alcohol abuse', 'illegal', 'illicit', 'drug abuse']
heart_failure_list = ['Congestive Heart Failure', 'heart failure']
hiv_list = ['HIV', 'aids', 'human immunodeficiency virus']
allergy_list = ['Allergies', 'allergy', 'hypersensitivity']

# %% [markdown]
# ### Inital Predictive Terms

# %%
smoker_pred_list = ['current']
pregnancy_pred_list = ['potential', 'negative']
birth_control_pred_list = ['effective', 'Fertile patients', 'must use effective',
                           'must use', 'use effective', 'Fertile patients must use',
                           'fertile']
drug_pred_list = ['use', 'abuse']
heart_failure_pred_list = []
hiv_pred_list = []
allergy_pred_list = ['known', 'history', 'suspected', 'known suspected',
                     'clinically significant']

# %%
trial_criteria_split_test = deepcopy(dict(trial_criteria_split.items()[:3]))

# %% [markdown]
# ### Process Text

# %%
def process_text(text_dict):
    #break sentences on '-' for each subdoc of each document
    for key, doc in text_dict.items():
        for n in xrange(len(doc)):
            text_dict[key][n] = re.split(' - ', text_dict[key][n])


    #get sentence tokenizer
    sent_tokenizer=nltk.data.load('tokenizers/punkt/english.pickle')

    #run the sentence tokenizer over all the documents
    def sent_token(text):
        sentence_groups = []
        for sent_group in text:
            group_holder = []
            for sent in sent_group:
                group_holder += (sent_tokenizer.tokenize(sent))
            sentence_groups.append(group_holder)
            del group_holder
        return sentence_groups

    #run sentence tokenizer over each doc in the dict
    for key, doc in text_dict.items():
        text_dict[key] = sent_token(doc)



    #CREATING TOKENS

    #patter for tokenizing
    pattern = r'''(?x)    # set flag to allow verbose regexps
            ([A-Z]\.)+        # abbreviations, e.g. U.S.A
            | \w+([-‘]\w+)*        # words with optional internal hyphens
            | \$?\d+(\.\d+)?%?  # currency and percentages, e.g. $12.40, 82%
            | \.\.\.            # ellipsis...   
            | [][.,;"'?():\-_`]+  # these are separate tokens
            '''



    for key, doc in text_dict.items():
        for n in xrange(len(doc)):
            text_dict[key][n] = [nltk.regexp_tokenize(sent, pattern) for sent
                                             in doc[n]]
    return text_dict

# %%
result = process_text(trial_criteria_split_test)

# %% [markdown]
# ### Save Tokenized Text

# %%
pickle.dump(result, open('data/trial_criteria_split_token.pkl', 'wb'))

# %% [markdown]
# ### Load Tokenized Text

# %%
trial_criteria_split_token = pickle.load(open('data/trial_criteria_split_token.pkl', 'rb'))

# %% [markdown]
# ### POS Tag Tokens

# %%
def pos_tag(text_dict):
    #tag document structured criteria text
    def doc_tagger_pos(text):
        result = []
        for doc in text:
            doc_text = []
            for sent in doc:
                doc_text.append(nltk.pos_tag(sent))
            result.append(doc_text)
        return result
    
    for key, doc in text_dict.items():
        text_dict[key] = doc_tagger_pos(doc)
        
    return text_dict
    
result_pos = pos_tag(result)

# %%
result
# Out:
# {u'NCT00370032': [[[(u'Inclusion', 'NN'), (u'criteria', 'VBD'), (u':', ':')],
#    [(u'The', 'DT'),
#     (u'subject', 'NN'),
#     (u'signs', 'NNS'),
#     (u'and', 'CC'),
#     (u'dates', 'NNS'),
#     (u'a', 'DT'),
#     (u'written', 'VBN'),
#     (u'informed', 'VBN'),
#     (u'consent', 'NN'),
#     (u'form', 'NN'),
#     (u'prior', 'RB'),
#     (u'to', 'TO'),
#     (u'the', 'DT'),
#     (u'initiation', 'NN'),
#     (u'of', 'IN'),
#     (u'any', 'DT'),
#     (u'study-related', 'JJ'),
#     (u'activities', 'NNS'),
#     (u'.', '.')],
#    [(u'The', 'DT'),
#     (u'subject', 'NN'),
#     (u'is', 'VBZ'),
#     (u'between', 'IN'),
#     (u'18', 'CD'),
#     (u'and', 'CC'),
#     (u'49', 'CD'),
#     (u'years', 'NNS'),
#     (u'of', 'IN'),
#     (u'age', 'NN'),
#     (u'at', 'IN'),
#     (u'the', 'DT'),
#     (u'time', 'NN'),
#     (u'of', 'IN'),
#     (u'the', 'DT'),
#     (u'Screening', 'NNP'),
#     (u'Visit', 'NNP'),
#     (u'.', '.')],
#    [(u'The', 'DT'),
#     (u'subject', 'NN'),
#     (u'is', 'VBZ'),
#     (u'female', 'JJ'),
#     (u'and', 'CC'),
#     (u'either', 'DT'),
#     (u':', ':')],
#    [(u'A', 'DT'), (u'healthy', 'JJ'), (u'subject', 'NN'), (u'.', '.')],
#    [(u'Healthy', 'NNP'),
#     (u'subjects', 'NNS'),
#     (u'are', 'VBP'),
#     (u'defined', 'VBN'),
#     (u'as', 'IN'),
#     (u'individuals', 'NNS'),
#     (u'who', 'WP'),
#     (u'are', 'VBP'),
#     (u'free', 'JJ'),
#     (u'from', 'IN'),
#     (u'clinically', 'RB'),
#     (u'significant', 'JJ'),
#     (u'illness', 'NN'),
#     (u'or', 'CC'),
#     (u'disease', 'NN'),
#     (u'as', 'IN'),
#     (u'determined', 'VBN'),
#     (u'by', 'IN'),
#     (u'their', 'PRP$'),
#     (u'medical', 'JJ'),
#     (u'history', 'NN'),
#     (u'(', ':'),
#     (u'including', 'VBG'),
#     (u'family', 'NN'),
#     (u'),', ':'),
#     (u'physical', 'JJ'),
#     (u'examination', 'NN'),
#     (u',', ','),
#     (u'laboratory', 'NN'),
#     (u'studies', 'NNS'),
#     (u',', ','),
#     (u'and', 'CC'),
#     (u'other', 'JJ'),
#     (u'tests', 'NNS'),
#     (u'.', '.')],
#    [(u'OR', 'CC')],
#    [(u'A', 'DT'),
#     (u'd-IBS', 'JJ'),
#     (u'patient', 'NN'),
#     (u'per', 'IN'),
#     (u'the', 'DT'),
#     (u'Rome', 'NNP'),
#     (u'II', 'NNP'),
#     (u'criteria', 'NN'),
#     (u'who', 'WP'),
#     (u'has', 'VBZ'),
#     (u'a', 'DT'),
#     (u'normal', 'JJ'),
#     (u'result', 'NN'),
#     (u'from', 'IN'),
#     (u'a', 'DT'),
#     (u'flexible', 'JJ'),
#     (u'sigmoidoscopy', 'NN'),
#     (u'or', 'CC'),
#     (u'colonoscopy', 'NN'),
#     (u',', ','),
#     (u'or', 'CC'),
#     (u'flexible', 'JJ'),
#     (u'sigmoidoscopy', 'NN'),
#     (u'plus', 'CC'),
#     (u'barium', 'NN'),
#     (u'enema', 'NN'),
#     (u',', ','),
#     (u'within', 'IN'),
#     (u'2', 'CD'),
#     (u'years', 'NNS'),
#     (u'of', 'IN'),
#     (u'the', 'DT'),
#     (u'Screening', 'NNP'),
#     (u'visit', 'NN'),
#     (u'.', '.')],
#    [(u'The', 'DT'),
#     (u'subject', 'NN'),
#     (u'demonstrates', 'VBZ'),
#     (u'a', 'DT'),
#     (u'negative', 'JJ'),
#     (u'urine', 'NN'),
#     (u'pregnancy', 'NN'),
#     (u'test', 'NN'),
#     (u'result', 'NN'),
#     (u'prior', 'RB'),
#     (u'to', 'TO'),
#     (u'investigational', 'JJ'),
#     (u'product', 'NN'),
#     (u'administration', 'NN'),
#     (u'and', 'CC'),
#     (u'be', 'VB'),
#     (u'either', 'DT'),
#     (u':', ':')],
#    [(u'Of', 'IN'),
#     (u'non-childbearing', 'JJ'),
#     (u'potential', 'NN'),
#     (u'(', ':'),
#     (u'i', 'PRP'),
#     (u'.', '.'),
#     (u'e', 'NN'),
#     (u'.,', ':'),
#     (u'physiologically', 'RB'),
#     (u'incapable', 'JJ'),
#     (u'of', 'IN'),
#     (u'becoming', 'VBG'),
#     (u'pregnant', 'JJ'),
#     (u')', 'NN')],
#    [(u'post-menopausal', 'JJ'),
#     (u'define', 'NN'),
#     (u'as', 'IN'),
#     (u'one', 'CD'),
#     (u'year', 'NN'),
#     (u'without', 'IN'),
#     (u'menses', 'NNS'),
#     (u'in', 'IN'),
#     (u'the', 'DT'),
#     (u'absence', 'NN'),
#     (u'of', 'IN'),
#     (u'hormone', 'NN'),
#     (u'replacement', 'NN'),
#     (u'therapy', 'NN'),
#     (u'.', '.')],
#    [(u'sterilization', 'NN'),
#     (u'(', '``'),
#     (u'via', 'IN'),
#     (u'hysterectomy', 'NN'),
#     (u'or', 'CC'),
#     (u'bilateral', 'JJ'),
#     (u'tubal', 'JJ'),
#     (u'ligation', 'NN'),
#     (u')', ':')],
#    [(u'Of', 'IN'),
#     (u'childbearing', 'VBG'),
#     (u'potential', 'JJ'),
#     (u'and', 'CC'),
#     (u'agrees', 'NNS'),
#     (u'to', 'TO'),
#     (u'one', 'CD'),
#     (u'of', 'IN'),
#     (u'the', 'DT'),
#     (u'following', 'JJ'),
#     (u'acceptable', 'JJ'),
#     (u'non-hormonal', 'JJ'),
#     (u'contraceptive', 'JJ'),
#     (u'methods', 'NNS'),
#     (u'consistently', 'RB'),
#     (u'and', 'CC'),
#     (u'in', 'IN'),
#     (u'accordance', 'NN'),
#     (u'with', 'IN'),
#     (u'both', 'DT'),
#     (u'the', 'DT'),
#     (u'product', 'NN'),
#     (u'label', 'NN'),
#     (u'and', 'CC'),
#     (u'the', 'DT'),
#     (u'instructions', 'NNS'),
#     (u'of', 'IN'),
#     (u'a', 'DT'),
#     (u'physician', 'JJ'),
#     (u'.', '.')],
#    [(u'Subjects', 'NNS'),
#     (u'will', 'MD'),
#     (u'use', 'VB'),
#     (u'effective', 'JJ'),
#     (u'contraceptive', 'JJ'),
#     (u'methods', 'NNS'),
#     (u'for', 'IN'),
#     (u'at', 'IN'),
#     (u'least', 'JJS'),
#     (u'one', 'CD'),
#     (u'month', 'NN'),
#     (u'prior', 'RB'),
#     (u'to', 'TO'),
#     (u'Screening', 'NNP'),
#     (u'and', 'CC'),
#     (u'should', 'MD'),
#     (u'continue', 'VB'),
#     (u'to', 'TO'),
#     (u'use', 'VB'),
#     (u'the', 'DT'),
#     (u'same', 'JJ'),
#     (u'contraceptive', 'JJ'),
#     (u'method', 'NN'),
#     (u'throughout', 'IN'),
#     (u'the', 'DT'),
#     (u'study', 'NN'),
#     (u'(', ':'),
#     (u'Follow-up', 'JJ'),
#     (u'Visit', 'NN'),
#     (u').', ':')],
#    [(u'Complete', 'NNP'),
#     (u'abstinence', 'NN'),
#     (u'from', 'IN'),
#     (u'intercourse', 'NN')],
#    [(u'an', 'DT'),
#     (u'intra-uterine', 'JJ'),
#     (u'device', 'NN'),
#     (u'(', ':'),
#     (u'IUD', 'NNP'),
#     (u')', ':'),
#     (u'inserted', 'VBD'),
#     (u'by', 'IN'),
#     (u'a', 'DT'),
#     (u'qualified', 'JJ'),
#     (u'physician', 'NN'),
#     (u',', ','),
#     (u'provided', 'VBN'),
#     (u'the', 'DT'),
#     (u'IUD', 'NNP'),
#     (u'is', 'VBZ'),
#     (u'not', 'RB'),
#     (u'of', 'IN'),
#     (u'the', 'DT'),
#     (u'hormonal', 'JJ'),
#     (u'type', 'NN'),
#     (u'and', 'CC'),
#     (u'it', 'PRP'),
#     (u'has', 'VBZ'),
#     (u'published', 'VBN'),
#     (u'data', 'NNS'),
#     (u'showing', 'VBG'),
#     (u'that', 'IN'),
#     (u'the', 'DT'),
#     (u'highest', 'JJS'),
#     (u'expected', 'VBN'),
#     (u'failure', 'NN'),
#     (u'rate', 'NN'),
#     (u'is', 'VBZ'),
#     (u'less', 'JJR'),
#     (u'than', 'IN'),
#     (u'1', 'CD'),
#     (u'per', 'IN'),
#     (u'year', 'NN'),
#     (u'(', ':'),
#     (u'not', 'RB'),
#     (u'all', 'DT'),
#     (u'IUDs', 'NNP'),
#     (u'meet', 'NN'),
#     (u'this', 'DT'),
#     (u'criterion', 'NN'),
#     (u')', ':')],
#    [(u'double', 'JJ'),
#     (u'barrier', 'NN'),
#     (u'method', 'NN'),
#     (u'if', 'IN'),
#     (u'comprised', 'VBN'),
#     (u'of', 'IN'),
#     (u'a', 'DT'),
#     (u'spermicide', 'NN'),
#     (u'with', 'IN'),
#     (u'either', 'DT'),
#     (u'a', 'DT'),
#     (u'condom', 'NN'),
#     (u'or', 'CC'),
#     (u'diaphragm', 'NN')],
#    [(u'sterilization', 'NN'),
#     (u'of', 'IN'),
#     (u'partner', 'NN'),
#     (u'The', 'DT'),
#     (u'subject', 'NN'),
#     (u'is', 'VBZ'),
#     (u'ambulatory', 'NN'),
#     (u'(', ':'),
#     (u'defined', 'VBN'),
#     (u'as', 'IN'),
#     (u'not', 'RB'),
#     (u'depending', 'VBG'),
#     (u'exclusively', 'RB'),
#     (u'on', 'IN'),
#     (u'a', 'DT'),
#     (u'wheelchair', 'NN'),
#     (u'for', 'IN'),
#     (u'mobility', 'NN'),
#     (u').', ':')]],
#   [[(u'Exclusion', 'NN'), (u'criteria', 'VBD'), (u':', ':')],
#    [(u'The', 'DT'),
#     (u'subject', 'NN'),
#     (u'is', 'VBZ'),
#     (u'taking', 'VBG'),
#     (u'oral', 'JJ'),
#     (u'contraceptive', 'JJ'),
#     (u'or', 'CC'),
#     (u'other', 'JJ'),
#     (u'hormonal', 'JJ'),
#     (u'therapy', 'NN'),
#     (u'.', '.')],
#    [(u'The', 'DT'),
#     (u'subject', 'NN'),
#     (u'has', 'VBZ'),
#     (u'a', 'DT'),
#     (u'concurrent', 'NN'),
#     (u'illness', 'NN'),
#     (u'or', 'CC'),
#     (u'disability', 'NN'),
#     (u'that', 'IN'),
#     (u'may', 'MD'),
#     (u'affect', 'VB'),
#     (u'the', 'DT'),
#     (u'interpretation', 'NN'),
#     (u'of', 'IN'),
#     (u'clinical', 'JJ'),
#     (u'data', 'NNS'),
#     (u',', ','),
#     (u'or', 'CC'),
#     (u'otherwise', 'RB'),
#     (u'contraindicates', 'VBZ'),
#     (u'participation', 'NN'),
#     (u'in', 'IN'),
#     (u'this', 'DT'),
#     (u'clinical', 'JJ'),
#     (u'study', 'NN'),
#     (u'(', ':'),
#     (u'e', 'NN'),
#     (u'.', '.'),
#     (u'g', 'NN'),
#     (u'.,', ':'),
#     (u'an', 'DT'),
#     (u'unstable', 'JJ'),
#     (u'cardiovascular', 'NN'),
#     (u',', ','),
#     (u'autoimmune', 'NN'),
#     (u',', ','),
#     (u'renal', 'JJ'),
#     (u',', ','),
#     (u'hepatic', 'JJ'),
#     (u',', ','),
#     (u'pulmonary', 'JJ'),
#     (u',', ','),
#     (u'endocrine', 'NN'),
#     (u',', ','),
#     (u'metabolic', 'JJ'),
#     (u',', ','),
#     (u'gastrointestinal', 'JJ'),
#     (u',', ','),
#     (u'hematologic', 'JJ'),
#     (u',', ','),
#     (u'or', 'CC'),
#     (u'neurological', 'JJ'),
#     (u'condition', 'NN'),
#     (u').', ':')],
#    [(u'The', 'DT'),
#     (u'subject', 'NN'),
#     (u'has', 'VBZ'),
#     (u'constipation-predominant', 'JJ'),
#     (u'IBS', 'NNP'),
#     (u'(', 'NNP'),
#     (u'c-IBS', 'NNP'),
#     (u')', 'NNP'),
#     (u'or', 'CC'),
#     (u'alternating', 'VBG'),
#     (u'IBS', 'NNP'),
#     (u'per', 'IN'),
#     (u'the', 'DT'),
#     (u'ROME', 'NNP'),
#     (u'II', 'NNP'),
#     (u'criteria', 'NN'),
#     (u'.', '.')],
#    [(u'The', 'DT'),
#     (u'subject', 'NN'),
#     (u'has', 'VBZ'),
#     (u'current', 'JJ'),
#     (u'evidence', 'NN'),
#     (u'of', 'IN'),
#     (u'or', 'CC'),
#     (u'history', 'NN'),
#     (u'of', 'IN'),
#     (u'chronic', 'JJ'),
#     (u'or', 'CC'),
#     (u'severe', 'JJ'),
#     (u'constipation', 'NN'),
#     (u',', ','),
#     (u'or', 'CC'),
#     (u'a', 'DT'),
#     (u'history', 'NN'),
#     (u'of', 'IN'),
#     (u'sequelae', 'NN'),
#     (u'from', 'IN'),
#     (u'constipation', 'NN'),
#     (u'.', '.')],
#    [(u'Evidence', 'NN'),
#     (u'of', 'IN'),
#     (u'a', 'DT'),
#     (u'biochemical', 'JJ'),
#     (u'or', 'CC'),
#     (u'structural', 'JJ'),
#     (u'abnormality', 'NN'),
#     (u'of', 'IN'),
#     (u'the', 'DT'),
#     (u'digestive', 'JJ'),
#     (u'tract', 'NN'),
#     (u'.', '.')],
#    [(u'These', 'DT'),
#     (u'conditions', 'NNS'),
#     (u'include', 'VBP'),
#     (u'(', ':'),
#     (u'but', 'CC'),
#     (u'not', 'RB'),
#     (u'limited', 'VBN'),
#     (u'to', 'TO'),
#     (u'):', ':')],
#    [(u'Current', 'JJ'),
#     (u'evidence', 'NN'),
#     (u',', ','),
#     (u'or', 'CC'),
#     (u'history', 'NN'),
#     (u'of', 'IN'),
#     (u'(', 'NNP'),
#     (u'at', 'IN'),
#     (u'any', 'DT'),
#     (u'time', 'NN'),
#     (u'in', 'IN'),
#     (u'the', 'DT'),
#     (u'past', 'JJ'),
#     (u'):', ':')],
#    [(u'GI', 'NNP'), (u'Bowel', 'NNP'), (u'conditions', 'NNS'), (u':', ':')],
#    [(u'inflammatory', 'NN'),
#     (u'bowel', 'NN'),
#     (u'disease', 'NN'),
#     (u'(', ':'),
#     (u'Crohn', 'NNP'),
#     (u"'", 'POS'),
#     (u's', 'NNS'),
#     (u'disease', 'NN'),
#     (u'or', 'CC'),
#     (u'ulcerative', 'JJ'),
#     (u'colitis', 'NNS'),
#     (u')', ':')],
#    [(u'celiac', 'NN'), (u'disease', 'NN')],
#    [(u'laxative', 'JJ'),
#     (u'abuse', 'NN'),
#     (u'(', ':'),
#     (u'in', 'IN'),
#     (u'the', 'DT'),
#     (u'clinical', 'JJ'),
#     (u'judgement', 'NN'),
#     (u'of', 'IN'),
#     (u'the', 'DT'),
#     (u'physician', 'JJ'),
#     (u')', 'NN')],
#    [(u'gastrointestinal', 'JJ'),
#     (u'surgery', 'NN'),
#     (u'(', ':'),
#     (u'exceptions', 'NNS'),
#     (u'include', 'VBP'),
#     (u'6', 'CD'),
#     (u'months', 'NNS'),
#     (u'post-surgery', 'JJ'),
#     (u'appendectomy', 'NN'),
#     (u',', ','),
#     (u'cholecystectomy', 'NN'),
#     (u',', ','),
#     (u'fundoplication', 'NN'),
#     (u'without', 'IN'),
#     (u'gas', 'NN'),
#     (u'bloat', 'IN'),
#     (u',', ','),
#     (u'or', 'CC'),
#     (u'hiatal', 'JJ'),
#     (u'hernia', 'NN'),
#     (u'repair', 'NN'),
#     (u';', ':'),
#     (u'3', 'CD'),
#     (u'months', 'NNS'),
#     (u'post-surgery', 'JJ'),
#     (u'herniorrhaphy', 'NN'),
#     (u'without', 'IN'),
#     (u'bowel', 'NN'),
#     (u'resection', 'NN'),
#     (u')', ':')],
#    [(u'gastroparesis', 'NN')],
#    [(u'GI', 'NNP'), (u'malignancy', 'NN')],
#    [(u'carcinoid', 'VBD'), (u'syndrome', 'VBN')],
#    [(u'amyloidosis', 'NN')],
#    [(u'gastrointestinal', 'JJ'), (u'adhesions', 'NNS')],
#    [(u'ischemic', 'JJ'), (u'colitis', 'NNS')],
#    [(u'toxic', 'JJ'), (u'megacolon', 'NN')],
#    [(u'impaired', 'VBD'), (u'intestinal', 'JJ'), (u'circulation', 'NN')],
#    [(u'gastrointestinal', 'JJ'), (u'perforation', 'NN')],
#    [(u'gastrointestinal', 'JJ'),
#     (u'obstruction', 'NN'),
#     (u'and', 'CC'),
#     (u'or', 'CC'),
#     (u'stricture', 'NN')],
#    [(u'Ischemic', 'JJ'),
#     (u'cardiovascular', 'NN'),
#     (u'conditions', 'NNS'),
#     (u':', ':')],
#    [(u'coronary', 'JJ'),
#     (u'artery', 'NN'),
#     (u'disease', 'NN'),
#     (u'(', ':'),
#     (u'CAD', 'NNP'),
#     (u')', ':')],
#    [(u'significant', 'JJ'), (u'atherosclerosis', 'NN')],
#    [(u'chronic', 'JJ'), (u'pancreatitis', 'NNS')],
#    [(u'diabetes', 'NNS')],
#    [(u'thrombophlebitis', 'NNS'),
#     (u'or', 'CC'),
#     (u'hypercoagulable', 'JJ'),
#     (u'state', 'NN'),
#     (u'.', '.')],
#    [(u'Current', 'JJ'),
#     (u'evidence', 'NN'),
#     (u'of', 'IN'),
#     (u'(', 'NNP'),
#     (u'within', 'IN'),
#     (u'the', 'DT'),
#     (u'past', 'JJ'),
#     (u'6', 'CD'),
#     (u'months', 'NNS'),
#     (u'):', ':')],
#    [(u'diverticulitis', 'NNS')],
#    [(u'ileus', 'NN')],
#    [(u'symptomatic', 'JJ'), (u'cholelithiasis', 'NN')],
#    [(u'proctitis', 'NNS'), (u'.', '.')],
#    [(u'Current', 'JJ'), (u'evidence', 'NN'), (u'of', 'IN'), (u':', ':')],
#    [(u'Hemoccult', 'NNP'),
#     (u'(', ':'),
#     (u')', ':'),
#     (u'stool', 'NN'),
#     (u'.', '.')],
#    [(u'The', 'DT'),
#     (u'subject', 'NN'),
#     (u'has', 'VBZ'),
#     (u'a', 'DT'),
#     (u'Body', 'NNP'),
#     (u'Mass', 'NNP'),
#     (u'Index', 'NNP'),
#     (u'(', 'NNP'),
#     (u'BMI', 'NNP'),
#     (u')', 'NNP'),
#     (u'of', 'IN'),
#     (u'27', 'CD'),
#     (u'.', '.')],
#    [(u'Mental', 'JJ'),
#     (u'impairment', 'NN'),
#     (u'or', 'CC'),
#     (u'inability', 'NN'),
#     (u'or', 'CC'),
#     (u'refusal', 'NN'),
#     (u'to', 'TO'),
#     (u'follow', 'VB'),
#     (u'directions', 'NNS'),
#     (u'.', '.')],
#    [(u'The', 'DT'),
#     (u'subject', 'NN'),
#     (u'has', 'VBZ'),
#     (u'current', 'JJ'),
#     (u'evidence', 'NN'),
#     (u'of', 'IN'),
#     (u',', ','),
#     (u'or', 'CC'),
#     (u'has', 'VBZ'),
#     (u'been', 'VBN'),
#     (u'treated', 'VBN'),
#     (u'for', 'IN'),
#     (u'a', 'DT'),
#     (u'malignancy', 'NN'),
#     (u'within', 'IN'),
#     (u'the', 'DT'),
#     (u'past', 'JJ'),
#     (u'five', 'CD'),
#     (u'years', 'NNS'),
#     (u'(', ':'),
#     (u'other', 'JJ'),
#     (u'than', 'IN'),
#     (u'localized', 'JJ'),
#     (u'basal', 'NN'),
#     (u'cell', 'NN'),
#     (u',', ','),
#     (u'squamous', 'JJ'),
#     (u'cell', 'NN'),
#     (u'skin', 'NN'),
#     (u'cancer', 'NN'),
#     (u'or', 'CC'),
#     (u'cancer', 'NN'),
#     (u'in', 'IN'),
#     (u'situ', 'NN'),
#     (u'that', 'IN'),
#     (u'has', 'VBZ'),
#     (u'been', 'VBN'),
#     (u'resected', 'VBN'),
#     (u').', 'NNP')],
#    [(u'The', 'DT'),
#     (u'subject', 'NN'),
#     (u'exhibits', 'VBZ'),
#     (u'evidence', 'NN'),
#     (u'of', 'IN'),
#     (u'hepatic', 'JJ'),
#     (u'dysfunction', 'NN'),
#     (u',', ','),
#     (u'viral', 'JJ'),
#     (u'hepatitis', 'NNS'),
#     (u',', ','),
#     (u'or', 'CC'),
#     (u'exhibits', 'NNS'),
#     (u'serum', 'VBP'),
#     (u'ALT', 'NNP'),
#     (u'(', 'NNP'),
#     (u'SGPT', 'NNP'),
#     (u'),', ','),
#     (u'AST', 'NNP'),
#     (u'(', 'NNP'),
#     (u'SGOT', 'NNP'),
#     (u')', 'NNP'),
#     (u'values', 'VBZ'),
#     (u'2', 'CD'),
#     (u'.', '.'),
#     (u'5', 'CD'),
#     (u'times', 'NNS'),
#     (u'the', 'DT'),
#     (u'upper', 'NN'),
#     (u'limit', 'NN'),
#     (u'of', 'IN'),
#     (u'normal', 'JJ'),
#     (u'or', 'CC'),
#     (u'alkaline', 'NN'),
#     (u'phosphatase', 'NN'),
#     (u'or', 'CC'),
#     (u'bilirubin', 'NN'),
#     (u'values', 'NNS'),
#     (u'2', 'CD'),
#     (u'.', '.'),
#     (u'0', '-NONE-'),
#     (u'times', 'VBZ'),
#     (u'the', 'DT'),
#     (u'upper', 'NN'),
#     (u'limit', 'NN'),
#     (u'of', 'IN'),
#     (u'normal', 'JJ'),
#     (u'.', '.')],
#    [(u'The', 'DT'),
#     (u'subject', 'NN'),
#     (u'displays', 'VBZ'),
#     (u'renal', 'JJ'),
#     (u'impairment', 'NN'),
#     (u'as', 'IN'),
#     (u'evidenced', 'VBN'),
#     (u'by', 'IN'),
#     (u'a', 'DT'),
#     (u'serum', 'NN'),
#     (u'creatinine', 'NN'),
#     (u'value', 'NN'),
#     (u'2', 'CD'),
#     (u'.', '.'),
#     (u'0', '-NONE-'),
#     (u'mg', 'NN'),
#     (u'dl', 'NN'),
#     (u'.', '.')],
#    [(u'The', 'DT'),
#     (u'subject', 'NN'),
#     (u'has', 'VBZ'),
#     (u'used', 'VBN'),
#     (u'any', 'DT'),
#     (u'medication', 'NN'),
#     (u'within', 'IN'),
#     (u'the', 'DT'),
#     (u'seven', 'CD'),
#     (u'days', 'NNS'),
#     (u'prior', 'RB'),
#     (u'to', 'TO'),
#     (u'dosing', 'NN'),
#     (u',', ','),
#     (u'unless', 'IN'),
#     (u'approved', 'VBN'),
#     (u'by', 'IN'),
#     (u'the', 'DT'),
#     (u'investigator', 'NN'),
#     (u'and', 'CC'),
#     (u'GSK', 'NNP'),
#     (u'personnel', 'NN'),
#     (u'.', '.')],
#    [(u'Section', 'NN'), (u'9', 'CD'), (u'.', '.'), (u'1', 'CD'), (u'.', '.')],
#    [(u'The', 'DT'),
#     (u'subject', 'NN'),
#     (u'has', 'VBZ'),
#     (u'used', 'VBN'),
#     (u'an', 'DT'),
#     (u'investigational', 'JJ'),
#     (u'drug', 'NN'),
#     (u',', ','),
#     (u'or', 'CC'),
#     (u'participated', 'VBN'),
#     (u'in', 'IN'),
#     (u'an', 'DT'),
#     (u'investigational', 'JJ'),
#     (u'study', 'NN'),
#     (u',', ','),
#     (u'within', 'IN'),
#     (u'30', 'CD'),
#     (u'days', 'NNS'),
#     (u'of', 'IN'),
#     (u'the', 'DT'),
#     (u'Screening', 'NNP'),
#     (u'Visit', 'NNP'),
#     (u'.', '.')],
#    [(u'The', 'DT'),
#     (u'subject', 'NN'),
#     (u'has', 'VBZ'),
#     (u'a', 'DT'),
#     (u'history', 'NN'),
#     (u'of', 'IN'),
#     (u'drug', 'NN'),
#     (u'allergies', 'NNS'),
#     (u'(', ':'),
#     (u'including', 'VBG'),
#     (u'but', 'CC'),
#     (u'not', 'RB'),
#     (u'limited', 'VBN'),
#     (u'to', 'TO'),
#     (u'hypersensitivity', 'NN'),
#     (u'responses', 'NNS'),
#     (u'to', 'TO'),
#     (u'alosetron', 'VB'),
#     (u'which', 'WDT'),
#     (u',', ','),
#     (u'in', 'IN'),
#     (u'the', 'DT'),
#     (u'opinion', 'NN'),
#     (u'of', 'IN'),
#     (u'the', 'DT'),
#     (u'investigator', 'NN'),
#     (u',', ','),
#     (u'contraindicates', 'VBZ'),
#     (u'the', 'DT'),
#     (u'subject', 'NN'),
#     (u"'", 'POS'),
#     (u's', 'NNS'),
#     (u'participation', 'NN'),
#     (u'in', 'IN'),
#     (u'this', 'DT'),
#     (u'study', 'NN'),
#     (u'.', '.')],
#    [(u'Subjects', 'NNS'),
#     (u'who', 'WP'),
#     (u'have', 'VBP'),
#     (u'made', 'VBN'),
#     (u'a', 'DT'),
#     (u'blood', 'NN'),
#     (u'donation', 'NN'),
#     (u'(', ':'),
#     (u'450mL', 'CD'),
#     (u')', 'CD'),
#     (u'within', 'IN'),
#     (u'6', 'CD'),
#     (u'weeks', 'NNS'),
#     (u'prior', 'RB'),
#     (u'to', 'TO'),
#     (u'screening', 'NN'),
#     (u'.', '.')],
#    [(u'The', 'DT'),
#     (u'subject', 'NN'),
#     (u'has', 'VBZ'),
#     (u'a', 'DT'),
#     (u'history', 'NN'),
#     (u'of', 'IN'),
#     (u'alcohol', 'NN'),
#     (u'and', 'CC'),
#     (u'or', 'CC'),
#     (u'substance', 'NN'),
#     (u'abuse', 'NN'),
#     (u'within', 'IN'),
#     (u'the', 'DT'),
#     (u'past', 'JJ'),
#     (u'two', 'CD'),
#     (u'years', 'NNS'),
#     (u'.', '.')],
#    [(u'The', 'DT'),
#     (u'subject', 'NN'),
#     (u'is', 'VBZ'),
#     (u'pregnant', 'JJ'),
#     (u'.', '.')],
#    [(u'The', 'DT'),
#     (u'subject', 'NN'),
#     (u'is', 'VBZ'),
#     (u'breastfeeding', 'VBG'),
#     (u'.', '.')]]],
#  u'NCT00499928': [[[(u'Inclusion', 'NN'), (u'Criteria', 'NNP'), (u':', ':')],
#    [(u'Healthy', 'NNP'),
#     (u'adult', 'VBD'),
#     (u'males', 'NNS'),
#     (u'of', 'IN'),
#     (u'age', 'NN'),
#     (u'35', 'CD'),
#     (u'to', 'TO'),
#     (u'65', 'CD'),
#     (u'years', 'NNS'),
#     (u',', ','),
#     (u'inclusive', 'JJ'),
#     (u',', ','),
#     (u'or', 'CC'),
#     (u'healthy', 'JJ'),
#     (u'ambulatory', 'NN'),
#     (u'postmenopausal', 'NN'),
#     (u'women', 'NNS'),
#     (u'defined', 'VBD'),
#     (u'as', 'IN'),
#     (u'being', 'VBG'),
#     (u'amenorrheic', 'JJ'),
#     (u'for', 'IN'),
#     (u'at', 'IN'),
#     (u'least', 'JJS'),
#     (u'2', 'CD'),
#     (u'years', 'NNS'),
#     (u'and', 'CC'),
#     (u'40', 'CD'),
#     (u'to', 'TO'),
#     (u'65', 'CD'),
#     (u'years', 'NNS'),
#     (u'of', 'IN'),
#     (u'age', 'NN'),
#     (u',', ','),
#     (u'inclusive', 'JJ'),
#     (u',', ','),
#     (u'at', 'IN'),
#     (u'screening', 'NN'),
#     (u'with', 'IN'),
#     (u'FSH', 'NNP'),
#     (u'levels', 'NNS'),
#     (u'consistent', 'VBP'),
#     (u'with', 'IN'),
#     (u'menopause', 'NN'),
#     (u'.', '.')],
#    [(u'Healthy', 'NNP'),
#     (u'postmenopausal', 'NN'),
#     (u'women', 'NNS'),
#     (u',', ','),
#     (u'who', 'WP'),
#     (u'are', 'VBP'),
#     (u'between', 'IN'),
#     (u'ages', 'NNS'),
#     (u'40', 'CD'),
#     (u'to', 'TO'),
#     (u'50', 'CD'),
#     (u'years', 'NNS'),
#     (u',', ','),
#     (u'inclusive', 'JJ'),
#     (u',', ','),
#     (u'must', 'MD'),
#     (u'also', 'RB'),
#     (u'have', 'VB'),
#     (u'a', 'DT'),
#     (u'documented', 'VBN'),
#     (u'history', 'NN'),
#     (u'of', 'IN'),
#     (u'bilateral', 'JJ'),
#     (u'oophorectomy', 'NN'),
#     (u'(', ':'),
#     (u'with', 'IN'),
#     (u'or', 'CC'),
#     (u'without', 'IN'),
#     (u'hysterectomy', 'NN'),
#     (u')', ':'),
#     (u'and', 'CC'),
#     (u'be', 'VB'),
#     (u'at', 'IN'),
#     (u'least', 'JJS'),
#     (u'6', 'CD'),
#     (u'weeks', 'NNS'),
#     (u'post-surgery', 'JJ'),
#     (u'.)', 'NN')],
#    [(u'Non-smokers', 'NNS')],
#    [(u'Body', 'NNP'),
#     (u'weight', 'VBD'),
#     (u'or', 'CC'),
#     (u'50', 'CD'),
#     (u'kg', 'NN'),
#     (u'and', 'CC'),
#     (u'BMI', 'NNP'),
#     (u'within', 'IN'),
#     (u'the', 'DT'),
#     (u'range', 'NN'),
#     (u'19', 'CD')],
#    [(u'32', 'CD'), (u'kg', 'NN'), (u'm2', 'NNP')],
#    [(u'A', 'DT'),
#     (u'history', 'NN'),
#     (u'of', 'IN'),
#     (u'regular', 'JJ'),
#     (u'bowel', 'NN'),
#     (u'movements', 'NNS')],
#    [(u'Capable', 'JJ'),
#     (u'of', 'IN'),
#     (u'giving', 'VBG'),
#     (u'written', 'VBN'),
#     (u'informed', 'VBN'),
#     (u'consent', 'NN')]],
#   [[(u'Exclusion', 'NN'), (u'Criteria', 'NNP'), (u':', ':')],
#    [(u'Any', 'DT'),
#     (u'clinically', 'RB'),
#     (u'relevant', 'JJ'),
#     (u'biological', 'JJ'),
#     (u'or', 'CC'),
#     (u'physical', 'JJ'),
#     (u'abnormality', 'NN'),
#     (u'found', 'VBD'),
#     (u'or', 'CC'),
#     (u'reported', 'VBN'),
#     (u'at', 'IN'),
#     (u'screening', 'NN'),
#     (u'which', 'WDT'),
#     (u',', ','),
#     (u'in', 'IN'),
#     (u'the', 'DT'),
#     (u'opinion', 'NN'),
#     (u'of', 'IN'),
#     (u'the', 'DT'),
#     (u'investigator', 'NN'),
#     (u',', ','),
#     (u'is', 'VBZ'),
#     (u'clinically', 'RB'),
#     (u'significant', 'JJ'),
#     (u'and', 'CC'),
#     (u'would', 'MD'),
#     (u'preclude', 'VB'),
#     (u'safe', 'JJ'),
#     (u'participation', 'NN'),
#     (u'in', 'IN'),
#     (u'this', 'DT'),
#     (u'study', 'NN')],
#    [(u'QTc', 'NNP'),
#     (u'interval', 'NN'),
#     (u'of', 'IN'),
#     (u'450', 'CD'),
#     (u'msec', 'NN'),
#     (u'at', 'IN'),
#     (u'screening', 'NN')],
#    [(u'Positive', 'JJ'),
#     (u'urine', 'NN'),
#     (u'drug', 'NN'),
#     (u'screen', 'NN'),
#     (u'at', 'IN'),
#     (u'screening', 'NN')],
#    [(u'Positive', 'JJ'),
#     (u'urine', 'NN'),
#     (u'test', 'NN'),
#     (u'for', 'IN'),
#     (u'alcohol', 'NN'),
#     (u'at', 'IN'),
#     (u'pre-dose', 'JJ')],
#    [(u'Positive', 'JJ'),
#     (u'for', 'IN'),
#     (u'HIV', 'NNP'),
#     (u'at', 'IN'),
#     (u'screening', 'VBG')],
#    [(u'Chronic', 'NNP'),
#     (u'hepatitis', 'VBZ'),
#     (u'B', 'NNP'),
#     (u'and', 'CC'),
#     (u'C', 'NNP'),
#     (u',', ','),
#     (u'as', 'IN'),
#     (u'evidenced', 'VBN'),
#     (u'by', 'IN'),
#     (u'positive', 'JJ'),
#     (u'Hepatitis', 'NNP'),
#     (u'B', 'NNP'),
#     (u'surface', 'NN'),
#     (u'antigen', 'NN'),
#     (u'or', 'CC'),
#     (u'Hepatitis', 'NNP'),
#     (u'C', 'NNP'),
#     (u'antibody', 'NN')],
#    [(u'Urinary', 'NNP'),
#     (u'cotinine', 'NN'),
#     (u'levels', 'NNS'),
#     (u'indicative', 'VBP'),
#     (u'of', 'IN'),
#     (u'smoking', 'NN'),
#     (u'at', 'IN'),
#     (u'screening', 'NN')],
#    [(u'History', 'NN'),
#     (u'of', 'IN'),
#     (u'smoking', 'NN'),
#     (u'or', 'CC'),
#     (u'use', 'VBP'),
#     (u'of', 'IN'),
#     (u'nicotine', 'NN'),
#     (u'containing', 'VBG'),
#     (u'products', 'NNS'),
#     (u'within', 'IN'),
#     (u'one', 'CD'),
#     (u'year', 'NN'),
#     (u'of', 'IN'),
#     (u'the', 'DT'),
#     (u'study', 'NN'),
#     (u'or', 'CC'),
#     (u'10', 'CD'),
#     (u'pack-year', 'JJ'),
#     (u'history', 'NN'),
#     (u'of', 'IN'),
#     (u'smoking', 'NN'),
#     (u'overall', 'JJ')],
#    [(u'History', 'NN'),
#     (u'of', 'IN'),
#     (u'regular', 'JJ'),
#     (u'alcohol', 'NN'),
#     (u'consumption', 'NN'),
#     (u'exceeding', 'VBG'),
#     (u'7', 'CD'),
#     (u'units', 'NNS'),
#     (u'week', 'NN'),
#     (u'for', 'IN'),
#     (u'women', 'NNS'),
#     (u'and', 'CC'),
#     (u'14', 'CD'),
#     (u'units', 'NNS'),
#     (u'week', 'NN'),
#     (u'for', 'IN'),
#     (u'men', 'NNS'),
#     (u'within', 'IN'),
#     (u'6', 'CD'),
#     (u'months', 'NNS'),
#     (u'of', 'IN'),
#     (u'screening', 'VBG')],
#    [(u'History', 'NN'),
#     (u'of', 'IN'),
#     (u'drug', 'NN'),
#     (u'abuse', 'NN'),
#     (u'within', 'IN'),
#     (u'6', 'CD'),
#     (u'months', 'NNS'),
#     (u'of', 'IN'),
#     (u'the', 'DT'),
#     (u'study', 'NN')],
#    [(u'Participation', 'NN'),
#     (u'in', 'IN'),
#     (u'a', 'DT'),
#     (u'clinical', 'JJ'),
#     (u'study', 'NN'),
#     (u'and', 'CC'),
#     (u'received', 'VBD'),
#     (u'a', 'DT'),
#     (u'drug', 'NN'),
#     (u'or', 'CC'),
#     (u'a', 'DT'),
#     (u'new', 'JJ'),
#     (u'chemical', 'NN'),
#     (u'entity', 'NN'),
#     (u'with', 'IN'),
#     (u'30', 'CD'),
#     (u'days', 'NNS'),
#     (u'or', 'CC'),
#     (u'5', 'CD'),
#     (u'half-lives', 'NNS'),
#     (u',', ','),
#     (u'or', 'CC'),
#     (u'twice', 'NN'),
#     (u'the', 'DT'),
#     (u'duration', 'NN'),
#     (u'of', 'IN'),
#     (u'the', 'DT'),
#     (u'biological', 'JJ'),
#     (u'effect', 'NN'),
#     (u'of', 'IN'),
#     (u'any', 'DT'),
#     (u'drug', 'NN'),
#     (u'prior', 'RB'),
#     (u'to', 'TO'),
#     (u'the', 'DT'),
#     (u'first', 'JJ'),
#     (u'dose', 'NN'),
#     (u'of', 'IN'),
#     (u'the', 'DT'),
#     (u'current', 'JJ'),
#     (u'study', 'NN'),
#     (u'medication', 'NN')],
#    [(u'Exposure', 'NN'),
#     (u'to', 'TO'),
#     (u'more', 'JJR'),
#     (u'than', 'IN'),
#     (u'four', 'CD'),
#     (u'new', 'JJ'),
#     (u'chemical', 'JJ'),
#     (u'entities', 'NNS'),
#     (u'within', 'IN'),
#     (u'12', 'CD'),
#     (u'months', 'NNS'),
#     (u'prior', 'RB'),
#     (u'to', 'TO'),
#     (u'the', 'DT'),
#     (u'first', 'JJ'),
#     (u'dosing', 'NN'),
#     (u'day', 'NN')],
#    [(u'Subjects', 'NNS'),
#     (u'who', 'WP'),
#     (u'have', 'VBP'),
#     (u'received', 'VBN'),
#     (u'a', 'DT'),
#     (u'total', 'JJ'),
#     (u'body', 'NN'),
#     (u'radiation', 'NN'),
#     (u'dose', 'NN'),
#     (u'of', 'IN'),
#     (u'greater', 'JJR'),
#     (u'than', 'IN'),
#     (u'5', 'CD'),
#     (u'.', '.'),
#     (u'0', '-NONE-'),
#     (u'mSv', 'NNP'),
#     (u'or', 'CC'),
#     (u'exposure', 'NN'),
#     (u'to', 'TO'),
#     (u'significant', 'JJ'),
#     (u'radiation', 'NN'),
#     (u'in', 'IN'),
#     (u'the', 'DT'),
#     (u'12', 'CD'),
#     (u'months', 'NNS'),
#     (u'prior', 'RB'),
#     (u'to', 'TO'),
#     (u'this', 'DT'),
#     (u'study', 'NN')],
#    [(u'Radiation', 'NN'),
#     (u'exposure', 'NN'),
#     (u'from', 'IN'),
#     (u'the', 'DT'),
#     (u'previous', 'JJ'),
#     (u'3', 'CD'),
#     (u'year', 'NN'),
#     (u'period', 'NN'),
#     (u'is', 'VBZ'),
#     (u'over', 'IN'),
#     (u'10', 'CD'),
#     (u'mSv', 'NNP'),
#     (u'for', 'IN'),
#     (u'subjects', 'NNS'),
#     (u'who', 'WP'),
#     (u'have', 'VBP'),
#     (u'been', 'VBN'),
#     (u'exposed', 'VBN'),
#     (u'to', 'TO'),
#     (u'ionizing', 'NN'),
#     (u'radiation', 'NN'),
#     (u'above', 'IN'),
#     (u'background', 'NN'),
#     (u'as', 'IN'),
#     (u'a', 'DT'),
#     (u'result', 'NN'),
#     (u'of', 'IN'),
#     (u'their', 'PRP$'),
#     (u'work', 'NN'),
#     (u'with', 'IN'),
#     (u'radiation', 'NN'),
#     (u'as', 'IN'),
#     (u'category', 'NN'),
#     (u'A', 'DT'),
#     (u'workers', 'NNS'),
#     (u'or', 'CC'),
#     (u'as', 'IN'),
#     (u'a', 'DT'),
#     (u'result', 'NN'),
#     (u'of', 'IN'),
#     (u'research', 'NN'),
#     (u'studies', 'NNS'),
#     (u'they', 'PRP'),
#     (u'may', 'MD'),
#     (u'have', 'VB'),
#     (u'been', 'VBN'),
#     (u'involved', 'VBN'),
#     (u'in', 'IN'),
#     (u'.', '.')],
#    [(u'Clinical', 'JJ'),
#     (u'exposure', 'NN'),
#     (u'will', 'MD'),
#     (u'not', 'RB'),
#     (u'be', 'VB'),
#     (u'included', 'VBN')],
#    [(u'Condition', 'NN'),
#     (u'that', 'IN'),
#     (u'could', 'MD'),
#     (u'interfere', 'VB'),
#     (u'with', 'IN'),
#     (u'the', 'DT'),
#     (u'accurate', 'JJ'),
#     (u'assessment', 'NN'),
#     (u'and', 'CC'),
#     (u'recovery', 'NN'),
#     (u'of', 'IN'),
#     (u'radiocarbon', 'NN'),
#     (u'[', ':'),
#     (u'14C', 'CD'),
#     (u']', 'CD')],
#    [(u'Use', 'NN'),
#     (u'of', 'IN'),
#     (u'prescription', 'NN'),
#     (u'or', 'CC'),
#     (u'nonprescription', 'NN'),
#     (u'drugs', 'NNS'),
#     (u'including', 'VBG'),
#     (u'antacids', 'NNS'),
#     (u',', ','),
#     (u'including', 'VBG'),
#     (u'vitamins', 'NNS'),
#     (u',', ','),
#     (u'herbal', 'JJ'),
#     (u'and', 'CC'),
#     (u'dietary', 'JJ'),
#     (u'supplements', 'NNS'),
#     (u'within', 'IN'),
#     (u'7', 'CD'),
#     (u'days', 'NNS'),
#     (u'prior', 'RB'),
#     (u'to', 'TO'),
#     (u'the', 'DT'),
#     (u'first', 'JJ'),
#     (u'dose', 'NN'),
#     (u'of', 'IN'),
#     (u'study', 'NN'),
#     (u'medication', 'NN'),
#     (u'.', '.')],
#    [(u'Consumption', 'NN'),
#     (u'of', 'IN'),
#     (u'red', 'VBN'),
#     (u'wine', 'NN'),
#     (u',', ','),
#     (u'grapefruit', 'NN'),
#     (u',', ','),
#     (u'grapefruit', 'NN'),
#     (u'juice', 'NN'),
#     (u'or', 'CC'),
#     (u'grapefruit-containing', 'JJ'),
#     (u'products', 'NNS'),
#     (u'within', 'IN'),
#     (u'14', 'CD'),
#     (u'days', 'NNS'),
#     (u'prior', 'RB'),
#     (u'to', 'TO'),
#     (u'the', 'DT'),
#     (u'first', 'JJ'),
#     (u'dose', 'NN'),
#     (u'of', 'IN'),
#     (u'study', 'NN'),
#     (u'medication', 'NN')],
#    [(u'Donation', 'NN'),
#     (u'of', 'IN'),
#     (u'blood', 'NN'),
#     (u'in', 'IN'),
#     (u'excess', 'NN'),
#     (u'of', 'IN'),
#     (u'500', 'CD'),
#     (u'mL', 'NNP'),
#     (u'within', 'IN'),
#     (u'56', 'CD'),
#     (u'days', 'NNS'),
#     (u'prior', 'RB'),
#     (u'to', 'TO'),
#     (u'dosing', 'NN'),
#     (u'.', '.')],
#    [(u'Evidence', 'NN'),
#     (u'of', 'IN'),
#     (u'renal', 'JJ'),
#     (u',', ','),
#     (u'hepatic', 'JJ'),
#     (u'or', 'CC'),
#     (u'biliary', 'JJ'),
#     (u'impairment', 'NN')],
#    [(u'History', 'NN'),
#     (u'of', 'IN'),
#     (u'serious', 'JJ'),
#     (u'gastrointestinal', 'JJ'),
#     (u'disease', 'NN'),
#     (u'or', 'CC'),
#     (u'history', 'NN'),
#     (u'of', 'IN'),
#     (u'a', 'DT'),
#     (u'gastrointestinal', 'JJ'),
#     (u'surgical', 'JJ'),
#     (u'procedure', 'NN'),
#     (u'that', 'WDT'),
#     (u'might', 'MD'),
#     (u'affect', 'VB'),
#     (u'the', 'DT'),
#     (u'absorption', 'NN'),
#     (u'of', 'IN'),
#     (u'SB-751689', 'NNP')],
#    [(u'History', 'NN'),
#     (u'of', 'IN'),
#     (u'sensitivity', 'NN'),
#     (u'to', 'TO'),
#     (u'any', 'DT'),
#     (u'of', 'IN'),
#     (u'the', 'DT'),
#     (u'study', 'NN'),
#     (u'medications', 'NNS'),
#     (u',', ','),
#     (u'or', 'CC'),
#     (u'components', 'NNS'),
#     (u'thereof', 'IN'),
#     (u'or', 'CC'),
#     (u'a', 'DT'),
#     (u'history', 'NN'),
#     (u'of', 'IN'),
#     (u'drug', 'NN'),
#     (u'or', 'CC'),
#     (u'other', 'JJ'),
#     (u'allergy', 'NN'),
#     (u'that', 'IN'),
#     (u',', ','),
#     (u'in', 'IN'),
#     (u'the', 'DT'),
#     (u'opinion', 'NN'),
#     (u'of', 'IN'),
#     (u'the', 'DT'),
#     (u'physician', 'JJ'),
#     (u'responsible', 'JJ'),
#     (u',', ','),
#     (u'contraindicates', 'VBZ'),
#     (u'their', 'PRP$'),
#     (u'participation', 'NN')],
#    [(u'History', 'NN'),
#     (u'of', 'IN'),
#     (u'clinically', 'RB'),
#     (u'significant', 'JJ'),
#     (u'cardiovascular', 'JJ'),
#     (u'disease', 'NN')],
#    [(u'History', 'NN'),
#     (u'of', 'IN'),
#     (u'pernicious', 'JJ'),
#     (u'anemia', 'NN'),
#     (u',', ','),
#     (u'pancreatitis', 'VBZ'),
#     (u',', ','),
#     (u'osteosarcoma', 'NN'),
#     (u'or', 'CC'),
#     (u'kidney', 'NN'),
#     (u'stones', 'NNS'),
#     (u'.', '.')],
#    [(u'Conditions', 'NNS'),
#     (u'that', 'IN'),
#     (u'might', 'MD'),
#     (u'alter', 'VB'),
#     (u'bone', 'NN'),
#     (u'metabolism', 'NN'),
#     (u',', ','),
#     (u'including', 'VBG'),
#     (u'hyperparathyroidism', 'NN'),
#     (u',', ','),
#     (u'hypoparathyroidism', 'NN'),
#     (u',', ','),
#     (u'hyperthyroidism', 'NN'),
#     (u',', ','),
#     (u'hypothyroidism', 'NN'),
#     (u',', ','),
#     (u'Paget', 'NNP'),
#     (u"'", 'POS'),
#     (u's', 'NNS'),
#     (u'disease', 'NN'),
#     (u',', ','),
#     (u'myeloma', 'NN'),
#     (u',', ','),
#     (u'malabsorption', 'NN'),
#     (u',', ','),
#     (u'or', 'CC'),
#     (u'Cushing', 'NNP'),
#     (u"'", "''"),
#     (u's', 'VBZ'),
#     (u'syndrome', 'NN'),
#     (u',', ','),
#     (u'and', 'CC'),
#     (u'hypogonadism', 'NN'),
#     (u'(', ':'),
#     (u'for', 'IN'),
#     (u'male', 'JJ'),
#     (u'subjects', 'NNS'),
#     (u'),', ':'),
#     (u'hypocalcemia', 'NN'),
#     (u',', ','),
#     (u'hypercalcemia', 'NN'),
#     (u',', ','),
#     (u'hypophosphatemia', 'NN'),
#     (u',', ','),
#     (u'hypomagnesemia', 'NN'),
#     (u',', ','),
#     (u'hypermagnesemia', 'NN'),
#     (u',', ','),
#     (u'osteopetrosis', 'NN'),
#     (u',', ','),
#     (u'osteomalacia', 'NN'),
#     (u',', ','),
#     (u'and', 'CC'),
#     (u'recent', 'JJ'),
#     (u'history', 'NN'),
#     (u'of', 'IN'),
#     (u'fracture', 'NN'),
#     (u'or', 'CC'),
#     (u'prolonged', 'VBN'),
#     (u'bed', 'VBN'),
#     (u'rest', 'NN')],
#    [(u'Liver', 'RB'),
#     (u'function', 'NN'),
#     (u'tests', 'NNS'),
#     (u',', ','),
#     (u'PTH', 'NNP'),
#     (u',', ','),
#     (u'or', 'CC'),
#     (u'CPK', 'NNP'),
#     (u'outside', 'IN'),
#     (u'the', 'DT'),
#     (u'reference', 'NN'),
#     (u'range', 'NN'),
#     (u'at', 'IN'),
#     (u'screening', 'NN')],
#    [(u'Males', 'NNS'),
#     (u'unwilling', 'VBG'),
#     (u'to', 'TO'),
#     (u'refrain', 'VB'),
#     (u'from', 'IN'),
#     (u'fathering', 'VBG'),
#     (u'a', 'DT'),
#     (u'child', 'NN'),
#     (u'during', 'IN'),
#     (u'the', 'DT'),
#     (u'study', 'NN'),
#     (u'and', 'CC'),
#     (u'for', 'IN'),
#     (u'14', 'CD'),
#     (u'days', 'NNS'),
#     (u'after', 'IN')]]],
#  u'NCT00523861': [[[(u'Inclusion', 'NN'), (u'Criteria', 'NNP'), (u':', ':')],
#    [(u'Healthy', 'NNP'),
#     (u'as', 'IN'),
#     (u'assessed', 'VBN'),
#     (u'by', 'IN'),
#     (u'the', 'DT'),
#     (u':', ':')],
#    [(u'physical', 'JJ'), (u'examination', 'NN')],
#    [(u'results', 'NNS'),
#     (u'of', 'IN'),
#     (u'the', 'DT'),
#     (u'pre-study', 'JJ'),
#     (u'laboratory', 'NN'),
#     (u'tests', 'NNS')],
#    [(u'Males', 'NNS'),
#     (u'aged', 'VBD'),
#     (u'between', 'IN'),
#     (u'18', 'CD'),
#     (u'and', 'CC'),
#     (u'40', 'CD'),
#     (u'years', 'NNS'),
#     (u'at', 'IN'),
#     (u'Day', 'NNP'),
#     (u'01', 'CD'),
#     (u'of', 'IN'),
#     (u'the', 'DT'),
#     (u'study', 'NN'),
#     (u'(', ':'),
#     (u'including', 'VBG'),
#     (u'18', 'CD'),
#     (u'and', 'CC'),
#     (u'40', 'CD'),
#     (u')', 'CD')],
#    [(u'Lean', 'JJ'),
#     (u'subjects', 'NNS'),
#     (u'and', 'CC'),
#     (u'overweight', 'VBD'),
#     (u'obese', 'JJ'),
#     (u'subjects', 'NNS'),
#     (u':', ':'),
#     (u'BMI', 'NNP'),
#     (u'18', 'CD'),
#     (u'.', '.'),
#     (u'5-35', 'CD'),
#     (u'kg', 'NN'),
#     (u'm2', 'NNP')],
#    [(u'Alcohol', 'NN'),
#     (u'consumption', 'NN'),
#     (u'between', 'IN'),
#     (u'7', 'CD'),
#     (u'and', 'CC'),
#     (u'28', 'CD'),
#     (u'units', 'NNS'),
#     (u'week', 'NN'),
#     (u'(', ':'),
#     (u'including', 'VBG'),
#     (u'7', 'CD'),
#     (u'and', 'CC'),
#     (u'28', 'CD'),
#     (u')', 'CD')],
#    [(u'Non', 'NNP'),
#     (u'restrained', 'VBD'),
#     (u'eater', 'NN'),
#     (u',', ','),
#     (u'defined', 'VBD'),
#     (u'as', 'IN'),
#     (u'a', 'DT'),
#     (u'score', 'NN'),
#     (u'2', 'CD'),
#     (u'.', '.'),
#     (u'5', 'CD'),
#     (u'on', 'IN'),
#     (u'the', 'DT'),
#     (u'Dutch', 'JJ'),
#     (u'Restrained', 'NNP'),
#     (u'Eating', 'NNP'),
#     (u'Questionnaire', 'NNP')]],
#   [[(u'Exclusion', 'NN'), (u'Criteria', 'NNP'), (u':', ':')],
#    [(u'Smoking', 'VBG')],
#    [(u'Not', 'RB'),
#     (u'willing', 'JJ'),
#     (u'or', 'CC'),
#     (u'able', 'JJ'),
#     (u'to', 'TO'),
#     (u'change', 'VB'),
#     (u'habitual', 'JJ'),
#     (u'alcohol', 'NN'),
#     (u'consumption', 'NN'),
#     (u'during', 'IN'),
#     (u'the', 'DT'),
#     (u'study', 'NN'),
#     (u'according', 'VBG'),
#     (u'to', 'TO'),
#     (u'protocol', 'NN')],
#    [(u'Having', 'VBG'),
#     (u'an', 'DT'),
#     (u'allergy', 'NN'),
#     (u'for', 'IN'),
#     (u'paracetamol', 'NN')]]]}

# %%
#save test corpus
pickle.dump(result,open('data/test_tagged_data.pkl', 'wb'))

# %% [markdown]
# ### Save tagged text

# %%
#save tagged corpus
pickle.save_object(criteria_text_sent_tag,
                   'data/criteria_corpus_pos_tagged.pkl')

# %%
#load tagged corpus
criteria_text_sent_tag = pickle.open_object('data/criteria_corpus_pos_tagged.pkl')
