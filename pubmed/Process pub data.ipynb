# %%
from bs4 import BeautifulSoup
import cPickle as pickle
import time

# %%
#import data for getting investigator mesh dict
invest_mesh_comp = pickle.load(open('data/investigator_mesh.pkl', 'rb'))
investigator_dict = pickle.load(open('data/investigator_dict.pkl', 'rb'))

# %%
#add mesh terms to the investidgator dict
def add_mesh(investigator_dict, invest_mesh_comp):
    id_list = invest_mesh_comp.keys()
    for investigator in investigator_dict:
        investigator_dict[investigator]['mesh'] = []
        for ids in investigator_dict[investigator]['id']:
            #check to make sure there is a matching id in the invest mesh dict
            #there are missing ids that aren't associated with mesh terms
            if ids in id_list:
                investigator_dict[investigator]['mesh'] += invest_mesh_comp[ids]
    return investigator_dict

investigator_dict = add_mesh(investigator_dict, invest_mesh_comp)

# %%
#save investigator mesh dict
pickle.dump(investigator_mesh_dict, open('data/investigator_mesh_dict.pkl','wb'))

# %%
#load in data for processing
data = pickle.load(open('data/investigator_dict_1.pkl', 'rb'))
investigator_mesh_dict = pickle.load(open('data/investigator_mesh_dict.pkl', 'rb'))

# %%
#lowercase all mesh terms
for invest in investigator_mesh_dict:
    investigator_mesh_dict[invest]['mesh'] = [x.lower() for x in investigator_mesh_dict[invest]['mesh']]

# %%
investigator_mesh_dict
# Out:
# {u'"MARIA CRISTINA MEIRA FERREIRA': {'Trials': [u'NCT01813435'],
#   'id': [112484],
#   'mesh': [u'coronary disease',
#    u'coronary artery disease',
#    u'myocardial ischemia']},
#  u"'Aizenberg": {'Trials': [u'NCT01261273'], 'id': [40578], 'mesh': []},
#  u"'Pastayalka": {'Trials': [u'NCT01261273'], 'id': [40228], 'mesh': []},
#  u'. Ira Shafran': {'Trials': [u'NCT01951326'],
#   'id': [134523],
#   'mesh': [u'crohn disease']},
#  u': David Wilber': {'Trials': [u'NCT01635998'],
#   'id': [81672],
#   'mesh': [u'atrial fibrillation', u'hypertension']},
#  u': Gennady M. Galstyan': {'Trials': [u'NCT01849237'],
#   'id': [114299],
#   'mesh': [u'shock',
#    u'anemia, aplastic',
#    u'neutropenia',
#    u'shock, septic',
#    u'anemia']},
#  u': Morris Mosseri': {'Trials': [u'NCT01414439'],
#   'id': [55981],
#   'mesh': [u'heart failure']},
#  u': christine. tranchant': {'Trials': [u'NCT02071459'],
#   'id': [141649],
#   'mesh': [u'atrophy',
#    u'shy-drager syndrome',
#    u'multiple system atrophy',
#    u'hypotension, orthostatic',
#    u'hypotension']},
#  u'A A Akinbami': {'Trials': [u'NCT01704794'],
#   'id': [96010],
#   'mesh': [u'anemia, sickle cell']},
#  u'A Alhasso': {'Trials': [u'NCT00470236'],
#   'id': [8695, 8799],
#   'mesh': [u'carcinoma, ductal, breast',
#    u'carcinoma in situ',
#    u'carcinoma, intraductal, noninfiltrating',
#    u'carcinoma',
#    u'carcinoma, ductal',
#    u'carcinoma, ductal, breast',
#    u'carcinoma in situ',
#    u'carcinoma, intraductal, noninfiltrating',
#    u'carcinoma',
#    u'carcinoma, ductal']},
#  u'A Anstey': {'Trials': [u'NCT01926496'],
#   'id': [124770],
#   'mesh': [u'carcinoma, squamous cell',
#    u'keratosis',
#    u'carcinoma',
#    u'keratosis, actinic']},
#  u'A Bahl': {'Trials': [u'NCT00470236'],
#   'id': [8164],
#   'mesh': [u'carcinoma, ductal, breast',
#    u'carcinoma in situ',
#    u'carcinoma, intraductal, noninfiltrating',
#    u'carcinoma',
#    u'carcinoma, ductal']},
#  u'A Belhabri': {'Trials': [u'NCT01810705'],
#   'id': [105677],
#   'mesh': [u'leukemia, myeloid, acute', u'leukemia, myeloid', u'leukemia']},
#  u'A Bewley': {'Trials': [u'NCT01953172'], 'id': [132256], 'mesh': []},
#  u'A Bochove': {'Trials': [u'NCT01606098', u'NCT01918852'],
#   'id': [131236, 85255],
#   'mesh': [u'neoplasm metastasis',
#    u'colorectal neoplasms',
#    u'neoplasm metastasis',
#    u'colonic neoplasms']},
#  u'A Butt': {'Trials': [u'NCT01926496'],
#   'id': [124769],
#   'mesh': [u'carcinoma, squamous cell',
#    u'keratosis',
#    u'carcinoma',
#    u'keratosis, actinic']},
#  u'A C Vahl': {'Trials': [u'NCT01385774'],
#   'id': [59864],
#   'mesh': [u'intermittent claudication',
#    u'peripheral arterial disease',
#    u'arterial occlusive diseases',
#    u'peripheral vascular diseases']},
#  u'A Chaput': {'Trials': [u'NCT01423136'],
#   'id': [56623],
#   'mesh': [u'postoperative complications']},
#  u'A Courdi': {'Trials': [u'NCT00470236'],
#   'id': [8038],
#   'mesh': [u'carcinoma, ductal, breast',
#    u'carcinoma in situ',
#    u'carcinoma, intraductal, noninfiltrating',
#    u'carcinoma',
#    u'carcinoma, ductal']},
#  u'A Daniels': {'Trials': [u'NCT01721785'],
#   'id': [92190],
#   'mesh': [u'neoplasms', u'rectal neoplasms']},
#  u'A Downs': {'Trials': [u'NCT01926496'],
#   'id': [124765],
#   'mesh': [u'carcinoma, squamous cell',
#    u'keratosis',
#    u'carcinoma',
#    u'keratosis, actinic']},
#  u'A E Smals': {'Trials': [u'NCT01606098'],
#   'id': [86455],
#   'mesh': [u'neoplasm metastasis', u'colonic neoplasms']},
#  u'A Fayad': {'Trials': [u'NCT01423136'],
#   'id': [56624],
#   'mesh': [u'postoperative complications']},
#  u'A Finelli': {'Trials': [u'NCT02036684'],
#   'id': [139385],
#   'mesh': [u'prostatic neoplasms']},
#  u'A Flavin': {'Trials': [u'NCT00470236'],
#   'id': [8039],
#   'mesh': [u'carcinoma, ductal, breast',
#    u'carcinoma in situ',
#    u'carcinoma, intraductal, noninfiltrating',
#    u'carcinoma',
#    u'carcinoma, ductal']},
#  u'A G Kfoury': {'Trials': [u'NCT01278745'], 'id': [50348], 'mesh': []},
#  u'A G Unnikrishnan': {'Trials': [u'NCT01212328'],
#   'id': [47375],
#   'mesh': [u'diabetes mellitus',
#    u'hypertension',
#    u'cardiovascular diseases',
#    u'dyslipidemias',
#    u'diabetes mellitus, type 2']},
#  u'A Gibbon': {'Trials': [u'NCT01529099'],
#   'id': [73915],
#   'mesh': [u'gout', u'osteoarthritis', u'arthritis', u'chondrocalcinosis']},
#  u'A H Honkoop': {'Trials': [u'NCT01898117', u'NCT01996267'],
#   'id': [136808, 117179],
#   'mesh': [u'breast neoplasms', u'breast neoplasms']},
#  u'A H Li': {'Trials': [u'NCT00247533'],
#   'id': [2726],
#   'mesh': [u'cerebral infarction',
#    u'myocardial ischemia',
#    u'stroke',
#    u'coronary stenosis',
#    u'coronary disease',
#    u'coronary artery disease',
#    u'arrhythmias, cardiac']},
#  u'A Hoeben': {'Trials': [u'NCT02054442'],
#   'id': [146379],
#   'mesh': [u'carcinoma, squamous cell',
#    u'carcinoma',
#    u'head and neck neoplasms']},
#  u'A Hui': {'Trials': [u'NCT01013779'],
#   'id': [27535],
#   'mesh': [u'carcinoma', u'carcinoma, merkel cell']},
#  u'A I Igwilo': {'Trials': [u'NCT01936064'],
#   'id': [127425],
#   'mesh': [u'breast neoplasms', u'congenital abnormalities']},
#  u'A Ignaszewski': {'Trials': [u'NCT01248702'],
#   'id': [40750],
#   'mesh': [u'myocardial infarction',
#    u'infarction',
#    u'cardiomyopathies',
#    u'heart failure']},
#  u'A J Gelderblom': {'Trials': [u'NCT01299506'],
#   'id': [50527],
#   'mesh': [u'sarcoma']},
#  u'A J de Nie': {'Trials': [u'NCT01385774'],
#   'id': [59963],
#   'mesh': [u'intermittent claudication',
#    u'peripheral arterial disease',
#    u'arterial occlusive diseases',
#    u'peripheral vascular diseases']},
#  u'A J ten Cate-Hoek': {'Trials': [u'NCT01429714'],
#   'id': [70018],
#   'mesh': [u'venous thrombosis',
#    u'postphlebitic syndrome',
#    u'thrombosis',
#    u'venous thromboembolism',
#    u'postthrombotic syndrome']},
#  u'A Jansen-Mager': {'Trials': [u'NCT01996267'],
#   'id': [136279],
#   'mesh': [u'breast neoplasms']},
#  u'A KL Reyners': {'Trials': [u'NCT01358539'],
#   'id': [55415],
#   'mesh': [u'neoplasm metastasis',
#    u'bone neoplasms',
#    u'bone marrow diseases']},
#  u'A L Imholz': {'Trials': [u'NCT01898117', u'NCT01996267'],
#   'id': [136172, 117070],
#   'mesh': [u'breast neoplasms', u'breast neoplasms']},
#  u'A L. Milani': {'Trials': [u'NCT00372190'],
#   'id': [7399],
#   'mesh': [u'prolapse', u'uterine prolapse', u'pelvic organ prolapse']},
#  u'A LT Imholz': {'Trials': [u'NCT01606098', u'NCT01136005'],
#   'id': [37108, 86727],
#   'mesh': [u'exanthema', u'neoplasm metastasis', u'colonic neoplasms']},
#  u'A Lopez-Santiago': {'Trials': [u'NCT01380405'],
#   'id': [66734],
#   'mesh': [u'lung diseases',
#    u'pulmonary disease, chronic obstructive',
#    u'lung diseases, obstructive',
#    u'respiration disorders']},
#  u'A M Kamper': {'Trials': [u'NCT01530308'],
#   'id': [68531],
#   'mesh': [u'emergencies', u'delirium']},
#  u'A M Layton': {'Trials': [u'NCT01926496'],
#   'id': [124771],
#   'mesh': [u'carcinoma, squamous cell',
#    u'keratosis',
#    u'carcinoma',
#    u'keratosis, actinic']},
#  u'A MW Broekman': {'Trials': [u'NCT00372190'],
#   'id': [7406],
#   'mesh': [u'prolapse', u'uterine prolapse', u'pelvic organ prolapse']},
#  u'A MacIssac': {'Trials': [u'NCT01015612'],
#   'id': [26803],
#   'mesh': [u'constriction, pathologic', u'aortic valve stenosis']},
#  u'A N Goosens': {'Trials': [u'NCT01996267'],
#   'id': [136166],
#   'mesh': [u'breast neoplasms']},
#  u'A Nabid': {'Trials': [u'NCT01350180'],
#   'id': [52665],
#   'mesh': [u'prostatic neoplasms']},
#  u'A Naz': {'Trials': [u'NCT02014649'],
#   'id': [137433],
#   'mesh': [u'influenza, human']},
#  u'A Nichol': {'Trials': [u'NCT00470236'],
#   'id': [8036],
#   'mesh': [u'carcinoma, ductal, breast',
#    u'carcinoma in situ',
#    u'carcinoma, intraductal, noninfiltrating',
#    u'carcinoma',
#    u'carcinoma, ductal']},
#  u'A Nsair': {'Trials': [u'NCT01670981'],
#   'id': [91202],
#   'mesh': [u'ischemia',
#    u'cardiomyopathies',
#    u'cardiomyopathy, dilated',
#    u'heart failure']},
#  u'A O Dosunmu': {'Trials': [u'NCT01704794'],
#   'id': [96007],
#   'mesh': [u'anemia, sickle cell']},
#  u'A Odgaard': {'Trials': [u'NCT01542580'],
#   'id': [68432],
#   'mesh': [u'osteoarthritis']},
#  u'A P Hamberg': {'Trials': [u'NCT01898117'],
#   'id': [117080],
#   'mesh': [u'breast neoplasms']},
#  u'A P Kappetein': {'Trials': [u'NCT00639782'],
#   'id': [12822],
#   'mesh': [u'heart valve diseases']},
#  u'A PASQUIER': {'Trials': [u'NCT00354237'],
#   'id': [6128],
#   'mesh': [u'coronary disease',
#    u'coronary artery disease',
#    u'diabetes mellitus, type 2',
#    u'diabetes mellitus',
#    u'myocardial ischemia']},
#  u'A PI Houwink': {'Trials': [u'NCT01855217'], 'id': [122025], 'mesh': []},
#  u'A Pathmeswaren': {'Trials': [u'NCT01174381'],
#   'id': [38558],
#   'mesh': [u'heart diseases',
#    u'coronary artery disease',
#    u'hypertension',
#    u'stroke',
#    u'myocardial ischemia']},
#  u'A Richetti': {'Trials': [u'NCT00470236'],
#   'id': [8056],
#   'mesh': [u'carcinoma, ductal, breast',
#    u'carcinoma in situ',
#    u'carcinoma, intraductal, noninfiltrating',
#    u'carcinoma',
#    u'carcinoma, ductal']},
#  u'A Robinson': {'Trials': [u'NCT00470236'],
#   'id': [8802],
#   'mesh': [u'carcinoma, ductal, breast',
#    u'carcinoma in situ',
#    u'carcinoma, intraductal, noninfiltrating',
#    u'carcinoma',
#    u'carcinoma, ductal']},
#  u'A Roelstraete': {'Trials': [u'NCT00470236'],
#   'id': [9276],
#   'mesh': [u'carcinoma, ductal, breast',
#    u'carcinoma in situ',
#    u'carcinoma, intraductal, noninfiltrating',
#    u'carcinoma',
#    u'carcinoma, ductal']},
#  u'A Rulo': {'Trials': [u'NCT01774474'],
#   'id': [109118],
#   'mesh': [u'diabetes mellitus',
#    u'capsule opacification',
#    u'cataract',
#    u'macular edema',
#    u'edema']},
#  u'A Rutgers': {'Trials': [u'NCT01985373'],
#   'id': [128302],
#   'mesh': [u'immunologic deficiency syndromes']},
#  u'A Scholten': {'Trials': [u'NCT00470236'],
#   'id': [8048],
#   'mesh': [u'carcinoma, ductal, breast',
#    u'carcinoma in situ',
#    u'carcinoma, intraductal, noninfiltrating',
#    u'carcinoma',
#    u'carcinoma, ductal']},
#  u'A Smals': {'Trials': [u'NCT01996267'],
#   'id': [136176],
#   'mesh': [u'breast neoplasms']},
#  u'A Stein': {'Trials': [u'NCT01759238'],
#   'id': [102998],
#   'mesh': [u'neoplasm metastasis', u'colorectal neoplasms']},
#  u'A Stevens': {'Trials': [u'NCT00470236'],
#   'id': [8162],
#   'mesh': [u'carcinoma, ductal, breast',
#    u'carcinoma in situ',
#    u'carcinoma, intraductal, noninfiltrating',
#    u'carcinoma',
#    u'carcinoma, ductal']},
#  u'A Stillie': {'Trials': [u'NCT00470236'],
#   'id': [8693],
#   'mesh': [u'carcinoma, ductal, breast',
#    u'carcinoma in situ',
#    u'carcinoma, intraductal, noninfiltrating',
#    u'carcinoma',
#    u'carcinoma, ductal']},
#  u'A Thijs': {'Trials': [u'NCT01227213'],
#   'id': [40436],
#   'mesh': [u'carcinoma, renal cell',
#    u'hypertension',
#    u'insulin resistance',
#    u'carcinoma']},
#  u'A V Gurava Reddy': {'Trials': [u'NCT01418378'],
#   'id': [62410],
#   'mesh': [u'osteoarthritis']},
#  u'A Vahl': {'Trials': [u'NCT01936168'],
#   'id': [126059, 126060],
#   'mesh': [u'varicose veins',
#    u'wounds and injuries',
#    u'varicose veins',
#    u'wounds and injuries']},
#  u'A Venkatesan': {'Trials': [u'NCT01834235'],
#   'id': [113556],
#   'mesh': [u'pancreatic neoplasms']},
#  u'A Verbeek-de Kanter': {'Trials': [u'NCT00470236'],
#   'id': [8050],
#   'mesh': [u'carcinoma, ductal, breast',
#    u'carcinoma in situ',
#    u'carcinoma, intraductal, noninfiltrating',
#    u'carcinoma',
#    u'carcinoma, ductal']},
#  u'A W Burks': {'Trials': [u'NCT01846208'],
#   'id': [114326],
#   'mesh': [u'food hypersensitivity',
#    u'hypersensitivity',
#    u'egg hypersensitivity']},
#  u'A W Haringhuizen': {'Trials': [u'NCT01898117', u'NCT01996267'],
#   'id': [117072, 136173],
#   'mesh': [u'breast neoplasms', u'breast neoplasms']},
#  u'A WJ Hoksbergen': {'Trials': [u'NCT01385774'],
#   'id': [59863],
#   'mesh': [u'intermittent claudication',
#    u'peripheral arterial disease',
#    u'arterial occlusive diseases',
#    u'peripheral vascular diseases']},
#  u'A Welling': {'Trials': [u'NCT02014324'],
#   'id': [137258],
#   'mesh': [u'lung neoplasms', u'carcinoma, non-small-cell lung']},
#  u'A Woollons': {'Trials': [u'NCT01926496'],
#   'id': [124775],
#   'mesh': [u'carcinoma, squamous cell',
#    u'keratosis',
#    u'carcinoma',
#    u'keratosis, actinic']},
#  u'A Wright': {'Trials': [u'NCT01926496'],
#   'id': [124776],
#   'mesh': [u'carcinoma, squamous cell',
#    u'keratosis',
#    u'carcinoma',
#    u'keratosis, actinic']},
#  u'A van Baardwijk': {'Trials': [u'NCT00470236'],
#   'id': [8049],
#   'mesh': [u'carcinoma, ductal, breast',
#    u'carcinoma in situ',
#    u'carcinoma, intraductal, noninfiltrating',
#    u'carcinoma',
#    u'carcinoma, ductal']},
#  u'A van Royen': {'Trials': [u'NCT01287715'],
#   'id': [51348],
#   'mesh': [u'arthritis', u'arthritis, juvenile rheumatoid']},
#  u'A vd Ham': {'Trials': [u'NCT00761475'], 'id': [14771], 'mesh': [u'hernia']},
#  u'A-F Cailleux': {'Trials': [u'NCT01588288'],
#   'id': [76136],
#   'mesh': [u'goiter, nodular', u'goiter']},
#  u'A-G Martin': {'Trials': [u'NCT01350180'],
#   'id': [52667],
#   'mesh': [u'prostatic neoplasms']},
#  u'A-Hyun Cho': {'Trials': [u'NCT01364220'],
#   'id': [60099],
#   'mesh': [u'recurrence', u'stroke', u'cerebral infarction']},
#  u'A. A. Adeowumi': {'Trials': [u'NCT01670955'],
#   'id': [91192],
#   'mesh': [u'anemia']},
#  u'A. A. van Sorge': {'Trials': [u'NCT00226044'],
#   'id': [2386],
#   'mesh': [u'gastroesophageal reflux',
#    u'hernia',
#    u'hernia, diaphragmatic',
#    u'hernia, hiatal',
#    u'esophageal atresia']},
#  u'A. Adler': {'Trials': [u'NCT01683240'],
#   'id': [91388],
#   'mesh': [u'cholestasis',
#    u'constriction, pathologic',
#    u'choledocholithiasis',
#    u'gallstones',
#    u'common bile duct neoplasms',
#    u'neoplasms',
#    u'cholecystolithiasis',
#    u'cholelithiasis',
#    u'bile duct neoplasms']},
#  u'A. B Cosimi': {'Trials': [u'NCT00854139'],
#   'id': [21213],
#   'mesh': [u'kidney diseases',
#    u'renal insufficiency',
#    u'neoplasms, plasma cell',
#    u'multiple myeloma',
#    u'kidney failure, chronic']},
#  u'A. BORSA - DORION': {'Trials': [u'NCT01777347'],
#   'id': [110771],
#   'mesh': [u'bronchiolitis', u'bronchiolitis, viral']},
#  u'A. Batra': {'Trials': [u'NCT01434589'],
#   'id': [71704],
#   'mesh': [u'behavior, addictive']},
#  u'A. Beeker': {'Trials': [u'NCT01998152'],
#   'id': [141809],
#   'mesh': [u'colorectal neoplasms']},
#  u'A. Berglund': {'Trials': [u'NCT01558921'],
#   'id': [82829],
#   'mesh': [u'rectal neoplasms']},
#  u'A. Botterweck': {'Trials': [u'NCT02062372'],
#   'id': [146030],
#   'mesh': [u'glioblastoma']},
#  u'A. C. Dingemans': {'Trials': [u'NCT00835471'],
#   'id': [21367],
#   'mesh': [u'lung neoplasms',
#    u'carcinoma',
#    u'carcinoma, non-small-cell lung']},
#  u'A. Cats': {'Trials': [u'NCT01558921', u'NCT01273051', u'NCT01918852'],
#   'id': [82185, 54379, 130599],
#   'mesh': [u'rectal neoplasms',
#    u'rectal neoplasms',
#    u'neoplasm metastasis',
#    u'colorectal neoplasms']},
#  u'A. Cequier Fillat': {'Trials': [u'NCT01986803'],
#   'id': [128569],
#   'mesh': [u'myocardial infarction', u'infarction']},
#  u'A. Cervantes': {'Trials': [u'NCT01558921'],
#   'id': [82310],
#   'mesh': [u'rectal neoplasms']},
#  u'A. Chauhan': {'Trials': [u'NCT01444469'],
#   'id': [70281],
#   'mesh': [u'asthma']},
#  u'A. Colao': {'Trials': [u'NCT01578239'],
#   'id': [78039],
#   'mesh': [u'neuroendocrine tumors', u'carcinoid tumor']},
#  u'A. Craig Lockhart': {'Trials': [u'NCT01525069',
#    u'NCT01413022',
#    u'NCT01155882',
#    u'NCT01390311',
#    u'NCT01061515',
#    u'NCT00807781',
#    u'NCT00770263',
#    u'NCT02023541',
#    u'NCT01339442',
#    u'NCT01747499',
#    u'NCT01677559',
#    u'NCT01907165',
#    u'NCT01784861'],
#   'id': [100995,
#    90023,
#    137212,
#    130986,
#    61036,
#    67965,
#    59698,
#    14103,
#    57113,
#    110586,
#    20284,
#    38717,
#    35454],
#   'mesh': [u'leukemia, myeloid, acute',
#    u'leukemia, myeloid',
#    u'leukemia',
#    u'myelodysplastic syndromes',
#    u'precursor cell lymphoblastic leukemia-lymphoma',
#    u'leukemia, lymphoid',
#    u'lymphoma',
#    u'preleukemia',
#    u'neoplasms',
#    u'adenocarcinoma',
#    u'pancreatic neoplasms',
#    u'carcinoma',
#    u'adenocarcinoma',
#    u'carcinoma, squamous cell',
#    u'glioblastoma',
#    u'leukemia, myeloid, acute',
#    u'leukemia, myeloid',
#    u'preleukemia',
#    u'leukemia',
#    u'myelodysplastic syndromes',
#    u'neoplasms',
#    u'liver neoplasms',
#    u'cholangiocarcinoma',
#    u'breast neoplasms',
#    u'neoplasms',
#    u'neoplasms',
#    u'adenocarcinoma',
#    u'pancreatic neoplasms',
#    u'neoplasms',
#    u'adenocarcinoma',
#    u'neuroendocrine tumors',
#    u'pancreatic neoplasms',
#    u'adenoma, islet cell',
#    u'breast neoplasms',
#    u'pancreatic neoplasms',
#    u'colorectal neoplasms',
#    u'carcinoma']},
#  u'A. Dahan': {'Trials': [u'NCT01968447'], 'id': [135155], 'mesh': []},
#  u'A. David Mendelow': {'Trials': [u'NCT00784134'],
#   'id': [13915],
#   'mesh': [u'hemorrhage', u'cerebral hemorrhage']},
#  u'A. David Tahernia': {'Trials': [u'NCT00401518'],
#   'id': [7566],
#   'mesh': [u'spinal stenosis', u'constriction, pathologic']},
#  u'A. De La Calle': {'Trials': [u'NCT01854450'], 'id': [120863], 'mesh': []},
#  u'A. Dirkali': {'Trials': [u'NCT01674803', u'NCT01127958'],
#   'id': [43474, 88398],
#   'mesh': [u'myocardial infarction',
#    u'angina pectoris',
#    u'acute coronary syndrome',
#    u'myocardial ischemia',
#    u'angina, unstable',
#    u'coronary restenosis',
#    u'coronary stenosis',
#    u'infarction',
#    u'coronary disease',
#    u'coronary artery disease']},
#  u'A. Dolly Razdan': {'Trials': [u'NCT01013649'],
#   'id': [27887],
#   'mesh': [u'adenocarcinoma', u'pancreatic neoplasms']},
#  u'A. Eden Evins': {'Trials': [u'NCT01784016'],
#   'id': [109649],
#   'mesh': [u'tobacco use disorder', u'smoking']},
#  u'A. Falanga': {'Trials': [u'NCT01164046'],
#   'id': [37387],
#   'mesh': [u'venous thromboembolism',
#    u'embolism',
#    u'neoplasms',
#    u'thrombosis',
#    u'venous thrombosis',
#    u'pulmonary embolism',
#    u'thromboembolism']},
#  u'A. Frey': {'Trials': [u'NCT00161551'],
#   'id': [1148],
#   'mesh': [u'atrial fibrillation', u'sick sinus syndrome', u'heart failure']},
#  u'A. Gabriella Wernicke': {'Trials': [u'NCT01757158'],
#   'id': [102728],
#   'mesh': [u'lung neoplasms']},
#  u'A. Ganser': {'Trials': [u'NCT00867672'],
#   'id': [22235],
#   'mesh': [u'leukemia, myeloid, acute', u'leukemia, myeloid', u'leukemia']},
#  u'A. Ghirarduzzi': {'Trials': [u'NCT01164046'],
#   'id': [37390],
#   'mesh': [u'venous thromboembolism',
#    u'embolism',
#    u'neoplasms',
#    u'thrombosis',
#    u'venous thrombosis',
#    u'pulmonary embolism',
#    u'thromboembolism']},
#  u'A. Gordon Smith': {'Trials': [u'NCT01511978'],
#   'id': [79106],
#   'mesh': [u'lambert-eaton myasthenic syndrome']},
#  u'A. H. Maass': {'Trials': [u'NCT01296022'],
#   'id': [50076],
#   'mesh': [u'arrhythmias, cardiac']},
#  u'A. Haidar': {'Trials': [u'NCT02014649'],
#   'id': [137439],
#   'mesh': [u'influenza, human']},
#  u'A. Harris Basali': {'Trials': [u'NCT01854229'],
#   'id': [120233],
#   'mesh': [u'back pain', u'pain, intractable']},
#  u'A. Hoeben': {'Trials': [u'NCT01598402'],
#   'id': [86339],
#   'mesh': [u'pneumonia',
#    u'pneumonia, aspiration',
#    u'head and neck neoplasms']},
#  u'A. Hoffmann': {'Trials': [u'NCT02062372'],
#   'id': [146018],
#   'mesh': [u'glioblastoma']},
#  u'A. Honkoop': {'Trials': [u'NCT00459771'],
#   'id': [10613],
#   'mesh': [u'breast neoplasms']},
#  u'A. J. Brendenoord': {'Trials': [u'NCT01574339'],
#   'id': [79448],
#   'mesh': [u'gastroesophageal reflux']},
#  u'A. J. van der Wouw': {'Trials': [u'NCT00459771', u'NCT01996267'],
#   'id': [10611, 136806],
#   'mesh': [u'breast neoplasms', u'breast neoplasms']},
#  u'A. James Moser': {'Trials': [u'NCT01357525', u'NCT01360593'],
#   'id': [53561, 54701],
#   'mesh': [u'adenocarcinoma', u'adenocarcinoma', u'pancreatic neoplasms']},
#  u'A. Jo Chien': {'Trials': [u'NCT01384526'],
#   'id': [60442],
#   'mesh': [u'breast neoplasms']},
#  u'A. John Blair': {'Trials': [u'NCT00225563'], 'id': [2382], 'mesh': []},
#  u'A. Johnsson': {'Trials': [u'NCT01558921'],
#   'id': [82928],
#   'mesh': [u'rectal neoplasms']},
#  u'A. Jon Stoessl': {'Trials': [u'NCT01835652'],
#   'id': [114098],
#   'mesh': [u'parkinson disease']},
#  u'A. KL Reyners': {'Trials': [u'NCT01641172'],
#   'id': [87723],
#   'mesh': [u'testicular neoplasms']},
#  u'A. Kaltoft': {'Trials': [u'NCT01756300'],
#   'id': [101041],
#   'mesh': [u'hypertension']},
#  u'A. Kathleen McClendon': {'Trials': [u'NCT01514565'],
#   'id': [74195],
#   'mesh': [u'breast neoplasms']},
#  u'A. Kingma': {'Trials': [u'NCT01599052'],
#   'id': [85145],
#   'mesh': [u'brain neoplasms', u'neoplasms', u'cystic fibrosis', u'fibrosis']},
#  u'A. Koneti Rao': {'Trials': [u'NCT00790335'],
#   'id': [22481],
#   'mesh': [u'venous thromboembolism',
#    u'thrombosis',
#    u'venous thrombosis',
#    u'thromboembolism',
#    u'postphlebitic syndrome',
#    u'postthrombotic syndrome']},
#  u'A. LeBron Paige': {'Trials': [u'NCT01733394'],
#   'id': [107608],
#   'mesh': [u'epilepsy']},
#  u'A. Lohse': {'Trials': [u'NCT01016002'],
#   'id': [26929],
#   'mesh': [u'carcinoma, ductal, breast',
#    u'carcinoma, ductal',
#    u'carcinoma',
#    u'bile duct neoplasms']},
#  u'A. M. Alings': {'Trials': [u'NCT01296022'],
#   'id': [50073],
#   'mesh': [u'arrhythmias, cardiac']},
#  u'A. M. Masclee': {'Trials': [u'NCT01493349'],
#   'id': [71998],
#   'mesh': [u'diverticulum, colon', u'diverticulitis', u'diverticulum']},
#  u'A. Mackaay': {'Trials': [u'NCT00189111'],
#   'id': [2071],
#   'mesh': [u'peripheral arterial disease', u'peripheral vascular diseases']},
#  u'A. Marc Gillinov': {'Trials': [u'NCT01593917'],
#   'id': [77781],
#   'mesh': [u'aortic valve insufficiency', u'aortic valve stenosis']},
#  u'A. Masclee': {'Trials': [u'NCT01908465'],
#   'id': [131158],
#   'mesh': [u'irritable bowel syndrome']},
#  u'A. Merrill H. Garrett': {'Trials': [u'NCT01783444'],
#   'id': [109207],
#   'mesh': [u'breast neoplasms']},
#  u'A. Mosterd': {'Trials': [u'NCT00189111'],
#   'id': [2068],
#   'mesh': [u'peripheral arterial disease', u'peripheral vascular diseases']},
#  u'A. M\xfcgge': {'Trials': [u'NCT01245933'],
#   'id': [43260],
#   'mesh': [u'lung diseases',
#    u'pulmonary disease, chronic obstructive',
#    u'lung diseases, obstructive',
#    u'respiration disorders']},
#  u'A. O. Dosunmu': {'Trials': [u'NCT01936064'],
#   'id': [127421],
#   'mesh': [u'breast neoplasms', u'congenital abnormalities']},
#  u'A. Osama Gaber': {'Trials': [u'NCT01789203', u'NCT01517984'],
#   'id': [72641, 109634],
#   'mesh': [u'virus diseases']},
#  u'A. Pieter Kappetein': {'Trials': [u'NCT01586910'],
#   'id': [78448],
#   'mesh': [u'constriction, pathologic', u'aortic valve stenosis']},
#  u'A. Pronk': {'Trials': [u'NCT01273051'],
#   'id': [54392],
#   'mesh': [u'rectal neoplasms']},
#  u'A. Randy McIntosh': {'Trials': [u'NCT01216449'], 'id': [44862], 'mesh': []},
#  u'A. Rastan': {'Trials': [u'NCT01598844'],
#   'id': [85127],
#   'mesh': [u'constriction, pathologic', u'aortic valve stenosis']},
#  u'A. Reyners': {'Trials': [u'NCT01299506'],
#   'id': [50526],
#   'mesh': [u'sarcoma']},
#  u'A. Roos': {'Trials': [u'NCT02060942'],
#   'id': [145230],
#   'mesh': [u'cardiac output, high']},
#  u'A. Rutten': {'Trials': [u'NCT00189111'],
#   'id': [1862],
#   'mesh': [u'peripheral arterial disease', u'peripheral vascular diseases']},
#  u'A. S. Hyun': {'Trials': [u'NCT01622361'],
#   'id': [80067],
#   'mesh': [u'breast neoplasms']},
#  u'A. S. Montenero': {'Trials': [u'NCT00643188'],
#   'id': [12347],
#   'mesh': [u'atrial fibrillation',
#    u'ventricular dysfunction',
#    u'ventricular dysfunction, left',
#    u'heart failure']},
#  u'A. Samer Al-Homsi': {'Trials': [u'NCT01860170'],
#   'id': [122702],
#   'mesh': [u'graft vs host disease', u'neoplasms', u'hematologic neoplasms']},
#  u'A. Sasha Krupnick': {'Trials': [u'NCT01146366'],
#   'id': [36140],
#   'mesh': [u'lung neoplasms', u'carcinoma, non-small-cell lung']},
#  u'A. Schuchert': {'Trials': [u'NCT00161551'],
#   'id': [1146],
#   'mesh': [u'atrial fibrillation', u'sick sinus syndrome', u'heart failure']},
#  u'A. Squizzato': {'Trials': [u'NCT01164046'],
#   'id': [37391],
#   'mesh': [u'venous thromboembolism',
#    u'embolism',
#    u'neoplasms',
#    u'thrombosis',
#    u'venous thrombosis',
#    u'pulmonary embolism',
#    u'thromboembolism']},
#  u'A. TRAN': {'Trials': [u'NCT02085915'],
#   'id': [140629],
#   'mesh': [u'liver cirrhosis', u'fibrosis', u'ascites']},
#  u'A. Tahir': {'Trials': [u'NCT01777347'],
#   'id': [110768],
#   'mesh': [u'bronchiolitis', u'bronchiolitis, viral']},
#  u'A. Verhagen Verhagen': {'Trials': [u'NCT01933828'],
#   'id': [125740],
#   'mesh': [u'lung neoplasms']},
#  u'A. Wesley Burks': {'Trials': [u'NCT01904604'],
#   'id': [125104],
#   'mesh': [u'food hypersensitivity',
#    u'hypersensitivity',
#    u'hypersensitivity, immediate',
#    u'peanut hypersensitivity']},
#  u'A. Whitney Brown': {'Trials': [u'NCT01963728'],
#   'id': [131809],
#   'mesh': [u'diabetes mellitus']},
#  u'A. Wilke': {'Trials': [u'NCT00161551'],
#   'id': [1147],
#   'mesh': [u'atrial fibrillation', u'sick sinus syndrome', u'heart failure']},
#  u'A. ten Tije': {'Trials': [u'NCT01918852'],
#   'id': [130604],
#   'mesh': [u'neoplasm metastasis', u'colorectal neoplasms']},
#  u'A. van Zanten': {'Trials': [u'NCT01783379'],
#   'id': [109092],
#   'mesh': [u'mycoses']},
#  u'A.A. Jacobi-Postma': {'Trials': [u'NCT02062372'],
#   'id': [146021],
#   'mesh': [u'glioblastoma']},
#  u'A.A.M. Masclee': {'Trials': [u'NCT01877057', u'NCT01877044'],
#   'id': [117154, 117151],
#   'mesh': [u'obesity', u'overweight', u'obesity', u'overweight']},
#  u'A.C.B. Pronk': {'Trials': [u'NCT01534234'],
#   'id': [73935],
#   'mesh': [u'heart failure']},
#  u'A.E van der Meulen': {'Trials': [u'NCT01464151'],
#   'id': [66033],
#   'mesh': [u'colorectal neoplasms',
#    u'intestinal diseases',
#    u'inflammatory bowel diseases']},
#  u'A.F.P. Mulder': {'Trials': [u'NCT00372190'],
#   'id': [7408],
#   'mesh': [u'prolapse', u'uterine prolapse', u'pelvic organ prolapse']},
#  u'A.F.T. Olieman': {'Trials': [u'NCT01558921'],
#   'id': [82199],
#   'mesh': [u'rectal neoplasms']},
#  u'A.G. Kfoury': {'Trials': [u'NCT01769443'], 'id': [102167], 'mesh': []},
#  u'A.J. Bredenoord': {'Trials': [u'NCT01908465'],
#   'id': [131159],
#   'mesh': [u'irritable bowel syndrome']},
#  u'A.J. ten Tije': {'Trials': [u'NCT01558921'],
#   'id': [82189],
#   'mesh': [u'rectal neoplasms']},
#  u'A.J. van Boven': {'Trials': [u'NCT01772108',
#    u'NCT01813435',
#    u'NCT01586910'],
#   'id': [78730, 112611, 102460],
#   'mesh': [u'constriction, pathologic',
#    u'aortic valve stenosis',
#    u'coronary disease',
#    u'coronary artery disease',
#    u'myocardial ischemia',
#    u'mitral valve insufficiency',
#    u'cardiovascular diseases',
#    u'heart failure']},
#  u'A.J.G.H. Bindels': {'Trials': [u'NCT02060942'],
#   'id': [145229],
#   'mesh': [u'cardiac output, high']},
#  u'A.K.L. Reyners': {'Trials': [u'NCT01834521'],
#   'id': [112335],
#   'mesh': [u'breast neoplasms']},
#  u'A.L.T. Imholz': {'Trials': [u'NCT01558921'],
#   'id': [82195],
#   'mesh': [u'rectal neoplasms']},
#  u'A.M. De Vos': {'Trials': [u'NCT00189111'],
#   'id': [1863],
#   'mesh': [u'peripheral arterial disease', u'peripheral vascular diseases']},
#  u'A.M. E. Bruynzeel': {'Trials': [u'NCT01558921'],
#   'id': [82186],
#   'mesh': [u'rectal neoplasms']},
#  u'A.M. James Shapiro': {'Trials': [u'NCT01653899'],
#   'id': [94842],
#   'mesh': [u'diabetes mellitus']},
#  u'A.M.E. Walenkamp': {'Trials': [u'NCT01849523'],
#   'id': [115054],
#   'mesh': [u'neuroendocrine tumors']},
#  u'A.R. Zaki Masud': {'Trials': [u'NCT01614652'],
#   'id': [91096],
#   'mesh': [u'heart failure', u'myocardial ischemia']},
#  u'A.R.H. Zanten': {'Trials': [u'NCT01362959'],
#   'id': [52162],
#   'mesh': [u'delirium',
#    u'psychomotor agitation',
#    u'substance withdrawal syndrome']},
#  u'A.T.M. Gosselink': {'Trials': [u'NCT01127958'], 'id': [43476], 'mesh': []},
#  u'A.W.G. van der Velde': {'Trials': [u'NCT00459771'],
#   'id': [10604],
#   'mesh': [u'breast neoplasms']},
#  u'A/P Dr Kanthimathi M. S.': {'Trials': [u'NCT01626430'],
#   'id': [86387],
#   'mesh': [u'metabolic syndrome x', u'insulin resistance']},
#  u'A/Prof Emma Duncan': {'Trials': [u'NCT00781261'],
#   'id': [15156],
#   'mesh': [u'osteonecrosis']},
#  u'A/Professor Morteza Aghmesheh': {'Trials': [u'NCT01721954'],
#   'id': [92944],
#   'mesh': [u'colorectal neoplasms', u'neoplasms']},
#  u'ABDELLATIF G ELKHOLY': {'Trials': [u'NCT02088424'],
#   'id': [140322],
#   'mesh': [u'insulin resistance', u'abortion, habitual']},
#  u'ABJ Groeneveld': {'Trials': [u'NCT01847079'], 'id': [115081], 'mesh': []},
#  u'ABRAHAM AVIGDOR': {'Trials': [u'NCT00795613'],
#   'id': [22054],
#   'mesh': [u'hodgkin disease', u'lymphoma']},
#  u'ACHILLE KOUATCHET': {'Trials': [u'NCT00188058'],
#   'id': [1809],
#   'mesh': [u'acute lung injury',
#    u'respiratory distress syndrome, adult',
#    u'respiratory distress syndrome, newborn',
#    u'lung injury',
#    u'wounds and injuries']},
#  u'AD Chetiyawardana': {'Trials': [u'NCT01604005'],
#   'id': [91470, 84870],
#   'mesh': [u'mesothelioma', u'mesothelioma']},
#  u'ADENIS Antoine': {'Trials': [u'NCT01598038'],
#   'id': [89867],
#   'mesh': [u'carcinoma, renal cell', u'carcinoma']},
#  u'ADNET Fr\xe9d\xe9ric': {'Trials': [u'NCT01961804'],
#   'id': [131991],
#   'mesh': [u'hemorrhage', u'craniocerebral trauma', u'wounds and injuries']},
#  u'ADRAG\xc3O': {'Trials': [u'NCT01170624'],
#   'id': [39704],
#   'mesh': [u'heart failure']},
#  u'ADRIANA ACASANDREI': {'Trials': [u'NCT01641562'],
#   'id': [86503],
#   'mesh': [u'breast neoplasms']},
#  u'AFTAB NAZ': {'Trials': [u'NCT02044341'],
#   'id': [144727],
#   'mesh': [u'otitis', u'otitis media']},
#  u'AGNES SALLE': {'Trials': [u'NCT01700738'],
#   'id': [96453],
#   'mesh': [u'obesity, morbid', u'obesity']},
#  u'AGNETA L SUNEHAG': {'Trials': [u'NCT00950677'],
#   'id': [29908],
#   'mesh': [u'diabetes mellitus', u'diabetes mellitus, type 2']},
#  u'AGOSTINI Aubert': {'Trials': [u'NCT00137982'],
#   'id': [1199],
#   'mesh': [u'pregnancy, ectopic', u'pregnancy, tubal']},
#  u'AGRAOU': {'Trials': [u'NCT01188356'],
#   'id': [44232],
#   'mesh': [u'arrhythmias, cardiac', u'atrial premature complexes']},
#  u'AGUSTIN ALBARRAN GONZALEZ-TREVILLA': {'Trials': [u'NCT01813435'],
#   'id': [113240],
#   'mesh': [u'coronary disease',
#    u'coronary artery disease',
#    u'myocardial ischemia']},
#  u'AH Gerards': {'Trials': [u'NCT01148043'],
#   'id': [43417],
#   'mesh': [u'osteoarthritis']},
#  u'AHED ZEIDAN': {'Trials': [u'NCT01746927'], 'id': [100237], 'mesh': []},
#  u'AHMAD AWADA': {'Trials': [u'NCT00199160'],
#   'id': [1716],
#   'mesh': [u'neoplasms', u'head and neck neoplasms']},
#  u'AHMET \xc7 AYKAN': {'Trials': [u'NCT02029456'],
#   'id': [138418],
#   'mesh': [u'pulmonary embolism', u'embolism']},
#  u'AITZIBER AGUINAGA': {'Trials': [u'NCT01592032'],
#   'id': [79632],
#   'mesh': [u'bacteremia', u'catheter-related infections']},
#  u'AJB McEwan': {'Trials': [u'NCT01747512'],
#   'id': [100996],
#   'mesh': [u'thyroid diseases',
#    u'neoplasms',
#    u'thyroid neoplasms',
#    u'head and neck neoplasms']},
#  u'AJM Geerards': {'Trials': [u'NCT01145937'],
#   'id': [36017],
#   'mesh': [u'keratoconus']},
#  u'AKANIST PIYAPANT': {'Trials': [u'NCT01906112'],
#   'id': [131466],
#   'mesh': [u'breast neoplasms', u'carcinoma']},
#  u'AKHIL KAPUR': {'Trials': [u'NCT00948116'],
#   'id': [31222],
#   'mesh': [u'diabetes mellitus',
#    u'acute kidney injury',
#    u'renal insufficiency',
#    u'wounds and injuries']},
#  u'AKNAR CALABRICH': {'Trials': [u'NCT01168505'],
#   'id': [32101],
#   'mesh': [u'breast neoplasms']},
#  u'AKW Lie': {'Trials': [u'NCT00563108', u'NCT00563589'],
#   'id': [11745, 11628],
#   'mesh': [u'graft vs host disease', u'graft vs host disease']},
#  u'ALAAELDIN KHAIRELDIN': {'Trials': [u'NCT01738113'],
#   'id': [107627],
#   'mesh': [u'congenital abnormalities']},
#  u'ALAIN BRANCHEREAU': {'Trials': [u'NCT00904501'],
#   'id': [23314],
#   'mesh': [u'vascular diseases',
#    u'peripheral vascular diseases',
#    u'ischemia',
#    u'peripheral arterial disease']},
#  u'ALAIN GRAFEILLE': {'Trials': [u'NCT02068118'],
#   'id': [145503],
#   'mesh': [u'heart failure']},
#  u'ALAIN MERCAT': {'Trials': [u'NCT00188058'],
#   'id': [1808],
#   'mesh': [u'acute lung injury',
#    u'respiratory distress syndrome, adult',
#    u'respiratory distress syndrome, newborn',
#    u'lung injury',
#    u'wounds and injuries']},
#  u'ALAIN PRAT': {'Trials': [u'NCT01920698'],
#   'id': [125156],
#   'mesh': [u'mitral valve insufficiency', u'cardiovascular diseases']},
#  u'ALAIN Sophie': {'Trials': [u'NCT02064699', u'NCT02067169'],
#   'id': [146257, 143894],
#   'mesh': [u'cytomegalovirus infections', u'cytomegalovirus infections']},
#  u'ALAN B SCOTT': {'Trials': [u'NCT01616108'],
#   'id': [87322],
#   'mesh': [u'graves disease',
#    u'esotropia',
#    u'nystagmus, pathologic',
#    u'exotropia',
#    u'strabismus']},
#  u'ALAPETITE Claire': {'Trials': [u'NCT01841047'],
#   'id': [115581],
#   'mesh': [u'retroperitoneal neoplasms', u'liposarcoma']},
#  u'ALBA BRANDES': {'Trials': [u'NCT01086826'],
#   'id': [28382],
#   'mesh': [u'carcinoma, squamous cell',
#    u'carcinoma',
#    u'head and neck neoplasms']},
#  u'ALBERT BARROSO-GARCIA': {'Trials': [u'NCT01729650'],
#   'id': [92928],
#   'mesh': [u'mental disorders',
#    u'schizophrenia',
#    u'bipolar disorder',
#    u'psychotic disorders']},
#  u'ALBERT TRAN': {'Trials': [u'NCT00914446'],
#   'id': [16232],
#   'mesh': [u'obesity, morbid', u'obesity', u'fatty liver']},
#  u'ALBERTO ZALIANI': {'Trials': [u'NCT02032927'],
#   'id': [138071],
#   'mesh': [u'osteoarthritis, knee', u'osteoarthritis']},
#  u'ALEC VAHANIAN': {'Trials': [u'NCT01920698'],
#   'id': [125163],
#   'mesh': [u'mitral valve insufficiency', u'cardiovascular diseases']},
#  u'ALESSANDRA AA ALGAROTTI': {'Trials': [u'NCT01186809'],
#   'id': [44698],
#   'mesh': [u'neoplasms', u'hematologic neoplasms']},
#  u'ALESSANDRO BERTOLINI': {'Trials': [u'NCT01086826'],
#   'id': [28497],
#   'mesh': [u'carcinoma, squamous cell',
#    u'carcinoma',
#    u'head and neck neoplasms']},
#  u'ALESSANDRO LEVIS': {'Trials': [u'NCT01399931'],
#   'id': [57005],
#   'mesh': [u'hodgkin disease', u'lymphoma']},
#  u'ALESSANDRO MA GIANNI': {'Trials': [u'NCT00795613'],
#   'id': [22164],
#   'mesh': [u'hodgkin disease', u'lymphoma']},
#  u'ALESSIO FALIVA': {'Trials': [u'NCT02032927'],
#   'id': [139539],
#   'mesh': [u'osteoarthritis, knee', u'osteoarthritis']},
#  u'ALEXANDRE AQUINO CAMARA': {'Trials': [u'NCT01178632'],
#   'id': [32220],
#   'mesh': [u'anxiety disorders']},
#  u'ALEXANDRE DEMOULE': {'Trials': [u'NCT00188058'],
#   'id': [1596],
#   'mesh': [u'acute lung injury',
#    u'respiratory distress syndrome, adult',
#    u'respiratory distress syndrome, newborn',
#    u'lung injury',
#    u'wounds and injuries']},
#  u'ALEXANDRE DUGUET': {'Trials': [u'NCT00188058'],
#   'id': [1595],
#   'mesh': [u'acute lung injury',
#    u'respiratory distress syndrome, adult',
#    u'respiratory distress syndrome, newborn',
#    u'lung injury',
#    u'wounds and injuries']},
#  u'ALEXANDRU BLIDARU': {'Trials': [u'NCT01641562'],
#   'id': [86502],
#   'mesh': [u'breast neoplasms']},
#  u'ALEXANDRU N MISCHIE': {'Trials': [u'NCT01575249'],
#   'id': [78598],
#   'mesh': [u'constriction, pathologic', u'aortic valve stenosis']},
#  u'ALFRED AIYEBELEHIN': {'Trials': [u'NCT00479947'],
#   'id': [10670],
#   'mesh': [u'vaginitis', u'candidiasis, vulvovaginal', u'candidiasis']},
#  u'ALFREIJAT': {'Trials': [u'NCT01008228'],
#   'id': [25635],
#   'mesh': [u'pneumothorax']},
#  u'ALIMI Yves': {'Trials': [u'NCT01230203'],
#   'id': [42879],
#   'mesh': [u'aortic aneurysm', u'aneurysm', u'aortic aneurysm, abdominal']},
#  u'ALIPOUR Homauon': {'Trials': [u'NCT01961804'],
#   'id': [131994],
#   'mesh': [u'hemorrhage', u'craniocerebral trauma', u'wounds and injuries']},
#  u'ALLIET': {'Trials': [u'NCT01715246'], 'id': [98763], 'mesh': []},
#  u'ALLOUACHE Djelila': {'Trials': [u'NCT01597284', u'NCT01436604'],
#   'id': [84755, 68631],
#   'mesh': [u'breast neoplasms', u'carcinoma']},
#  u'ALON SCOPE': {'Trials': [u'NCT01194947'],
#   'id': [44061],
#   'mesh': [u'nevus',
#    u'nevus, pigmented',
#    u'nevus, epithelioid and spindle cell']},
#  u'ALPER KIRKPANTUR': {'Trials': [u'NCT01382966'],
#   'id': [61107],
#   'mesh': [u'renal osteodystrophy',
#    u'kidney diseases',
#    u'arteriovenous fistula',
#    u'hypertrophy, left ventricular',
#    u'hypertrophy',
#    u'carpal tunnel syndrome',
#    u'renal insufficiency, chronic',
#    u'kidney failure, chronic']},
#  u'ALTAY GUVENIR': {'Trials': [u'NCT00970892'],
#   'id': [29956],
#   'mesh': [u'embolism',
#    u'vascular diseases',
#    u'atrial fibrillation',
#    u'thrombosis',
#    u'venous thrombosis',
#    u'cardiomyopathies',
#    u'pulmonary embolism',
#    u'peripheral arterial disease',
#    u'peripheral vascular diseases']},
#  u'AM Huisman': {'Trials': [u'NCT01148043'],
#   'id': [43416],
#   'mesh': [u'osteoarthritis']},
#  u'AMARA': {'Trials': [u'NCT01170624'],
#   'id': [39690],
#   'mesh': [u'heart failure']},
#  u'AME': {'Trials': [u'NCT00443339'],
#   'id': [8960],
#   'mesh': [u'myelodysplastic syndromes', u'preleukemia']},
#  u'AMELA Yaovi Messan': {'Trials': [u'NCT01598038'],
#   'id': [89869],
#   'mesh': [u'carcinoma, renal cell', u'carcinoma']},
#  u'AMER HAMADE': {'Trials': [u'NCT00904501'],
#   'id': [23315],
#   'mesh': [u'vascular diseases',
#    u'peripheral vascular diseases',
#    u'ischemia',
#    u'peripheral arterial disease']},
#  u'AMR H ELdeeb': {'Trials': [u'NCT01327729'],
#   'id': [59717],
#   'mesh': [u'hepatitis, chronic',
#    u'hepatitis c, chronic',
#    u'hepatitis a',
#    u'hepatitis',
#    u'hepatitis c']},
#  u'AMy C Janes': {'Trials': [u'NCT01782599'],
#   'id': [109553],
#   'mesh': [u'tobacco use disorder']},
#  u'ANA GODOY': {'Trials': [u'NCT02048397'],
#   'id': [147003],
#   'mesh': [u'bronchiectasis']},
#  u'ANA M\xaa MONZ\xd3': {'Trials': [u'NCT01581359'],
#   'id': [75873],
#   'mesh': [u'endometriosis', u'infertility']},
#  u'ANANT E BAGUL': {'Trials': [u'NCT01832428', u'NCT01834066', u'NCT01834079'],
#   'id': [114884, 112909, 114885],
#   'mesh': [u'muscular dystrophies',
#    u'muscular dystrophy, duchenne',
#    u'stroke',
#    u'cerebral infarction',
#    u'optic nerve diseases',
#    u'nervous system diseases',
#    u'optic atrophy',
#    u'atrophy']},
#  u'ANDRE BONGAIN': {'Trials': [u'NCT00485784'],
#   'id': [10067],
#   'mesh': [u'eclampsia', u'pre-eclampsia', u'pregnancy complications']},
#  u'ANDRE Fabrice': {'Trials': [u'NCT01349842'],
#   'id': [52224],
#   'mesh': [u'carcinoma, ductal, breast',
#    u'breast neoplasms',
#    u'neoplastic cells, circulating']},
#  u'ANDRE MICHEL': {'Trials': [u'NCT01013636'],
#   'id': [27732],
#   'mesh': [u'tick-borne diseases', u'anaplasmosis']},
#  u'ANDRE OBADIA Nathalie': {'Trials': [u'NCT01800136'],
#   'id': [111544],
#   'mesh': [u'neuralgia']},
#  u'ANDRE PISAPIA': {'Trials': [u'NCT00789139'],
#   'id': [20989],
#   'mesh': [u'recurrence', u'arrhythmias, cardiac']},
#  u'ANDRE TARDIEU': {'Trials': [u'NCT02068118'],
#   'id': [145512],
#   'mesh': [u'heart failure']},
#  u'ANDREA AMBROSOLI': {'Trials': [u'NCT02032927'],
#   'id': [138077],
#   'mesh': [u'osteoarthritis, knee', u'osteoarthritis']},
#  u'ANDREA ANGELO MARTONI': {'Trials': [u'NCT01989858'],
#   'id': [129362],
#   'mesh': [u'stomach neoplasms', u'adenocarcinoma']},
#  u'ANDREA ARDIZZONI': {'Trials': [u'NCT01086826'],
#   'id': [28491],
#   'mesh': [u'carcinoma, squamous cell',
#    u'carcinoma',
#    u'head and neck neoplasms']},
#  u'ANDREA GALLAMINI': {'Trials': [u'NCT00795613'],
#   'id': [22160],
#   'mesh': [u'hodgkin disease', u'lymphoma']},
#  u'ANDREEA NISSENKORN': {'Trials': [u'NCT02023424'],
#   'id': [137091],
#   'mesh': [u'rett syndrome']},
#  u'ANDREW FEIGIN': {'Trials': [u'NCT01560754'],
#   'id': [76476],
#   'mesh': [u'parkinson disease']},
#  u'ANGE FERRACCI': {'Trials': [u'NCT00789139'],
#   'id': [20988],
#   'mesh': [u'recurrence', u'arrhythmias, cardiac']},
#  u'ANGELO DI PILLA': {'Trials': [u'NCT01086826'],
#   'id': [28481],
#   'mesh': [u'carcinoma, squamous cell',
#    u'carcinoma',
#    u'head and neck neoplasms']},
#  u'ANGELO M CARELLA': {'Trials': [u'NCT01399931'],
#   'id': [57006],
#   'mesh': [u'hodgkin disease', u'lymphoma']},
#  u'ANIA NIESZKOWSKA': {'Trials': [u'NCT00188058'],
#   'id': [1848],
#   'mesh': [u'acute lung injury',
#    u'respiratory distress syndrome, adult',
#    u'respiratory distress syndrome, newborn',
#    u'lung injury',
#    u'wounds and injuries']},
#  u'ANIRUDDHA K AGARWAL': {'Trials': [u'NCT01546402'],
#   'id': [83435],
#   'mesh': [u'cataract', u'vision disorders', u'macular edema', u'edema']},
#  u'ANNA CANDONI': {'Trials': [u'NCT00909168'],
#   'id': [18272],
#   'mesh': [u'leukemia, myeloid, acute', u'leukemia, myeloid', u'leukemia']},
#  u'ANNA CANTISANI': {'Trials': [u'NCT00542802'],
#   'id': [11794],
#   'mesh': [u'seizures', u'stroke', u'epilepsy', u'cerebral infarction']},
#  u'ANNA MERLOTTI': {'Trials': [u'NCT01086826'],
#   'id': [28375],
#   'mesh': [u'carcinoma, squamous cell',
#    u'carcinoma',
#    u'head and neck neoplasms']},
#  u'ANNE-MARIE GUERIN': {'Trials': [u'NCT00188058'],
#   'id': [1815],
#   'mesh': [u'acute lung injury',
#    u'respiratory distress syndrome, adult',
#    u'respiratory distress syndrome, newborn',
#    u'lung injury',
#    u'wounds and injuries']},
#  u'ANNICK MOULY BANDINI': {'Trials': [u'NCT01569334'],
#   'id': [82415],
#   'mesh': [u'wounds and injuries']},
#  u'ANTHONY DE SOUZA': {'Trials': [u'NCT01622907'],
#   'id': [81100],
#   'mesh': [u'atrial fibrillation']},
#  u'ANTOINE RABBAT': {'Trials': [u'NCT00188058'],
#   'id': [1599],
#   'mesh': [u'acute lung injury',
#    u'respiratory distress syndrome, adult',
#    u'respiratory distress syndrome, newborn',
#    u'lung injury',
#    u'wounds and injuries']},
#  u'ANTOINE SALLOUM': {'Trials': [u'NCT02068118'],
#   'id': [145401],
#   'mesh': [u'heart failure']},
#  u'ANTONIO ALVAREZ': {'Trials': [u'NCT00188058'],
#   'id': [1822],
#   'mesh': [u'acute lung injury',
#    u'respiratory distress syndrome, adult',
#    u'respiratory distress syndrome, newborn',
#    u'lung injury',
#    u'wounds and injuries']},
#  u'ANTONIO DORADO': {'Trials': [u'NCT02048397'],
#   'id': [147001],
#   'mesh': [u'bronchiectasis']},
#  u'ANTONIO LUGINI': {'Trials': [u'NCT01086826'],
#   'id': [28495],
#   'mesh': [u'carcinoma, squamous cell',
#    u'carcinoma',
#    u'head and neck neoplasms']},
#  u'ANTONIO-MANUEL ALBA MU\xd1OZ': {'Trials': [u'NCT01729650'],
#   'id': [92926],
#   'mesh': [u'mental disorders',
#    u'schizophrenia',
#    u'bipolar disorder',
#    u'psychotic disorders']},
#  u'ANUSHEEL MUNSHI': {'Trials': [u'NCT01133067'],
#   'id': [36191],
#   'mesh': [u'lung neoplasms']},
#  u'ARACTINGI Selim': {'Trials': [u'NCT01988506'],
#   'id': [134098],
#   'mesh': [u'psoriasis',
#    u'aortic arch syndromes',
#    u'lupus erythematosus, systemic',
#    u'behcet syndrome',
#    u'arthritis',
#    u'cholangitis',
#    u'hepatitis',
#    u'takayasu arteritis',
#    u'spondylitis, ankylosing',
#    u'cholangitis, sclerosing',
#    u'hepatitis, autoimmune',
#    u'hepatitis a',
#    u'ulcer',
#    u'arthritis, rheumatoid',
#    u'wegener granulomatosis',
#    u'colitis, ulcerative',
#    u'spondylitis',
#    u'colitis',
#    u'crohn disease']},
#  u'ARIANE ABCARIAN': {'Trials': [u'NCT01312246'],
#   'id': [59666],
#   'mesh': [u'rectal diseases']},
#  u'ARIK NEMET': {'Trials': [u'NCT01968174'], 'id': [135029], 'mesh': []},
#  u'ARMANDO SANTORO': {'Trials': [u'NCT01989858'],
#   'id': [129371],
#   'mesh': [u'stomach neoplasms', u'adenocarcinoma']},
#  u'ARNAUD CAVAILLES': {'Trials': [u'NCT01698892'], 'id': [95872], 'mesh': []},
#  u'ARNAUD CHAUMEIL': {'Trials': [u'NCT02068118'],
#   'id': [145506],
#   'mesh': [u'heart failure']},
#  u'ARNAUD THILLE': {'Trials': [u'NCT00188058'],
#   'id': [1823],
#   'mesh': [u'acute lung injury',
#    u'respiratory distress syndrome, adult',
#    u'respiratory distress syndrome, newborn',
#    u'lung injury',
#    u'wounds and injuries']},
#  u'ARNOLDO SIERRA': {'Trials': [u'NCT01502488'],
#   'id': [72718],
#   'mesh': [u'autistic disorder']},
#  u'ARPITA BASU': {'Trials': [u'NCT01886989'],
#   'id': [123484],
#   'mesh': [u'diabetes mellitus', u'diabetes mellitus, type 2']},
#  u'ARQUIZAN CAROLINE': {'Trials': [u'NCT02013635'],
#   'id': [136396],
#   'mesh': [u'venous thrombosis', u'thrombosis', u'venous thromboembolism']},
#  u'ARSENE': {'Trials': [u'NCT01333735'],
#   'id': [57864],
#   'mesh': [u'breast neoplasms']},
#  u'ARZU ATALAY': {'Trials': [u'NCT00970034'],
#   'id': [25848],
#   'mesh': [u'mitral valve insufficiency', u'atrial fibrillation']},
#  u'ASAF MILLER': {'Trials': [u'NCT00994877'],
#   'id': [20573],
#   'mesh': [u'shock, surgical', u'systemic inflammatory response syndrome']},
#  u'ASHISH GULVE': {'Trials': [u'NCT01455805'],
#   'id': [69945],
#   'mesh': [u'spinal stenosis',
#    u'spondylolisthesis',
#    'intervertebral disc degeneration',
#    u'constriction, pathologic',
#    u'spinal diseases']},
#  u'ASTRUC Dominique': {'Trials': [u'NCT00213941'], 'id': [2159], 'mesh': []},
#  u'ATHANASIOS MIGDANIS': {'Trials': [u'NCT02036346'],
#   'id': [139265],
#   'mesh': []},
#  u'ATTAL Nadin e': {'Trials': [u'NCT02030626'],
#   'id': [133205],
#   'mesh': [u'radiculopathy', u'neuralgia']},
#  u'ATTILIO OLIVIERI': {'Trials': [u'NCT00795613'],
#   'id': [22170],
#   'mesh': [u'hodgkin disease', u'lymphoma']},
#  u'ATUL PATHAK': {'Trials': [u'NCT02068118'],
#   'id': [145519],
#   'mesh': [u'heart failure']},
#  u'AUBARD Yves': {'Trials': [u'NCT00456118'],
#   'id': [10096],
#   'mesh': [u'pre-eclampsia']},
#  u'AUBERT Axel': {'Trials': [u'NCT01349426'], 'id': [53581], 'mesh': []},
#  u'AUBIN Fran\xe7ois': {'Trials': [u'NCT00933296'],
#   'id': [16758],
#   'mesh': [u'schnitzler syndrome']},
#  u'AURELIE CRAVOISY': {'Trials': [u'NCT00188058'],
#   'id': [1838],
#   'mesh': [u'acute lung injury',
#    u'respiratory distress syndrome, adult',
#    u'respiratory distress syndrome, newborn',
#    u'lung injury',
#    u'wounds and injuries']},
#  u'AUTRET Alain': {'Trials': [u'NCT00479518'],
#   'id': [10663],
#   'mesh': [u'stroke',
#    u'ischemia',
#    u'cerebral infarction',
#    u'ischemic attack, transient']},
#  u'AVE MARIA BIFFI': {'Trials': [u'NCT01798329'],
#   'id': [105272],
#   'mesh': [u'hypertension, portal',
#    u'neurotoxicity syndromes',
#    u'hypertension',
#    u'delirium',
#    u'encephalitis',
#    u'brain damage, chronic',
#    u'hepatic encephalopathy']},
#  u'AXEL DE LABRIOLLE': {'Trials': [u'NCT02068118'],
#   'id': [145511],
#   'mesh': [u'heart failure']},
#  u'AYH Leung': {'Trials': [u'NCT00563108', u'NCT00563589'],
#   'id': [11624, 11747],
#   'mesh': [u'graft vs host disease', u'graft vs host disease']},
#  u'Aad Dhollander': {'Trials': [u'NCT01571102'], 'id': [76552], 'mesh': []},
#  u'Aaditya S Udupa': {'Trials': [u'NCT00902967'], 'id': [16732], 'mesh': []},
#  u'Aafke H Honkoop': {'Trials': [u'NCT01057069'],
#   'id': [35176],
#   'mesh': [u'breast neoplasms']},
#  u'Aage Vestergaard': {'Trials': [u'NCT01687374'],
#   'id': [96949],
#   'mesh': [u'fractures, bone', u'shoulder fractures']},
#  u'Aain VERGNENEGRE': {'Trials': [u'NCT01029678'],
#   'id': [26897],
#   'mesh': [u'lung neoplasms', u'carcinoma, non-small-cell lung']},
#  u'Aakanksha Asija': {'Trials': [u'NCT01458366'],
#   'id': [71713],
#   'mesh': [u'lymphoma, b-cell', u'lymphoma', u'lymphoma, non-hodgkin']},
#  u'Aali Sheen': {'Trials': [u'NCT01876342'],
#   'id': [122738],
#   'mesh': [u'hernia']},
#  u'Aaltomaa Sirpa': {'Trials': [u'NCT01675219'],
#   'id': [88522],
#   'mesh': [u'urinary bladder neoplasms']},
#  u'Aamina M Khan': {'Trials': [u'NCT01957631'],
#   'id': [135376],
#   'mesh': [u'fasciitis', u'fasciitis, plantar']},
#  u'Aamir Badruddin': {'Trials': [u'NCT01748903'],
#   'id': [106496],
#   'mesh': [u'aneurysm', u'intracranial aneurysm']},
#  u'Aamir Cheema': {'Trials': [u'NCT00911508'],
#   'id': [16561],
#   'mesh': [u'atrial fibrillation', u'arrhythmias, cardiac']},
#  u'Aamir Jamal': {'Trials': [u'NCT01240668'],
#   'id': [41139],
#   'mesh': [u'hyponatremia']},
#  u'Aamir Rasheed': {'Trials': [u'NCT01770964'],
#   'id': [100512],
#   'mesh': [u'diabetes mellitus',
#    u'polyneuropathies',
#    u'pain',
#    u'diabetic neuropathies']},
#  u'Aanand D Naik': {'Trials': [u'NCT01274715'],
#   'id': [54369],
#   'mesh': [u'diabetes mellitus', u'depression', u'depressive disorder']},
#  u'Aanand Dinkar Naik': {'Trials': [u'NCT01572389'],
#   'id': [76075],
#   'mesh': [u'diabetes mellitus', u'depression', u'depressive disorder']},
#  u'Aapo Ahonen': {'Trials': [u'NCT00418418'],
#   'id': [9788],
#   'mesh': [u'myocardial infarction',
#    u'heart failure',
#    u'myocardial ischemia',
#    u'infarction',
#    u'coronary disease',
#    u'coronary artery disease']},
#  u'Aarathi Cholkeri': {'Trials': [u'NCT01971060'],
#   'id': [134457],
#   'mesh': [u'tissue adhesions', u'leiomyoma', u'infertility', u'myofibroma']},
#  u'Aarif Eifan': {'Trials': [u'NCT02005627'],
#   'id': [142836],
#   'mesh': [u'rhinitis']},
#  u'Aarne Feldheiser': {'Trials': [u'NCT01311297',
#    u'NCT01703442',
#    u'NCT01809782'],
#   'id': [104439, 58387, 99051],
#   'mesh': [u'delirium', u'cognition disorders', u'anuria']},
#  u'Aarne Kivioja': {'Trials': [u'NCT00841152'],
#   'id': [21021],
#   'mesh': [u'bone neoplasms', u'neoplasms']},
# ...
#   'id': [58883],
#   'mesh': [u'prolapse', u'pelvic organ prolapse']},
#  u'Adrienne A Phillips': {'Trials': [u'NCT01274533'],
#   'id': [54353],
#   'mesh': [u'lymphoma',
#    u'leukemia, t-cell',
#    u'leukemia',
#    u'leukemia-lymphoma, adult t-cell']},
#  u'Adrienne Birnbaum': {'Trials': [u'NCT01675778'],
#   'id': [88929, 88930],
#   'mesh': []},
#  u'Adrienne C Lahti': {'Trials': [u'NCT00937716', u'NCT02034253'],
#   'id': [30997, 137719],
#   'mesh': [u'schizophrenia',
#    u'psychotic disorders',
#    u'schizophrenia',
#    u'mental disorders']},
#  u'Adrienne C Scheck': {'Trials': [u'NCT02046187'],
#   'id': [146075],
#   'mesh': [u'glioblastoma']},
#  u'Adrienne Gomez': {'Trials': [u'NCT01722357'],
#   'id': [92472],
#   'mesh': [u'obesity']},
#  u'Adrienne H Brouwers': {'Trials': [u'NCT01641679'],
#   'id': [87129],
#   'mesh': [u'thyroid diseases', u'neoplasms', u'thyroid neoplasms']},
#  u'Adrienne Joy Burns': {'Trials': [u'NCT01313559'],
#   'id': [58416],
#   'mesh': [u'prostatic neoplasms']},
#  u'Adrienne Kovacs': {'Trials': [u'NCT02085083', u'NCT01881893'],
#   'id': [142622, 123231],
#   'mesh': [u'inflammatory bowel diseases',
#    u'intestinal diseases',
#    u'heart defects, congenital',
#    u'congenital abnormalities',
#    u'heart diseases']},
#  u'Adrienne Phillips': {'Trials': [u'NCT01728805', u'NCT01626664'],
#   'id': [99282, 87020],
#   'mesh': [u'lymphoma',
#    u'lymphoma, t-cell, cutaneous',
#    u'lymphoma, t-cell',
#    u'lymphoma',
#    u'leukemia, t-cell',
#    u'leukemia',
#    u'leukemia-lymphoma, adult t-cell']},
#  u'Adrienne Platt': {'Trials': [u'NCT00493259'],
#   'id': [9303],
#   'mesh': [u'insulin resistance', u'depression', u'depressive disorder']},
#  u'Adrienne Prestridge': {'Trials': [u'NCT01558076', u'NCT01527799'],
#   'id': [82905, 74395],
#   'mesh': [u'anemia, sickle cell',
#    u'anemia',
#    u'anemia, sickle cell',
#    u'anemia']},
#  u'Adrienne Prestridge Savant': {'Trials': [u'NCT01746095'],
#   'id': [99959],
#   'mesh': [u'staphylococcal infections', u'cystic fibrosis', u'fibrosis']},
#  u'Adrienne Savant': {'Trials': [u'NCT02054156'],
#   'id': [146974],
#   'mesh': [u'pseudomonas infections', u'cystic fibrosis', u'fibrosis']},
#  u'Adrija Sharma': {'Trials': [u'NCT01882751', u'NCT01717001', u'NCT01864434'],
#   'id': [121371, 92971, 122756],
#   'mesh': []},
#  u'Adrijan Sarajlija': {'Trials': [u'NCT01331642',
#    u'NCT01457456',
#    u'NCT01330277'],
#   'id': [64097, 55874, 56181],
#   'mesh': [u'metabolic diseases',
#    u'osteochondrodysplasias',
#    u'lysosomal storage diseases',
#    u'mucopolysaccharidosis iv',
#    u'mucopolysaccharidoses',
#    u'mucopolysaccharidosis ii',
#    u'lysosomal storage diseases',
#    u'metabolic diseases',
#    u'gaucher disease',
#    u'metabolic diseases',
#    u'lipid metabolism disorders',
#    u'lysosomal storage diseases',
#    u'sphingolipidoses']},
#  u'Adrijan Sarajlijan': {'Trials': [u'NCT01306604'],
#   'id': [57136],
#   'mesh': [u'niemann-pick disease, type c',
#    u'aphasia, primary progressive',
#    u'niemann-pick disease, type a',
#    u'frontotemporal dementia',
#    u'niemann-pick diseases',
#    u'pick disease of the brain']},
#  u'Adri\xe1n Alegre': {'Trials': [u'NCT00804947', u'NCT01214499'],
#   'id': [19987, 46267],
#   'mesh': [u'neoplasms, plasma cell',
#    u'multiple myeloma',
#    u'coronary disease',
#    u'coronary artery disease',
#    u'angina pectoris']},
#  u'Adri\xe1n Ar\xe9s Luque': {'Trials': [u'NCT01192529'],
#   'id': [45886],
#   'mesh': [u'parkinson disease', u'dementia', u'alzheimer disease']},
#  u'Adri\xe1n Mart\xedn Garc\xeda': {'Trials': [u'NCT01643980'],
#   'id': [81463],
#   'mesh': [u'premature birth']},
#  u'Adunsky Abraham': {'Trials': [u'NCT00647309'],
#   'id': [18159],
#   'mesh': [u'fractures, bone', u'hip fractures']},
#  u'Adupa Rao': {'Trials': [u'NCT01746095'],
#   'id': [99950],
#   'mesh': [u'staphylococcal infections', u'cystic fibrosis', u'fibrosis']},
#  u'Adurius Aidietis': {'Trials': [u'NCT01784055'],
#   'id': [109662],
#   'mesh': [u'mitral valve insufficiency',
#    u'heart valve diseases',
#    u'cardiovascular diseases',
#    u'heart diseases']},
#  u'Advait Kothurkar': {'Trials': [u'NCT00967304'],
#   'id': [25091],
#   'mesh': [u'venous thromboembolism',
#    u'thromboembolism',
#    u'venous thrombosis']},
#  u'Adyr Moss': {'Trials': [u'NCT01672164'], 'id': [89502], 'mesh': []},
#  u'Ae Young Lee': {'Trials': [u'NCT01825317'],
#   'id': [113032],
#   'mesh': [u'alzheimer disease']},
#  u'AeRang Kim': {'Trials': [u'NCT02076906'],
#   'id': [142491],
#   'mesh': [u'neoplasms']},
#  u'Aecio Flavio T Gois': {'Trials': [u'NCT02049125'],
#   'id': [146412],
#   'mesh': [u'liver cirrhosis',
#    u'hepatorenal syndrome',
#    u'wounds and injuries',
#    u'acute kidney injury',
#    u'fibrosis']},
#  u'Aedin Cassidy': {'Trials': [u'NCT02035592'],
#   'id': [139236],
#   'mesh': [u'metabolic syndrome x', u'insulin resistance']},
#  u'Aeisha K. Rivers': {'Trials': [u'NCT00769379'],
#   'id': [8867, 8861],
#   'mesh': [u'carcinoma in situ',
#    u'carcinoma, ductal',
#    u'breast neoplasms',
#    u'carcinoma, intraductal, noninfiltrating',
#    u'carcinoma',
#    u'carcinoma, ductal, breast',
#    u'carcinoma in situ',
#    u'carcinoma, ductal',
#    u'breast neoplasms',
#    u'carcinoma, intraductal, noninfiltrating',
#    u'carcinoma',
#    u'carcinoma, ductal, breast']},
#  u'Aekaterini Galimanis': {'Trials': [u'NCT00811538'],
#   'id': [23876],
#   'mesh': [u'stroke', u'ischemia', u'cerebral infarction']},
#  u'Aeri Moon': {'Trials': [u'NCT01116388'],
#   'id': [43053],
#   'mesh': [u'signs and symptoms, digestive',
#    u'digestive system diseases',
#    u'gastrointestinal diseases',
#    u'autistic disorder']},
#  u'Afferent Afferent Investigative Site': {'Trials': [u'NCT01569438'],
#   'id': [82526],
#   'mesh': [u'cystitis, interstitial', u'somatoform disorders']},
#  u'Afferent Principal Investigator': {'Trials': [u'NCT01569438'],
#   'id': [82988,
#    82989,
#    82990,
#    82876,
#    82877,
#    82878,
#    82879,
#    82880,
#    82881,
#    82882,
#    82883,
#    82884,
#    82885,
#    82886,
#    82887,
#    82888,
#    82889,
#    82890,
#    82891,
#    82892,
#    82516,
#    82517,
#    82518,
#    82519,
#    82520,
#    82521,
#    82522,
#    82523,
#    82524,
#    82525,
#    82527,
#    82528,
#    82529,
#    82530,
#    82531,
#    82532,
#    82533,
#    82417,
#    82418,
#    82419,
#    82420],
#   'mesh': [u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders',
#    u'cystitis, interstitial',
#    u'somatoform disorders']},
#  u'Affif KADOUR': {'Trials': [u'NCT01291706'],
#   'id': [50442],
#   'mesh': [u'wounds and injuries', u'brain injuries']},
#  u'Afif Ali': {'Trials': [u'NCT01558466'],
#   'id': [83545],
#   'mesh': [u'hypertension, pulmonary',
#    u'persistent fetal circulation syndrome',
#    u'hypertension']},
#  u'Afksendiyos Kalangos': {'Trials': [u'NCT00720967'],
#   'id': [17921],
#   'mesh': [u'cardiovascular diseases']},
#  u'Afra M Lootah': {'Trials': [u'NCT01707745'],
#   'id': [95828],
#   'mesh': [u'retinopathy of prematurity', u'retinal diseases']},
#  u'Afsaneh Barzi': {'Trials': [u'NCT01871571'],
#   'id': [122404],
#   'mesh': [u'cystadenocarcinoma',
#    u'adenocarcinoma',
#    u'adenocarcinoma, mucinous',
#    u'rectal neoplasms']},
#  u'Afshin Ameri': {'Trials': [u'NCT01072370'],
#   'id': [35418],
#   'mesh': [u'paralysis', u'cerebral palsy']},
#  u'Afshin Assadian': {'Trials': [u'NCT01774058'],
#   'id': [108256],
#   'mesh': [u'gangrene', u'arteriosclerosis']},
#  u'Afshin Dowlati': {'Trials': [u'NCT01366144',
#    u'NCT02070549',
#    u'NCT01461538',
#    u'NCT00961220',
#    u'NCT01638533',
#    u'NCT01638546',
#    u'NCT01957007',
#    u'NCT01912625'],
#   'id': [134619, 130664, 80713, 64810, 66350, 80721, 146819, 25563],
#   'mesh': [u'lung neoplasms',
#    u'carcinoma, non-small-cell lung',
#    u'salivary gland neoplasms',
#    u'melanoma',
#    u'lymphoma, t-cell, peripheral',
#    u'head and neck neoplasms',
#    u'leukemia, hairy cell',
#    u'burkitt lymphoma',
#    u'waldenstrom macroglobulinemia',
#    u'carcinoma, squamous cell',
#    u'papilloma, inverted',
#    u'lymphoma, non-hodgkin',
#    u'urinary bladder neoplasms',
#    u'breast neoplasms, male',
#    u'carcinoma, verrucous',
#    u'leukemia, t-cell',
#    u'tongue neoplasms',
#    u'lymphoma, t-cell',
#    u'breast neoplasms',
#    u'carcinoma, mucoepidermoid',
#    u'immunoblastic lymphadenopathy',
#    u'mycosis fungoides',
#    u'leukemia',
#    u'granuloma',
#    u'lymphoma, large-cell, immunoblastic',
#    u'hodgkin disease',
#    u'carcinoma',
#    u'lymphoma, b-cell, marginal zone',
#    u'lymphoma, b-cell',
#    u'lymphoma',
#    u'mycoses',
#    u'laryngeal neoplasms',
#    u'lymphoma, mantle-cell',
#    u'sezary syndrome',
#    u'leukemia, lymphocytic, chronic, b-cell',
#    u'neoplasms, unknown primary',
#    u'precursor cell lymphoblastic leukemia-lymphoma',
#    u'nasopharyngeal neoplasms',
#    u'neoplasms',
#    u'hypopharyngeal neoplasms',
#    u'esthesioneuroblastoma, olfactory',
#    u'lymphoma, large b-cell, diffuse',
#    u'paranasal sinus neoplasms',
#    u'lymphoma, extranodal nk-t-cell',
#    u'leukemia, lymphoid',
#    u'lymphoma, t-cell, cutaneous',
#    u'leukemia, large granular lymphocytic',
#    u'pancreatic neoplasms',
#    u'oropharyngeal neoplasms',
#    u'carcinoma, adenoid cystic',
#    u'laryngeal diseases',
#    u'lymphoma, large-cell, anaplastic',
#    u'papilloma',
#    u'liver diseases',
#    u'lymphoma, follicular',
#    u'lymphomatoid granulomatosis',
#    u'carcinoma, basal cell',
#    u'leukemia-lymphoma, adult t-cell',
#    u'anemia, refractory',
#    u'leukemia, myeloid, acute',
#    u'precursor cell lymphoblastic leukemia-lymphoma',
#    u'leukemia',
#    u'anemia, refractory, with excess of blasts',
#    u'leukemia, myeloid',
#    u'leukemia, lymphoid',
#    u'anemia',
#    u'melanoma',
#    u'neoplasms, glandular and epithelial',
#    u'small cell lung carcinoma',
#    u'neoplasms',
#    u'breast neoplasms',
#    u'carcinoma, non-small-cell lung',
#    u'germinoma',
#    u'lung neoplasms',
#    u'ovarian neoplasms',
#    u'neoplasms, germ cell and embryonal',
#    u'small cell lung carcinoma',
#    u'lung neoplasms',
#    u'neoplasm metastasis',
#    u'liver diseases',
#    u'liver neoplasms',
#    u'lymphoma, t-cell, cutaneous',
#    u'lymphoma',
#    u'lymphoma, non-hodgkin',
#    u'lymphoma, t-cell']},
#  u'Afshin Forouzannia': {'Trials': [u'NCT00877136',
#    u'NCT01376661',
#    u'NCT01688388',
#    u'NCT01295723'],
#   'id': [23152, 60201, 51442, 103071],
#   'mesh': [u'neoplasms',
#    u'carcinoma',
#    u'liver neoplasms',
#    u'carcinoma, hepatocellular',
#    u'prostatic neoplasms',
#    u'carcinoma, ductal, breast',
#    u'carcinoma, lobular',
#    u'carcinoma, intraductal, noninfiltrating',
#    u'carcinoma',
#    u'carcinoma, ductal',
#    u'carcinoma, lobular',
#    u'breast neoplasms',
#    u'carcinoma in situ',
#    u'carcinoma']},
#  u'Afshin GANGI': {'Trials': [u'NCT01471002'],
#   'id': [64909],
#   'mesh': [u'kidney neoplasms']},
#  u'Afshin Gangi': {'Trials': [u'NCT02081053', u'NCT01461265'],
#   'id': [139852, 63919],
#   'mesh': [u'neoplasm metastasis',
#    u'bone marrow diseases',
#    u'bone neoplasms',
#    u'neoplasms',
#    u'neoplasms, second primary']},
#  u'Afshin Rashtian': {'Trials': [u'NCT02070952'],
#   'id': [142264],
#   'mesh': [u'prostatic neoplasms']},
#  u'Afshin Sam': {'Trials': [u'NCT01185275'],
#   'id': [39368],
#   'mesh': [u'asthma']},
#  u'Afsoon Roberts': {'Trials': [u'NCT01940757'],
#   'id': [127252],
#   'mesh': [u'hookworm infections', u'ancylostomiasis']},
#  u'Aftab Mahmood': {'Trials': [u'NCT01921426'],
#   'id': [124684],
#   'mesh': [u'neoplasms, squamous cell',
#    u'carcinoma, squamous cell',
#    u'oropharyngeal neoplasms',
#    u'carcinoma',
#    u'head and neck neoplasms']},
#  u'Afzal Chaudhry': {'Trials': [u'NCT00476164'], 'id': [9103], 'mesh': []},
#  u'Afzal Zaidid': {'Trials': [u'NCT01027299'],
#   'id': [27863],
#   'mesh': [u'heart failure']},
#  u'Agarwal': {'Trials': [u'NCT01226004'],
#   'id': [40273],
#   'mesh': [u'prostatic neoplasms']},
#  u'Agata Bielecka-Dabrowa': {'Trials': [u'NCT02026154', u'NCT01455714'],
#   'id': [69944, 139450],
#   'mesh': [u'hypertension',
#    u'heart failure',
#    u'hypertension',
#    u'heart failure']},
#  u'Agata O\u017carek-Hanc': {'Trials': [u'NCT01266772'],
#   'id': [48216],
#   'mesh': [u'asthma']},
#  u'Agathe Edet Sanson': {'Trials': [u'NCT01231295'],
#   'id': [41079],
#   'mesh': [u'alzheimer disease']},
#  u'Agathe Edet-Sanson': {'Trials': [u'NCT01576796', u'NCT01261598'],
#   'id': [76217, 40991],
#   'mesh': [u'lung neoplasms',
#    u'carcinoma, non-small-cell lung',
#    u'lung neoplasms',
#    u'carcinoma, non-small-cell lung']},
#  u'Agathe MASSEAU': {'Trials': [u'NCT01951989'],
#   'id': [134065],
#   'mesh': [u'gaucher disease']},
#  u'Agathe RASCALOU WAULTIER': {'Trials': [u'NCT01562990'],
#   'id': [83034],
#   'mesh': [u'lymphoma, large b-cell, diffuse',
#    u'lymphoma',
#    u'lymphoma, b-cell']},
#  u'Agathe Raynaud-Simon': {'Trials': [u'NCT01599676'],
#   'id': [84527],
#   'mesh': []},
#  u'Agathe R\xf8nning': {'Trials': [u'NCT01785264'],
#   'id': [109990],
#   'mesh': [u'rupture', u'rupture, spontaneous']},
#  u'Ageed Al Farazdag': {'Trials': [u'NCT01766830'],
#   'id': [102808],
#   'mesh': [u'brucellosis',
#    u'abscess',
#    u'fever',
#    u'typhoid fever',
#    u'malaria',
#    u'trypanosomiasis',
#    u'relapsing fever',
#    u'liver abscess, amebic',
#    u'trypanosomiasis, african',
#    u'leishmaniasis',
#    u'weil disease',
#    u'tuberculosis',
#    u'leptospirosis',
#    u'leishmaniasis, visceral',
#    u'liver abscess',
#    u'melioidosis',
#    u'rickettsia infections']},
#  u'Aggrey Dhabangi': {'Trials': [u'NCT01586923'],
#   'id': [78468],
#   'mesh': [u'anemia']},
#  u'Agi Golan': {'Trials': [u'NCT01565226', u'NCT01572272'],
#   'id': [76062, 82839],
#   'mesh': []},
#  u'Agnaldo J Lopes': {'Trials': [u'NCT01641705', u'NCT01888705'],
#   'id': [87134, 117871],
#   'mesh': [u'arthritis, rheumatoid',
#    u'arthritis',
#    u'pulmonary disease, chronic obstructive']},
#  u'Agnaldo Jos\xe9 Lopes': {'Trials': [u'NCT01725971'],
#   'id': [93415],
#   'mesh': [u'silicosis']},
#  u'Agnelli Giancarlo': {'Trials': [u'NCT00222625'],
#   'id': [2257],
#   'mesh': [u'hemorrhage', u'cerebral hemorrhage']},
#  ...}

# %%
def get_articles_data(data):
    
    time_count = 0
    last_time = time.time()
    
    auth_articles = {}
    auth_articles_abs = {}
    
    for key, value in data.items():
        time_count += 1
        if (time_count%100) == 0:
            print 'Count: ', time_count
            print 'Duration (mins): ', (time.time() - last_time)/60
            last_time = time.time()
            
        #if the investigator has no mesh terms in the db skip them
        if len(investigator_mesh_dict[key]['mesh']) == 0:
            continue
        
        auth_articles[key] = {}
        auth_articles_abs[key] = {}
        
        soup = BeautifulSoup(value)
        for article in soup.findAll('pubmedarticle'):

            #FILTER

            #get published dates
            #most pubdates refer to date as year but some refer to it as medlinedate
            try:
                year = article.findChild('pubdate').findChild('year').text
            except:
                #this includes months so we just pull out the year
                year = article.findChild('pubdate').findChild('medlinedate').text[:4]
            #if the year of the article is before 1995 skip it
            if int(year) < 1995:
                print 'Pre-1995'
                continue

            mesh_list = article.findChild('meshheadinglist')
            #if there are no mesh terms skip article
            if mesh_list is None:
                continue
                
            #creates a list of mesh terms. each mesh term is a tuple with
            #a major minor marker
            mesh_terms = article.findAll('meshheading')
            mesh_terms_list = []
            for term in mesh_terms:
                for element in term:
                    try:
                        if element.name == 'descriptorname':
                            mesh_terms_list.append((element.text, element.attrs.values()[0]))
                    except:
                        pass
            
            #check to see if there are any matching mesh terms between the
            #article and the investigator mesh terms from the db
            skip_switch = True
            for term, weight in mesh_terms_list:
                #do not use certain very common mesh terms for matching
                if term.lower() in ['adult', 'humans', 'male', 'female', 'aged']:
                    continue
                if term.lower() in investigator_mesh_dict[key]['mesh']:
                    skip_switch = False
                    break
            
            if skip_switch:
                continue

            #GET DATA

            title = article.findChild('articletitle').text
            pub_id = article.findChild('pmid').text

            #get a list of all other ids
            other_ids = article.findAll('articleid')
            other_ids_list = []
            for ids in other_ids:
                other_ids_list.append((ids.attrs.values()[0],ids.text))

            abstract = article.findChild('abstract')

            #creates a list of lists where each list consists of
            #tuples of data types and the data
            authors = article.findAll('author')
            authors_list = []
            for author in authors:
                temp = []
                for element in author:
                    try:
                        if element.name is not None:
                            if element.name == 'initials' or element.name == 'suffix':
                                continue
                            if element.name == 'forename':
                                temp[0] = element.text + ' ' + temp[0]
                                continue
                            temp.append(element.text)
                    except:
                        pass

                authors_list.append(temp)
                del temp
        
            country = article.findChild('country').text

            language = article.findChild('language').text
            #this is a list of the chemicals found in the paper
            #may be useful for maching articles to trials
            #creates a list of all the chemicals in the paper if there are any
            chemicals = article.findAll('chemical')
            chemicals_list = []
            for chemical in chemicals:
                for element in chemical:
                    try:
                        if element.name == 'nameofsubstance':
                            chemicals_list.append(element.text)
                    except:
                        pass

            #creates a list of keywords. each keyword is a tuple with
            #a major minor marker
            keywords = article.findAll('keyword')
            keywords_list = []
            for keyword in keywords:
                keywords_list.append((keyword.text, keyword.attrs.values()[0]))
    
            #not all journals have an issn, get text if it exists, pass if it doesn't
            journal_id_issn = article.findChild('issn')
            try:
                journal_id_issn = journal_id_issn.text
            except:
                pass


            #create dictionary
            auth_articles[key][pub_id] = {'journal_id':journal_id_issn,
                                          'keywords':keywords_list,
                                          'mesh':mesh_terms_list,
                                          'chemicals':chemicals_list,
                                          'language':language,
                                          'country':country,
                                          'authors':authors_list,
                                          'other_ids':other_ids_list,
                                          'title':title,
                                          'year':year
                                          }
            auth_articles_abs[key][pub_id] = abstract
    return auth_articles, auth_articles_abs

# %%
auth_articles, auth_articles_abs = get_articles_data(data)

# %%
investigator_mesh_dict[u'Michael M\xfcntener']['mesh']
# Out:
# [u'prostatic neoplasms', u'anoxia']
